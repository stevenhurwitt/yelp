# %% [markdown]
# # Yelp Dataset Machine Learning Analysis
#
# This notebook applies various machine learning models to the Yelp dataset for:
# 1. **Business Rating Prediction** - Predict business star ratings
# 2. **Review Sentiment Analysis** - Classify review sentiment from text
# 3. **User Behavior Prediction** - Predict user engagement metrics
# 4. **Business Success Classification** - Classify businesses as successful or not
# 5. **Recommendation Systems** - Build collaborative filtering models

# %% [markdown]
# ## Setup and Data Loading

# %%
# Import required libraries
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier, GradientBoostingRegressor
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.svm import SVR, SVC
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

# PySpark imports
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.ml.feature import VectorAssembler, StringIndexer, StandardScaler as SparkStandardScaler
from pyspark.ml.regression import RandomForestRegressor as SparkRandomForestRegressor
from pyspark.ml.classification import RandomForestClassifier as SparkRandomForestClassifier
from pyspark.ml.evaluation import RegressionEvaluator, BinaryClassificationEvaluator
from pyspark.ml import Pipeline

print("Libraries imported successfully!")

# Set plotting style
plt.style.use('default')
sns.set_palette("husl")
plt.rcParams['figure.figsize'] = (12, 8)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Libraries imported successfully!

# %%
# Load credentials
with open("creds.json", "r") as f:
    creds = json.load(f)
    f.close()

print("Credentials loaded successfully!")
# Out:
# Credentials loaded successfully!

# %%
# Initialize Spark Session
try:
    spark = SparkSession.builder \
        .appName("YelpMachineLearning") \
        .master("spark://spark-master:7077") \
        .config("spark.driver.memory", "4g") \
        .config("spark.executor.memory", "4g") \
        .config("spark.executor.cores", "4") \
        .config("spark.worker.memory", "4g") \
        .config("spark.cores.max", "8") \
        .config("spark.hadoop.fs.s3a.access.key", creds["aws_client"]) \
        .config("spark.hadoop.fs.s3a.secret.key", creds["aws_secret"]) \
        .config("spark.jars.packages", 
                "org.apache.hadoop:hadoop-aws:3.3.4," + 
                "org.apache.hadoop:hadoop-common:3.3.4," +
                "com.amazonaws:aws-java-sdk-bundle:1.12.261," +
                "org.apache.logging.log4j:log4j-slf4j-impl:2.17.2," +
                "org.apache.logging.log4j:log4j-api:2.17.2," +
                "org.apache.logging.log4j:log4j-core:2.17.2," + 
                "org.apache.hadoop:hadoop-client:3.3.4," + 
                "io.delta:delta-core_2.12:2.4.0," + 
                "org.postgresql:postgresql:42.2.18") \
        .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
        .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
        .config("spark.hadoop.fs.s3a.endpoint", "s3.amazonaws.com") \
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
        .getOrCreate()
    
    print("Spark session initialized successfully!")
    
except Exception as e:
    print(f"Error initializing Spark: {str(e)}")
# Out:
# :: loading settings :: url = jar:file:/usr/local/lib/python3.7/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# org.apache.hadoop#hadoop-common added as a dependency
# com.amazonaws#aws-java-sdk-bundle added as a dependency
# org.apache.logging.log4j#log4j-slf4j-impl added as a dependency
# org.apache.logging.log4j#log4j-api added as a dependency
# org.apache.logging.log4j#log4j-core added as a dependency
# org.apache.hadoop#hadoop-client added as a dependency
# io.delta#delta-core_2.12 added as a dependency
# org.postgresql#postgresql added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-d6813aa7-6518-432e-9166-a3fb2dbfc173;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.3.4 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.12.262 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# 	found org.apache.hadoop#hadoop-common;3.3.4 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_7;1.1.1 in central
# 	found org.apache.hadoop#hadoop-annotations;3.3.4 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 in central
# 	found com.google.guava#guava;27.0-jre in central
# 	found com.google.guava#failureaccess;1.0 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.5.2 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.17 in central
# 	found commons-cli#commons-cli;1.2 in central
# 	found org.apache.commons#commons-math3;3.1.1 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found org.apache.httpcomponents#httpcore;4.4.13 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found commons-codec#commons-codec;1.15 in central
# 	found commons-io#commons-io;2.8.0 in central
# 	found commons-net#commons-net;3.6 in central
# 	found commons-collections#commons-collections;3.2.2 in central
# 	found javax.servlet#javax.servlet-api;3.1.0 in central
# 	found org.eclipse.jetty#jetty-server;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-http;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-io;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-servlet;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-security;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-webapp;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-xml;9.4.43.v20210629 in central
# 	found com.sun.jersey#jersey-core;1.19 in central
# 	found javax.ws.rs#jsr311-api;1.1.1 in central
# 	found com.sun.jersey#jersey-servlet;1.19 in central
# 	found com.sun.jersey#jersey-server;1.19 in central
# 	found com.sun.jersey#jersey-json;1.19 in central
# 	found org.codehaus.jettison#jettison;1.1 in central
# 	found com.sun.xml.bind#jaxb-impl;2.2.3-1 in central
# 	found javax.xml.bind#jaxb-api;2.2.11 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# 	found org.codehaus.jackson#jackson-mapper-asl;1.9.13 in central
# 	found org.codehaus.jackson#jackson-jaxrs;1.9.13 in central
# 	found org.codehaus.jackson#jackson-xc;1.9.13 in central
# 	found ch.qos.reload4j#reload4j;1.2.22 in central
# 	found commons-beanutils#commons-beanutils;1.9.4 in central
# 	found org.apache.commons#commons-configuration2;2.1.1 in central
# 	found org.apache.commons#commons-lang3;3.12.0 in central
# 	found org.apache.commons#commons-text;1.4 in central
# 	found org.slf4j#slf4j-api;1.7.36 in central
# 	found org.slf4j#slf4j-reload4j;1.7.36 in central
# 	found org.apache.avro#avro;1.7.7 in central
# 	found com.thoughtworks.paranamer#paranamer;2.3 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.2 in central
# 	found org.apache.commons#commons-compress;1.21 in central
# 	found com.google.re2j#re2j;1.1 in central
# 	found com.google.protobuf#protobuf-java;2.5.0 in central
# 	found com.google.code.gson#gson;2.8.9 in central
# 	found org.apache.hadoop#hadoop-auth;3.3.4 in central
# 	found com.nimbusds#nimbus-jose-jwt;9.8.1 in central
# 	found com.github.stephenc.jcip#jcip-annotations;1.0-1 in central
# 	found net.minidev#json-smart;2.4.7 in central
# 	found net.minidev#accessors-smart;2.4.7 in central
# 	found org.ow2.asm#asm;5.0.4 in central
# 	found org.apache.zookeeper#zookeeper;3.5.6 in central
# 	found org.apache.zookeeper#zookeeper-jute;3.5.6 in central
# 	found org.apache.yetus#audience-annotations;0.5.0 in central
# 	found org.apache.curator#curator-framework;4.2.0 in central
# 	found org.apache.curator#curator-client;4.2.0 in central
# 	found org.apache.kerby#kerb-simplekdc;1.0.1 in central
# 	found org.apache.kerby#kerb-client;1.0.1 in central
# 	found org.apache.kerby#kerby-config;1.0.1 in central
# 	found org.apache.kerby#kerb-core;1.0.1 in central
# 	found org.apache.kerby#kerby-pkix;1.0.1 in central
# 	found org.apache.kerby#kerby-asn1;1.0.1 in central
# 	found org.apache.kerby#kerby-util;1.0.1 in central
# 	found org.apache.kerby#kerb-common;1.0.1 in central
# 	found org.apache.kerby#kerb-crypto;1.0.1 in central
# 	found org.apache.kerby#kerb-util;1.0.1 in central
# 	found org.apache.kerby#token-provider;1.0.1 in central
# 	found org.apache.kerby#kerb-admin;1.0.1 in central
# 	found org.apache.kerby#kerb-server;1.0.1 in central
# 	found org.apache.kerby#kerb-identity;1.0.1 in central
# 	found org.apache.kerby#kerby-xdr;1.0.1 in central
# 	found com.jcraft#jsch;0.1.55 in central
# 	found org.apache.curator#curator-recipes;4.2.0 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.12.7 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.12.7 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.12.7 in central
# 	found org.codehaus.woodstox#stax2-api;4.2.1 in central
# 	found com.fasterxml.woodstox#woodstox-core;5.3.0 in central
# 	found dnsjava#dnsjava;2.1.7 in central
# 	found jakarta.activation#jakarta.activation-api;1.2.1 in central
# 	found javax.servlet.jsp#jsp-api;2.1 in central
# 	found org.apache.logging.log4j#log4j-slf4j-impl;2.17.2 in central
# 	found org.apache.logging.log4j#log4j-core;2.17.2 in central
# 	found org.apache.logging.log4j#log4j-api;2.17.2 in central
# 	found org.apache.hadoop#hadoop-client;3.3.4 in central
# 	found org.apache.hadoop#hadoop-hdfs-client;3.3.4 in central
# 	found org.apache.hadoop#hadoop-yarn-api;3.3.4 in central
# 	found org.apache.hadoop#hadoop-yarn-client;3.3.4 in central
# 	found org.eclipse.jetty.websocket#websocket-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-common;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-api;9.4.43.v20210629 in central
# 	found org.jline#jline;3.9.0 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-core;3.3.4 in central
# 	found org.apache.hadoop#hadoop-yarn-common;3.3.4 in central
# 	found com.sun.jersey#jersey-client;1.19 in central
# 	found com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.12.7 in central
# 	found jakarta.xml.bind#jakarta.xml.bind-api;2.3.2 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.12.7 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.12.7 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-jobclient;3.3.4 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-common;3.3.4 in central
# 	found io.delta#delta-core_2.12;2.4.0 in central
# 	found io.delta#delta-storage;2.4.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# 	found org.postgresql#postgresql;42.2.18 in central
# 	found org.checkerframework#checker-qual;3.5.0 in central
# :: resolution report :: resolve 1409ms :: artifacts dl 50ms
# 	:: modules in use:
# 	ch.qos.reload4j#reload4j;1.2.22 from central in [default]
# 	com.amazonaws#aws-java-sdk-bundle;1.12.262 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.12.7 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.12.7 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.12.7 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.12.7 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.12.7 from central in [default]
# 	com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.12.7 from central in [default]
# 	com.fasterxml.woodstox#woodstox-core;5.3.0 from central in [default]
# 	com.github.stephenc.jcip#jcip-annotations;1.0-1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.8.9 from central in [default]
# 	com.google.guava#failureaccess;1.0 from central in [default]
# 	com.google.guava#guava;27.0-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.google.protobuf#protobuf-java;2.5.0 from central in [default]
# 	com.google.re2j#re2j;1.1 from central in [default]
# 	com.jcraft#jsch;0.1.55 from central in [default]
# 	com.nimbusds#nimbus-jose-jwt;9.8.1 from central in [default]
# 	com.sun.jersey#jersey-client;1.19 from central in [default]
# 	com.sun.jersey#jersey-core;1.19 from central in [default]
# 	com.sun.jersey#jersey-json;1.19 from central in [default]
# 	com.sun.jersey#jersey-server;1.19 from central in [default]
# 	com.sun.jersey#jersey-servlet;1.19 from central in [default]
# 	com.sun.xml.bind#jaxb-impl;2.2.3-1 from central in [default]
# 	com.thoughtworks.paranamer#paranamer;2.3 from central in [default]
# 	commons-beanutils#commons-beanutils;1.9.4 from central in [default]
# 	commons-cli#commons-cli;1.2 from central in [default]
# 	commons-codec#commons-codec;1.15 from central in [default]
# 	commons-collections#commons-collections;3.2.2 from central in [default]
# 	commons-io#commons-io;2.8.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	commons-net#commons-net;3.6 from central in [default]
# 	dnsjava#dnsjava;2.1.7 from central in [default]
# 	io.delta#delta-core_2.12;2.4.0 from central in [default]
# 	io.delta#delta-storage;2.4.0 from central in [default]
# 	jakarta.activation#jakarta.activation-api;1.2.1 from central in [default]
# 	jakarta.xml.bind#jakarta.xml.bind-api;2.3.2 from central in [default]
# 	javax.servlet#javax.servlet-api;3.1.0 from central in [default]
# 	javax.servlet.jsp#jsp-api;2.1 from central in [default]
# 	javax.ws.rs#jsr311-api;1.1.1 from central in [default]
# 	javax.xml.bind#jaxb-api;2.2.11 from central in [default]
# 	net.minidev#accessors-smart;2.4.7 from central in [default]
# 	net.minidev#json-smart;2.4.7 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	org.apache.avro#avro;1.7.7 from central in [default]
# 	org.apache.commons#commons-compress;1.21 from central in [default]
# 	org.apache.commons#commons-configuration2;2.1.1 from central in [default]
# 	org.apache.commons#commons-lang3;3.12.0 from central in [default]
# 	org.apache.commons#commons-math3;3.1.1 from central in [default]
# 	org.apache.commons#commons-text;1.4 from central in [default]
# 	org.apache.curator#curator-client;4.2.0 from central in [default]
# 	org.apache.curator#curator-framework;4.2.0 from central in [default]
# 	org.apache.curator#curator-recipes;4.2.0 from central in [default]
# 	org.apache.hadoop#hadoop-annotations;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-auth;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-common;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-hdfs-client;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-mapreduce-client-common;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-mapreduce-client-core;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-mapreduce-client-jobclient;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-client;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-common;3.3.4 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_7;1.1.1 from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.13 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.13 from central in [default]
# 	org.apache.kerby#kerb-admin;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-client;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-common;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-core;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-crypto;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-identity;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-server;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-simplekdc;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-util;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-asn1;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-config;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-pkix;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-util;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-xdr;1.0.1 from central in [default]
# 	org.apache.kerby#token-provider;1.0.1 from central in [default]
# 	org.apache.logging.log4j#log4j-api;2.17.2 from central in [default]
# 	org.apache.logging.log4j#log4j-core;2.17.2 from central in [default]
# 	org.apache.logging.log4j#log4j-slf4j-impl;2.17.2 from central in [default]
# 	org.apache.yetus#audience-annotations;0.5.0 from central in [default]
# 	org.apache.zookeeper#zookeeper;3.5.6 from central in [default]
# 	org.apache.zookeeper#zookeeper-jute;3.5.6 from central in [default]
# 	org.checkerframework#checker-qual;3.5.0 from central in [default]
# 	org.codehaus.jackson#jackson-core-asl;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-jaxrs;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-mapper-asl;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-xc;1.9.13 from central in [default]
# 	org.codehaus.jettison#jettison;1.1 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.17 from central in [default]
# 	org.codehaus.woodstox#stax2-api;4.2.1 from central in [default]
# 	org.eclipse.jetty#jetty-client;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-http;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-io;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-security;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-server;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-servlet;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-util;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-webapp;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-xml;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-api;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-client;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-common;9.4.43.v20210629 from central in [default]
# 	org.jline#jline;3.9.0 from central in [default]
# 	org.ow2.asm#asm;5.0.4 from central in [default]
# 	org.postgresql#postgresql;42.2.18 from central in [default]
# 	org.slf4j#slf4j-api;1.7.36 from central in [default]
# 	org.slf4j#slf4j-reload4j;1.7.36 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.8.2 from central in [default]
# 	:: evicted modules:
# 	org.checkerframework#checker-qual;2.5.2 by [org.checkerframework#checker-qual;3.5.0] in [default]
# 	com.amazonaws#aws-java-sdk-bundle;1.12.261 by [com.amazonaws#aws-java-sdk-bundle;1.12.262] in [default]
# 	org.slf4j#slf4j-api;1.7.25 by [org.slf4j#slf4j-api;1.7.36] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |  123  |   0   |   0   |   3   ||  120  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-d6813aa7-6518-432e-9166-a3fb2dbfc173
# 	confs: [default]
# 	0 artifacts copied, 120 already retrieved (0kB/13ms)
# 25/09/03 21:02:12 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# /usr/local/lib/python3.7/site-packages/pyspark/context.py:317: FutureWarning: Python 3.7 support is deprecated in Spark 3.4.
#   warnings.warn("Python 3.7 support is deprecated in Spark 3.4.", FutureWarning)
# Spark session initialized successfully!

# %%
# Load data from Delta tables
def read_delta(path: str):
    """Read a Delta table from S3 path"""
    try:
        df = spark.read \
            .format("delta") \
            .option("inferSchema", "true") \
            .load(path)
            
        print(f"Successfully read delta table from: {path}")
        print(f"Number of rows: {df.count():,}")
        return df
        
    except Exception as e:
        print(f"Error reading delta table from {path}")
        print(f"Error: {str(e)}")
        return None

# Load all tables
bucket = "yelp-stevenhurwitt-2"

business_df = read_delta(f"s3a://{bucket}/business")
review_df = read_delta(f"s3a://{bucket}/reviews")
user_df = read_delta(f"s3a://{bucket}/users")
checkin_df = read_delta(f"s3a://{bucket}/checkins")
tip_df = read_delta(f"s3a://{bucket}/tips")
# Out:
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/03 21:03:55 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/03 21:03:55 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Number of rows: 150,346
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/03 21:03:55 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Number of rows: 150,346
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/03 21:03:55 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Number of rows: 150,346
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/reviews
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/03 21:03:55 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Number of rows: 150,346
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/reviews
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/03 21:03:55 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Number of rows: 150,346
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/reviews
# Number of rows: 6,990,280
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/users
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/users
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/03 21:03:55 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Number of rows: 150,346
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/reviews
# Number of rows: 6,990,280
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/users
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/users
# 25/09/03 21:02:37 WARN MetricsConfig: Cannot locate configuration: tried hadoop-metrics2-s3a-file-system.properties,hadoop-metrics2.properties
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/03 21:03:55 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Number of rows: 150,346
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/reviews
# Number of rows: 6,990,280
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/users
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/users
# Number of rows: 1,987,897
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/checkins
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/checkins
# Number of rows: 131,930
# Number of rows: 131,930
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/tips
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/tips
# Number of rows: 908,915
# Number of rows: 908,915

# %% [markdown]
# ## Feature Engineering

# %%
# Create comprehensive features for machine learning
print("Creating feature dataset...")

# Business features with aggregated metrics
business_features = business_df.select(
    "business_id",
    "stars",
    "review_count",
    "is_open",
    "state",
    "city",
    "categories",
    "latitude",
    "longitude"
).withColumn(
    "has_categories", when(col("categories").isNotNull(), 1).otherwise(0)
).withColumn(
    "is_restaurant", when(col("categories").contains("Restaurant"), 1).otherwise(0)
).withColumn(
    "category_count", when(col("categories").isNotNull(), size(split(col("categories"), ","))).otherwise(0)
)

# Add user aggregated features to reviews
user_agg = user_df.select(
    "user_id",
    "review_count",
    "useful",
    "funny",
    "cool",
    "fans",
    "average_stars"
).withColumnRenamed("review_count", "user_review_count") \
 .withColumnRenamed("useful", "user_useful") \
 .withColumnRenamed("funny", "user_funny") \
 .withColumnRenamed("cool", "user_cool")

# Create review features dataset
review_features = review_df.select(
    "review_id",
    "user_id",
    "business_id",
    "stars",
    "useful",
    "funny",
    "cool",
    "text",
    "date"
).withColumn("text_length", length(col("text"))) \
 .withColumn("year", year(col("date"))) \
 .withColumn("month", month(col("date"))) \
 .withColumn("total_votes", col("useful") + col("funny") + col("cool"))

# Join datasets for comprehensive feature set
ml_dataset = review_features.join(business_features, "business_id", "inner") \
                           .join(user_agg, "user_id", "inner")

print(f"ML dataset created with {ml_dataset.count():,} rows and {len(ml_dataset.columns)} columns")
# Out:
# Creating feature dataset...
# Creating feature dataset...
# 25/09/03 21:28:37 ERROR TaskSchedulerImpl: Lost executor 0 on 172.18.0.5: Command exited with code 137
# 25/09/03 21:28:37 WARN TaskSetManager: Lost task 2.0 in stage 46.0 (TID 744) (172.18.0.5 executor 0): ExecutorLostFailure (executor 0 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/03 21:28:37 WARN TaskSetManager: Lost task 1.0 in stage 46.0 (TID 743) (172.18.0.5 executor 0): ExecutorLostFailure (executor 0 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/03 21:28:37 WARN TaskSetManager: Lost task 0.0 in stage 46.0 (TID 742) (172.18.0.5 executor 0): ExecutorLostFailure (executor 0 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/03 21:28:37 WARN TaskSetManager: Lost task 3.0 in stage 46.0 (TID 745) (172.18.0.5 executor 0): ExecutorLostFailure (executor 0 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_22 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_12 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_22 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_22 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_12 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_12 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_22 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_22 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_12 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_22 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_22 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_12 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_22 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_12 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_48 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_13 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_22 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_12 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_17 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_25 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_40 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_30 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_29 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_10 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_47 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_37 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_12 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_28 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_19 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_5 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_1 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_9 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_14 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_34 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_35 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_7 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_36 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_12 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_8 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_18 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_15 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_41 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_33 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_21 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_45 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_6 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_39 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_2 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_11 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_43 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_23 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_16 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_49 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_42 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_32 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_38 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_26 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_27 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_20 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_46 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_0 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_3 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_4 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_31 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_44 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_24 !
# 25/09/03 21:28:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_22 !
# ...
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# 25/09/03 21:28:48 WARN TaskSetManager: Lost task 2.1 in stage 46.0 (TID 749) (172.18.0.5 executor 1): FetchFailed(null, shuffleId=11, mapIndex=-1, mapId=-1, reduceId=99, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 11 partition 99
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# 25/09/03 21:28:48 WARN TaskSetManager: Lost task 1.1 in stage 46.0 (TID 748) (172.18.0.5 executor 1): FetchFailed(null, shuffleId=11, mapIndex=-1, mapId=-1, reduceId=49, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 11 partition 49
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# 25/09/03 21:28:48 WARN TaskSetManager: Lost task 3.1 in stage 46.0 (TID 746) (172.18.0.5 executor 1): FetchFailed(null, shuffleId=11, mapIndex=-1, mapId=-1, reduceId=149, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 11 partition 149
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# 25/09/03 21:28:48 WARN TaskSetManager: Lost task 4.0 in stage 46.0 (TID 750) (172.18.0.5 executor 1): FetchFailed(null, shuffleId=11, mapIndex=-1, mapId=-1, reduceId=198, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 11 partition 198
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# [Stage 46:=======================>                                  (2 + 3) / 5]
# ML dataset created with 6,990,247 rows and 30 columns

# %%
# Sample data for local ML processing (to manage memory)
sample_size = 0.1  # 10% sample
ml_sample = ml_dataset.sample(sample_size, seed=42)

print(f"Sampled {ml_sample.count():,} rows for ML analysis")
ml_sample.show(5)
# Out:
# 25/09/04 20:53:27 ERROR TaskSchedulerImpl: Lost executor 55 on 172.18.0.6: Command exited with code 137
# 25/09/04 20:53:27 WARN TaskSetManager: Lost task 0.0 in stage 116.0 (TID 5296) (172.18.0.6 executor 55): ExecutorLostFailure (executor 55 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 20:53:27 WARN TaskSetManager: Lost task 4.0 in stage 116.0 (TID 5298) (172.18.0.6 executor 55): ExecutorLostFailure (executor 55 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 20:53:27 WARN TaskSetManager: Lost task 2.0 in stage 116.0 (TID 5297) (172.18.0.6 executor 55): ExecutorLostFailure (executor 55 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 20:53:27 WARN TaskSetManager: Lost task 5.0 in stage 116.0 (TID 5299) (172.18.0.6 executor 55): ExecutorLostFailure (executor 55 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_6 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_37 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_28 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_44 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_33 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_6 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_31 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_27 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_40 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_26 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_12 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_40 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_49 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_29 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_4 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_37 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_45 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_27 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_30 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_36 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_45 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_7 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_30 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_39 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_10 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_4 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_2 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_9 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_24 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_18 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_26 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_15 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_24 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_0 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_21 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_37 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_44 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_17 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_28 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_32 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_11 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_47 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_26 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_12 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_15 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_24 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_16 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_17 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_45 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_47 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_10 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_9 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_16 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_44 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_25 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_49 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_21 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_19 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_36 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_4 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_26 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_39 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_30 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_46 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_46 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_2 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_0 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_18 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_36 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_16 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_24 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_8 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_4 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_14 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_6 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_40 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_8 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_18 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_14 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_0 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_27 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_39 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_47 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_18 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_19 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_39 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_6 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_44 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_2 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_36 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_45 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_40 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_0 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_7 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_19 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_25 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_32 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_16 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_30 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_32 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_11 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_2 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_29 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_19 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_33 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_32 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_37 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_47 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_27 !
# 25/09/04 20:53:27 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_31 !
# 25/09/04 21:06:39 ERROR TaskSchedulerImpl: Lost executor 56 on 172.18.0.5: Command exited with code 137
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 0.0 in stage 122.0 (TID 5663) (172.18.0.5 executor 56): ExecutorLostFailure (executor 56 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 6.0 in stage 122.0 (TID 5669) (172.18.0.5 executor 56): ExecutorLostFailure (executor 56 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 2.0 in stage 122.0 (TID 5665) (172.18.0.5 executor 56): ExecutorLostFailure (executor 56 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 4.0 in stage 122.0 (TID 5667) (172.18.0.5 executor 56): ExecutorLostFailure (executor 56 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_48 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_3 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_41 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_22 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_11 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_35 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_46 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_43 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_8 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_15 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_42 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_35 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_26 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_9 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_29 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_29 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_49 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_34 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_27 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_48 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_11 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_25 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_34 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_42 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_18 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_16 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_38 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_1 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_25 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_13 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_42 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_45 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_25 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_1 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_24 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_17 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_22 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_45 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_13 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_14 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_28 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_22 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_9 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_36 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_38 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_14 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_48 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_12 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_48 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_6 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_32 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_34 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_7 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_27 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_5 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_33 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_43 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_36 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_47 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_21 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_9 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_20 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_12 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_9 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_13 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_15 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_11 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_0 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_46 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_22 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_41 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_1 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_13 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_20 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_8 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_38 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_20 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_4 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_40 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_8 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_11 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_23 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_21 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_3 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_17 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_37 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_21 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_20 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_23 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_18 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_1 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_49 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_17 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_14 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_32 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_30 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_49 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_3 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_5 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_33 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_10 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_44 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_23 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_42 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_5 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_43 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_23 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_41 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_10 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_31 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_6 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_7 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_35 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_37 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_30 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_3 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_20 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_8 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_20 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_31 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_1 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_35 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_15 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_10 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_47 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_46 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_43 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_33 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_42 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_13 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_5 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_28 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_29 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_13 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_19 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_44 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_39 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_34 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_3 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_23 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_2 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_22 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_1 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_28 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_14 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_29 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_5 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_48 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_35 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_2 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_5 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_17 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_21 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_10 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_38 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_41 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_4 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_7 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_35 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_28 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_34 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_31 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_12 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_15 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_41 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_33 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_16 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_41 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_39 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_31 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_24 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_34 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_23 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_43 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_3 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_38 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_49 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_42 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_25 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_43 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_38 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_26 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_46 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_0 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_7 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_48 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_22 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_12 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_19 !
# 25/09/04 21:06:39 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_40 !
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 5.0 in stage 122.0 (TID 5668) (172.18.0.6 executor 57): FetchFailed(null, shuffleId=25, mapIndex=-1, mapId=-1, reduceId=122, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 25 partition 122
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 7.0 in stage 122.0 (TID 5670) (172.18.0.6 executor 57): FetchFailed(null, shuffleId=25, mapIndex=-1, mapId=-1, reduceId=171, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 25 partition 171
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 3.0 in stage 122.0 (TID 5666) (172.18.0.6 executor 57): FetchFailed(null, shuffleId=25, mapIndex=-1, mapId=-1, reduceId=73, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 25 partition 73
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 1.0 in stage 122.0 (TID 5664) (172.18.0.6 executor 57): FetchFailed(null, shuffleId=25, mapIndex=-1, mapId=-1, reduceId=24, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 25 partition 24
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 0.1 in stage 122.0 (TID 5674) (172.18.0.6 executor 57): FetchFailed(null, shuffleId=25, mapIndex=-1, mapId=-1, reduceId=0, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 25 partition 0
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.ZippedPartitionsRDD2.compute(ZippedPartitionsRDD.scala:89)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.rdd.MapPartitionsRDD.compute(MapPartitionsRDD.scala:52)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# 	at org.apache.spark.shuffle.ShuffleWriteProcessor.write(ShuffleWriteProcessor.scala:59)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:101)
# 	at org.apache.spark.scheduler.ShuffleMapTask.runTask(ShuffleMapTask.scala:53)
# 	at org.apache.spark.TaskContext.runTaskWithListeners(TaskContext.scala:161)
# 	at org.apache.spark.scheduler.Task.run(Task.scala:139)
# 	at org.apache.spark.executor.Executor$TaskRunner.$anonfun$run$3(Executor.scala:554)
# 	at org.apache.spark.util.Utils$.tryWithSafeFinally(Utils.scala:1529)
# 	at org.apache.spark.executor.Executor$TaskRunner.run(Executor.scala:557)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
#
# )
# 25/09/04 21:06:39 WARN TaskSetManager: Lost task 6.1 in stage 122.0 (TID 5673) (172.18.0.6 executor 57): FetchFailed(null, shuffleId=25, mapIndex=-1, mapId=-1, reduceId=147, message=
# org.apache.spark.shuffle.MetadataFetchFailedException: Missing an output location for shuffle 25 partition 147
# 	at org.apache.spark.MapOutputTracker$.validateStatus(MapOutputTracker.scala:1718)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11(MapOutputTracker.scala:1665)
# 	at org.apache.spark.MapOutputTracker$.$anonfun$convertMapStatuses$11$adapted(MapOutputTracker.scala:1664)
# 	at scala.collection.Iterator.foreach(Iterator.scala:943)
# 	at scala.collection.Iterator.foreach$(Iterator.scala:943)
# 	at scala.collection.AbstractIterator.foreach(Iterator.scala:1431)
# 	at org.apache.spark.MapOutputTracker$.convertMapStatuses(MapOutputTracker.scala:1664)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorIdImpl(MapOutputTracker.scala:1306)
# 	at org.apache.spark.MapOutputTrackerWorker.getMapSizesByExecutorId(MapOutputTracker.scala:1268)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:141)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader(ShuffleManager.scala:63)
# 	at org.apache.spark.shuffle.ShuffleManager.getReader$(ShuffleManager.scala:57)
# 	at org.apache.spark.shuffle.sort.SortShuffleManager.getReader(SortShuffleManager.scala:73)
# 	at org.apache.spark.sql.execution.ShuffledRowRDD.compute(ShuffledRowRDD.scala:200)
# 	at org.apache.spark.rdd.RDD.computeOrReadCheckpoint(RDD.scala:367)
# 	at org.apache.spark.rdd.RDD.iterator(RDD.scala:331)
# ...
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_24 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_3 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_8 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_20 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_31 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_1 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_15 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_10 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_47 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_37 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_44 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_46 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_28 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_43 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_26 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_42 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_13 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_5 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_28 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_29 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_13 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_19 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_44 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_39 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_34 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_45 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_47 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_28 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_44 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_25 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_49 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_14 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_19 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_4 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_39 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_29 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_48 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_35 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_16 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_14 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_6 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_17 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_10 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_38 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_41 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_35 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_34 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_31 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_12 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_18 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_15 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_41 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_33 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_16 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_41 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_39 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_47 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_39 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_31 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_18 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_24 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_39 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_6 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_44 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_2 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_45 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_40 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_23 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_43 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_7 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_3 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_16 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_38 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_49 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_42 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_32 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_25 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_43 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_38 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_26 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_46 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_32 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_7 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_48 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_22 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_12 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_19 !
# 25/09/04 21:14:50 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_40 !
# 25/09/04 21:17:32 ERROR TaskSchedulerImpl: Lost executor 59 on 172.18.0.6: Command exited with code 137
# 25/09/04 21:17:32 WARN TaskSetManager: Lost task 37.0 in stage 135.0 (TID 6109) (172.18.0.6 executor 59): ExecutorLostFailure (executor 59 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:17:32 WARN TaskSetManager: Lost task 40.0 in stage 135.0 (TID 6112) (172.18.0.6 executor 59): ExecutorLostFailure (executor 59 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:17:32 WARN TaskSetManager: Lost task 38.0 in stage 135.0 (TID 6110) (172.18.0.6 executor 59): ExecutorLostFailure (executor 59 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:17:32 WARN TaskSetManager: Lost task 41.0 in stage 135.0 (TID 6113) (172.18.0.6 executor 59): ExecutorLostFailure (executor 59 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:17:32 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_5 !
# 25/09/04 21:17:32 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_4 !
# 25/09/04 21:17:32 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_0 !
# 25/09/04 21:17:32 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_5 !
# 25/09/04 21:17:32 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_2 !
# 25/09/04 21:17:32 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_0 !
# 25/09/04 21:17:32 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_2 !
# 25/09/04 21:17:32 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_4 !
# 25/09/04 21:19:25 ERROR TaskSchedulerImpl: Lost executor 60 on 172.18.0.5: Command exited with code 137
# 25/09/04 21:19:25 WARN TaskSetManager: Lost task 2.1 in stage 135.0 (TID 6139) (172.18.0.5 executor 60): ExecutorLostFailure (executor 60 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:19:25 WARN TaskSetManager: Lost task 1.2 in stage 135.0 (TID 6142) (172.18.0.5 executor 60): ExecutorLostFailure (executor 60 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:19:25 WARN TaskSetManager: Lost task 8.1 in stage 135.0 (TID 6141) (172.18.0.5 executor 60): ExecutorLostFailure (executor 60 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:19:25 WARN TaskSetManager: Lost task 22.1 in stage 135.0 (TID 6135) (172.18.0.5 executor 60): ExecutorLostFailure (executor 60 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:21:55 ERROR TaskSchedulerImpl: Lost executor 61 on 172.18.0.6: Command exited with code 137
# 25/09/04 21:21:55 WARN TaskSetManager: Lost task 43.0 in stage 135.0 (TID 6174) (172.18.0.6 executor 61): ExecutorLostFailure (executor 61 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:21:55 WARN TaskSetManager: Lost task 34.1 in stage 135.0 (TID 6168) (172.18.0.6 executor 61): ExecutorLostFailure (executor 61 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:21:55 WARN TaskSetManager: Lost task 13.2 in stage 135.0 (TID 6170) (172.18.0.6 executor 61): ExecutorLostFailure (executor 61 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:21:55 WARN TaskSetManager: Lost task 26.2 in stage 135.0 (TID 6167) (172.18.0.6 executor 61): ExecutorLostFailure (executor 61 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:22:36 ERROR TaskSchedulerImpl: Lost executor 62 on 172.18.0.5: Command exited with code 137
# 25/09/04 21:22:36 WARN TaskSetManager: Lost task 29.3 in stage 135.0 (TID 6184) (172.18.0.5 executor 62): ExecutorLostFailure (executor 62 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:22:36 WARN TaskSetManager: Lost task 6.2 in stage 135.0 (TID 6183) (172.18.0.5 executor 62): ExecutorLostFailure (executor 62 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:22:36 WARN TaskSetManager: Lost task 22.3 in stage 135.0 (TID 6186) (172.18.0.5 executor 62): ExecutorLostFailure (executor 62 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:22:36 WARN TaskSetManager: Lost task 19.2 in stage 135.0 (TID 6185) (172.18.0.5 executor 62): ExecutorLostFailure (executor 62 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:23:58 ERROR TaskSchedulerImpl: Lost executor 63 on 172.18.0.6: Command exited with code 137
# 25/09/04 21:23:58 WARN TaskSetManager: Lost task 11.3 in stage 135.0 (TID 6202) (172.18.0.6 executor 63): ExecutorLostFailure (executor 63 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:23:58 WARN TaskSetManager: Lost task 15.3 in stage 135.0 (TID 6198) (172.18.0.6 executor 63): ExecutorLostFailure (executor 63 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:23:58 WARN TaskSetManager: Lost task 7.4 in stage 135.0 (TID 6200) (172.18.0.6 executor 63): ExecutorLostFailure (executor 63 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:23:58 WARN TaskSetManager: Lost task 10.3 in stage 135.0 (TID 6199) (172.18.0.6 executor 63): ExecutorLostFailure (executor 63 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:26:25 ERROR TaskSchedulerImpl: Lost executor 64 on 172.18.0.5: Command exited with code 137
# 25/09/04 21:26:25 WARN TaskSetManager: Lost task 3.3 in stage 135.0 (TID 6238) (172.18.0.5 executor 64): ExecutorLostFailure (executor 64 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:26:25 WARN TaskSetManager: Lost task 37.2 in stage 135.0 (TID 6239) (172.18.0.5 executor 64): ExecutorLostFailure (executor 64 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:26:25 WARN TaskSetManager: Lost task 24.2 in stage 135.0 (TID 6233) (172.18.0.5 executor 64): ExecutorLostFailure (executor 64 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:26:25 WARN TaskSetManager: Lost task 28.2 in stage 135.0 (TID 6235) (172.18.0.5 executor 64): ExecutorLostFailure (executor 64 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:28:03 ERROR TaskSchedulerImpl: Lost executor 65 on 172.18.0.6: Command exited with code 137
# 25/09/04 21:28:03 WARN TaskSetManager: Lost task 5.4 in stage 135.0 (TID 6258) (172.18.0.6 executor 65): ExecutorLostFailure (executor 65 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:28:03 WARN TaskSetManager: Lost task 25.4 in stage 135.0 (TID 6252) (172.18.0.6 executor 65): ExecutorLostFailure (executor 65 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:28:03 WARN TaskSetManager: Lost task 34.4 in stage 135.0 (TID 6259) (172.18.0.6 executor 65): ExecutorLostFailure (executor 65 exited caused by one of the running tasks) Reason: Command exited with code 137
# 25/09/04 21:28:03 WARN TaskSetManager: Lost task 17.5 in stage 135.0 (TID 6253) (172.18.0.6 executor 65): ExecutorLostFailure (executor 65 exited caused by one of the running tasks) Reason: Command exited with code 137
# [Stage 135:================================>                    (178 + 8) / 288]

# %% [markdown]
# ## 1. Business Rating Prediction

# %%
# Prepare data for business rating prediction
print("=== BUSINESS RATING PREDICTION ===")

# Aggregate features at business level
business_agg = ml_sample.groupBy("business_id").agg(
    avg("stars").alias("avg_rating"),
    count("review_id").alias("total_reviews"),
    avg("text_length").alias("avg_text_length"),
    sum("useful").alias("total_useful"),
    sum("funny").alias("total_funny"),
    sum("cool").alias("total_cool"),
    stddev("stars").alias("rating_variance")
).fillna(0)

# Join with business features
business_ml = business_agg.join(
    business_features.select("business_id", "review_count", "is_open", "category_count", "is_restaurant"),
    "business_id",
    "inner"
)

# Convert to Pandas for sklearn
business_pd = business_ml.toPandas()

print(f"Business dataset shape: {business_pd.shape}")
business_pd.head()

# %%
# Prepare features and target for business rating prediction
feature_columns = ['total_reviews', 'avg_text_length', 'total_useful', 'total_funny', 'total_cool', 
                   'rating_variance', 'review_count', 'is_open', 'category_count', 'is_restaurant']

# Remove rows with missing values
business_clean = business_pd.dropna(subset=feature_columns + ['avg_rating'])

X_business = business_clean[feature_columns]
y_business = business_clean['avg_rating']

print(f"Clean dataset shape: {X_business.shape}")
print(f"Target range: {y_business.min():.2f} - {y_business.max():.2f}")

# Split the data
X_train_bus, X_test_bus, y_train_bus, y_test_bus = train_test_split(
    X_business, y_business, test_size=0.2, random_state=42
)

# Scale features
scaler_bus = StandardScaler()
X_train_bus_scaled = scaler_bus.fit_transform(X_train_bus)
X_test_bus_scaled = scaler_bus.transform(X_test_bus)

print(f"Training set: {X_train_bus_scaled.shape}")
print(f"Test set: {X_test_bus_scaled.shape}")

# %%
# Train multiple regression models for business rating prediction
models_regression = {
    'Linear Regression': LinearRegression(),
    'Random Forest': RandomForestRegressor(n_estimators=100, random_state=42),
    'Gradient Boosting': GradientBoostingRegressor(n_estimators=100, random_state=42),
    'SVR': SVR(kernel='rbf', C=1.0)
}

results_regression = {}

for name, model in models_regression.items():
    print(f"\nTraining {name}...")
    
    # Train model
    model.fit(X_train_bus_scaled, y_train_bus)
    
    # Make predictions
    y_pred_train = model.predict(X_train_bus_scaled)
    y_pred_test = model.predict(X_test_bus_scaled)
    
    # Calculate metrics
    train_rmse = np.sqrt(mean_squared_error(y_train_bus, y_pred_train))
    test_rmse = np.sqrt(mean_squared_error(y_test_bus, y_pred_test))
    train_r2 = r2_score(y_train_bus, y_pred_train)
    test_r2 = r2_score(y_test_bus, y_pred_test)
    
    results_regression[name] = {
        'Train RMSE': train_rmse,
        'Test RMSE': test_rmse,
        'Train R²': train_r2,
        'Test R²': test_r2,
        'Model': model
    }
    
    print(f"Train RMSE: {train_rmse:.4f}, Test RMSE: {test_rmse:.4f}")
    print(f"Train R²: {train_r2:.4f}, Test R²: {test_r2:.4f}")

# Display results summary
results_df = pd.DataFrame({k: {metric: v[metric] for metric in ['Train RMSE', 'Test RMSE', 'Train R²', 'Test R²']} 
                          for k, v in results_regression.items()}).T
print("\n=== BUSINESS RATING PREDICTION RESULTS ===")
print(results_df.round(4))

# %% [markdown]
# ## 2. Review Sentiment Classification

# %%
# Prepare data for sentiment classification
print("=== REVIEW SENTIMENT CLASSIFICATION ===")

# Create sentiment labels (1-2 stars = negative, 4-5 stars = positive, skip 3 for clear distinction)
sentiment_sample = ml_sample.filter((col("stars") <= 2) | (col("stars") >= 4)) \
                           .withColumn("sentiment", when(col("stars") >= 4, 1).otherwise(0)) \
                           .select("text", "sentiment", "stars", "text_length")

# Sample smaller subset for text processing
text_sample = sentiment_sample.sample(0.2, seed=42).toPandas()

print(f"Sentiment dataset shape: {text_sample.shape}")
print(f"Positive samples: {text_sample['sentiment'].sum()}")
print(f"Negative samples: {len(text_sample) - text_sample['sentiment'].sum()}")

text_sample.head()

# %%
# Text preprocessing and feature extraction
print("Processing text features...")

# Clean text data
text_clean = text_sample.dropna(subset=['text', 'sentiment'])
text_clean = text_clean[text_clean['text'].str.len() > 10]  # Remove very short texts

# Create TF-IDF features
tfidf = TfidfVectorizer(
    max_features=5000,
    stop_words='english',
    ngram_range=(1, 2),
    min_df=2,
    max_df=0.95
)

X_text_tfidf = tfidf.fit_transform(text_clean['text'])
y_text = text_clean['sentiment']

print(f"TF-IDF matrix shape: {X_text_tfidf.shape}")
print(f"Vocabulary size: {len(tfidf.vocabulary_)}")

# Reduce dimensionality for faster processing
svd = TruncatedSVD(n_components=100, random_state=42)
X_text_reduced = svd.fit_transform(X_text_tfidf)

print(f"Reduced feature matrix shape: {X_text_reduced.shape}")
print(f"Explained variance ratio: {svd.explained_variance_ratio_.sum():.3f}")

# %%
# Train sentiment classification models
X_train_text, X_test_text, y_train_text, y_test_text = train_test_split(
    X_text_reduced, y_text, test_size=0.2, random_state=42, stratify=y_text
)

models_classification = {
    'Logistic Regression': LogisticRegression(random_state=42, max_iter=1000),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42),
    'SVM': SVC(kernel='rbf', random_state=42)
}

results_classification = {}

for name, model in models_classification.items():
    print(f"\nTraining {name}...")
    
    # Train model
    model.fit(X_train_text, y_train_text)
    
    # Make predictions
    y_pred_train = model.predict(X_train_text)
    y_pred_test = model.predict(X_test_text)
    
    # Calculate accuracy
    train_acc = (y_pred_train == y_train_text).mean()
    test_acc = (y_pred_test == y_test_text).mean()
    
    results_classification[name] = {
        'Train Accuracy': train_acc,
        'Test Accuracy': test_acc,
        'Model': model,
        'Predictions': y_pred_test
    }
    
    print(f"Train Accuracy: {train_acc:.4f}")
    print(f"Test Accuracy: {test_acc:.4f}")

# Display classification results
class_results_df = pd.DataFrame({k: {metric: v[metric] for metric in ['Train Accuracy', 'Test Accuracy']} 
                                for k, v in results_classification.items()}).T
print("\n=== SENTIMENT CLASSIFICATION RESULTS ===")
print(class_results_df.round(4))

# Show classification report for best model
best_model_name = class_results_df['Test Accuracy'].idxmax()
best_predictions = results_classification[best_model_name]['Predictions']

print(f"\n=== CLASSIFICATION REPORT ({best_model_name}) ===")
print(classification_report(y_test_text, best_predictions, target_names=['Negative', 'Positive']))

# %% [markdown]
# ## 3. Business Success Classification

# %%
# Define business success based on multiple criteria
print("=== BUSINESS SUCCESS CLASSIFICATION ===")

# Create success metric (high rating + many reviews + still open)
business_success = business_features.withColumn(
    "successful", 
    when((col("stars") >= 4.0) & (col("review_count") >= 50) & (col("is_open") == 1), 1)
    .otherwise(0)
)

# Select features for success prediction
success_features = business_success.select(
    "business_id",
    "review_count",
    "is_restaurant",
    "category_count",
    "has_categories",
    "successful"
).fillna(0)

# Convert to pandas
success_pd = success_features.toPandas()

print(f"Business success dataset shape: {success_pd.shape}")
print(f"Successful businesses: {success_pd['successful'].sum()} ({success_pd['successful'].mean()*100:.1f}%)")
print(f"Unsuccessful businesses: {len(success_pd) - success_pd['successful'].sum()} ({(1-success_pd['successful'].mean())*100:.1f}%)")

success_pd.head()

# %%
# Train business success classification model
feature_cols_success = ['review_count', 'is_restaurant', 'category_count', 'has_categories']

X_success = success_pd[feature_cols_success]
y_success = success_pd['successful']

# Split data
X_train_suc, X_test_suc, y_train_suc, y_test_suc = train_test_split(
    X_success, y_success, test_size=0.2, random_state=42, stratify=y_success
)

# Scale features
scaler_suc = StandardScaler()
X_train_suc_scaled = scaler_suc.fit_transform(X_train_suc)
X_test_suc_scaled = scaler_suc.transform(X_test_suc)

# Train classification models
success_models = {
    'Logistic Regression': LogisticRegression(random_state=42),
    'Random Forest': RandomForestClassifier(n_estimators=100, random_state=42),
    'SVM': SVC(kernel='rbf', random_state=42)
}

success_results = {}

for name, model in success_models.items():
    print(f"\nTraining {name} for business success...")
    
    # Train model
    model.fit(X_train_suc_scaled, y_train_suc)
    
    # Make predictions
    y_pred_train_suc = model.predict(X_train_suc_scaled)
    y_pred_test_suc = model.predict(X_test_suc_scaled)
    
    # Calculate accuracy
    train_acc = (y_pred_train_suc == y_train_suc).mean()
    test_acc = (y_pred_test_suc == y_test_suc).mean()
    
    success_results[name] = {
        'Train Accuracy': train_acc,
        'Test Accuracy': test_acc,
        'Model': model,
        'Predictions': y_pred_test_suc
    }
    
    print(f"Train Accuracy: {train_acc:.4f}")
    print(f"Test Accuracy: {test_acc:.4f}")

# Display results
success_results_df = pd.DataFrame({k: {metric: v[metric] for metric in ['Train Accuracy', 'Test Accuracy']} 
                                  for k, v in success_results.items()}).T
print("\n=== BUSINESS SUCCESS CLASSIFICATION RESULTS ===")
print(success_results_df.round(4))

# %% [markdown]
# ## 4. User Clustering Analysis

# %%
# User behavior clustering
print("=== USER CLUSTERING ANALYSIS ===")

# Prepare user features for clustering
user_features = user_df.select(
    "user_id",
    "review_count",
    "useful",
    "funny",
    "cool",
    "fans",
    "average_stars"
).fillna(0)

# Sample for clustering
user_cluster_sample = user_features.sample(0.05, seed=42).toPandas()

print(f"User clustering sample: {user_cluster_sample.shape}")

# Prepare features for clustering
cluster_features = ['review_count', 'useful', 'funny', 'cool', 'fans', 'average_stars']
X_cluster = user_cluster_sample[cluster_features]

# Remove outliers (users with extremely high values)
for col in cluster_features:
    q99 = X_cluster[col].quantile(0.99)
    X_cluster[col] = X_cluster[col].clip(upper=q99)

# Scale features for clustering
scaler_cluster = StandardScaler()
X_cluster_scaled = scaler_cluster.fit_transform(X_cluster)

print(f"Features for clustering: {X_cluster_scaled.shape}")

# %%
# Perform K-means clustering
# Find optimal number of clusters using elbow method
inertias = []
k_range = range(2, 11)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_cluster_scaled)
    inertias.append(kmeans.inertia_)

# Plot elbow curve
plt.figure(figsize=(10, 6))
plt.plot(k_range, inertias, 'bo-')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal k')
plt.grid(True, alpha=0.3)
plt.show()

# Use k=5 based on elbow method
optimal_k = 5
kmeans = KMeans(n_clusters=optimal_k, random_state=42, n_init=10)
cluster_labels = kmeans.fit_predict(X_cluster_scaled)

# Add cluster labels to dataframe
user_cluster_sample['cluster'] = cluster_labels

print(f"\nCluster distribution:")
print(user_cluster_sample['cluster'].value_counts().sort_index())

# %%
# Analyze cluster characteristics
cluster_analysis = user_cluster_sample.groupby('cluster')[cluster_features].mean()

print("=== CLUSTER CHARACTERISTICS ===")
print(cluster_analysis.round(2))

# Visualize clusters
fig, axes = plt.subplots(2, 3, figsize=(18, 12))
axes = axes.ravel()

for i, feature in enumerate(cluster_features):
    for cluster_id in range(optimal_k):
        cluster_data = user_cluster_sample[user_cluster_sample['cluster'] == cluster_id][feature]
        axes[i].hist(cluster_data, alpha=0.7, label=f'Cluster {cluster_id}', bins=20)
    
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Frequency')
    axes[i].set_title(f'Distribution of {feature} by Cluster')
    axes[i].legend()
    axes[i].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# Interpret clusters
print("\n=== CLUSTER INTERPRETATION ===")
cluster_names = {
    0: "Casual Users",
    1: "Active Reviewers", 
    2: "Social Influencers",
    3: "Power Users",
    4: "Elite Critics"
}

for i in range(optimal_k):
    cluster_stats = cluster_analysis.loc[i]
    print(f"\nCluster {i} ({cluster_names.get(i, f'Cluster {i}')}):") 
    print(f"  Avg Reviews: {cluster_stats['review_count']:.1f}")
    print(f"  Avg Rating: {cluster_stats['average_stars']:.2f}")
    print(f"  Fans: {cluster_stats['fans']:.1f}")
    print(f"  Useful Votes: {cluster_stats['useful']:.1f}")

# %% [markdown]
# ## 5. Model Performance Summary

# %%
# Create comprehensive results summary
print("=== MACHINE LEARNING RESULTS SUMMARY ===")

# Business rating prediction summary
print("\n1. BUSINESS RATING PREDICTION:")
print("Task: Predict average business rating from business characteristics")
best_reg_model = results_df['Test R²'].idxmax()
best_reg_r2 = results_df.loc[best_reg_model, 'Test R²']
best_reg_rmse = results_df.loc[best_reg_model, 'Test RMSE']
print(f"Best Model: {best_reg_model} (R² = {best_reg_r2:.4f}, RMSE = {best_reg_rmse:.4f})")

# Sentiment classification summary
print("\n2. REVIEW SENTIMENT CLASSIFICATION:")
print("Task: Classify review sentiment (positive/negative) from text")
best_class_model = class_results_df['Test Accuracy'].idxmax()
best_class_acc = class_results_df.loc[best_class_model, 'Test Accuracy']
print(f"Best Model: {best_class_model} (Accuracy = {best_class_acc:.4f})")

# Business success classification summary
print("\n3. BUSINESS SUCCESS CLASSIFICATION:")
print("Task: Predict business success (high rating + many reviews + open)")
best_success_model = success_results_df['Test Accuracy'].idxmax()
best_success_acc = success_results_df.loc[best_success_model, 'Test Accuracy']
print(f"Best Model: {best_success_model} (Accuracy = {best_success_acc:.4f})")

# Clustering summary
print("\n4. USER CLUSTERING:")
print(f"Task: Segment users based on behavior patterns")
print(f"Clusters Identified: {optimal_k} distinct user segments")
print(f"Sample Size: {len(user_cluster_sample):,} users")

print("\n=== KEY INSIGHTS ===")
print("• Business ratings can be predicted with moderate accuracy from aggregated features")
print("• Text-based sentiment classification achieves good performance on polarized reviews")
print("• Business success can be classified using simple business metrics")
print("• Users show distinct behavioral patterns suitable for targeted recommendations")
print("• Feature engineering and data quality are crucial for model performance")

# %% [markdown]
# ## 6. Feature Importance Analysis

# %%
# Analyze feature importance for best performing models
print("=== FEATURE IMPORTANCE ANALYSIS ===")

# Business rating prediction feature importance
best_reg_model_obj = results_regression[best_reg_model]['Model']
if hasattr(best_reg_model_obj, 'feature_importances_'):
    feature_importance = pd.DataFrame({
        'feature': feature_columns,
        'importance': best_reg_model_obj.feature_importances_
    }).sort_values('importance', ascending=False)
    
    print(f"\nFeature Importance - {best_reg_model} (Business Rating Prediction):")
    print(feature_importance)
    
    # Plot feature importance
    plt.figure(figsize=(10, 6))
    plt.barh(feature_importance['feature'], feature_importance['importance'])
    plt.xlabel('Feature Importance')
    plt.title(f'Feature Importance - {best_reg_model}')
    plt.tight_layout()
    plt.show()

# Business success feature importance
best_success_model_obj = success_results[best_success_model]['Model']
if hasattr(best_success_model_obj, 'feature_importances_'):
    success_importance = pd.DataFrame({
        'feature': feature_cols_success,
        'importance': best_success_model_obj.feature_importances_
    }).sort_values('importance', ascending=False)
    
    print(f"\nFeature Importance - {best_success_model} (Business Success):")
    print(success_importance)
    
    # Plot feature importance
    plt.figure(figsize=(10, 4))
    plt.barh(success_importance['feature'], success_importance['importance'])
    plt.xlabel('Feature Importance')
    plt.title(f'Feature Importance - {best_success_model} (Success Prediction)')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Recommendations and Next Steps
#
# ### Model Performance Insights:
# 1. **Business Rating Prediction**: Models show moderate predictive power, suggesting ratings are influenced by factors beyond basic business metrics
# 2. **Sentiment Classification**: Text-based models perform well on polarized reviews (1-2 vs 4-5 stars)
# 3. **Business Success**: Simple metrics like review count are strong predictors of success
# 4. **User Clustering**: Clear user segments emerge, enabling targeted strategies
#
# ### Recommendations for Improvement:
# 1. **Feature Engineering**: Include temporal features, geographic features, and competitive analysis
# 2. **Text Processing**: Use advanced NLP techniques (BERT, word embeddings) for better sentiment analysis
# 3. **Deep Learning**: Implement neural networks for complex pattern recognition
# 4. **Ensemble Methods**: Combine multiple models for better performance
# 5. **Cross-validation**: Use more robust validation strategies for model selection
#
# ### Business Applications:
# 1. **Restaurant Recommendations**: Use collaborative filtering based on user clusters
# 2. **Business Intelligence**: Predict which businesses are likely to succeed
# 3. **Review Quality**: Automatically flag potentially fake or low-quality reviews
# 4. **Market Analysis**: Identify market gaps and opportunities
# 5. **Customer Segmentation**: Tailor marketing strategies to different user segments
