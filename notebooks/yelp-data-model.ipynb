# %% [markdown]
# # Yelp Dataset Data Model
#
# This notebook explores the structure and relationships of the five Yelp dataset tables:
# - **Business**: Information about businesses (restaurants, shops, etc.)
# - **Reviews**: User reviews of businesses
# - **Users**: User profile information
# - **Tips**: Short tips from users about businesses
# - **Checkins**: Check-in timestamps for businesses

# %% [markdown]
# ## Setup and Data Loading

# %%
# Import required libraries
import json
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
import matplotlib.pyplot as plt
import seaborn as sns

# Load credentials
with open("creds.json", "r") as f:
    creds = json.load(f)
    f.close()

print("Libraries and credentials loaded successfully!")
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Libraries and credentials loaded successfully!

# %% [markdown]
# ## stop spark

# %%
# Stop any existing Spark session
if 'spark' in locals():
    spark.stop()

# %%
# Initialize Spark Session
try:
    spark = SparkSession.builder \
        .appName("YelpDataModel") \
        .master("spark://spark-master:7077") \
        .config("spark.driver.memory", "2g") \
        .config("spark.executor.memory", "2g") \
        .config("spark.executor.cores", "4") \
        .config("spark.worker.memory", "2g") \
        .config("spark.cores.max", "4") \
        .config("spark.hadoop.fs.s3a.access.key", creds["aws_client"]) \
        .config("spark.hadoop.fs.s3a.secret.key", creds["aws_secret"]) \
        .config("spark.jars.packages", 
                "org.apache.hadoop:hadoop-aws:3.3.4," + 
                "org.apache.hadoop:hadoop-common:3.3.4," +
                "com.amazonaws:aws-java-sdk-bundle:1.12.261," +
                "org.apache.logging.log4j:log4j-slf4j-impl:2.17.2," +
                "org.apache.logging.log4j:log4j-api:2.17.2," +
                "org.apache.logging.log4j:log4j-core:2.17.2," + 
                "org.apache.hadoop:hadoop-client:3.3.4," + 
                "io.delta:delta-core_2.12:2.4.0," + 
                "org.postgresql:postgresql:42.2.18") \
        .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem") \
        .config("spark.hadoop.fs.s3a.aws.credentials.provider", "org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider") \
        .config("spark.hadoop.fs.s3a.endpoint", "s3.amazonaws.com") \
        .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
        .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
        .getOrCreate()
    
    print("Spark session initialized successfully!")
    
except Exception as e:
    print(f"Error initializing Spark: {str(e)}")
# Out:
# :: loading settings :: url = jar:file:/usr/local/lib/python3.7/site-packages/pyspark/jars/ivy-2.5.1.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /root/.ivy2/cache
# The jars for the packages stored in: /root/.ivy2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# org.apache.hadoop#hadoop-common added as a dependency
# com.amazonaws#aws-java-sdk-bundle added as a dependency
# org.apache.logging.log4j#log4j-slf4j-impl added as a dependency
# org.apache.logging.log4j#log4j-api added as a dependency
# org.apache.logging.log4j#log4j-core added as a dependency
# org.apache.hadoop#hadoop-client added as a dependency
# io.delta#delta-core_2.12 added as a dependency
# org.postgresql#postgresql added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-3a19c2ad-28f1-4260-a55d-bef755375baf;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.3.4 in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.12.262 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.0.7.Final in central
# 	found org.apache.hadoop#hadoop-common;3.3.4 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_7;1.1.1 in central
# 	found org.apache.hadoop#hadoop-annotations;3.3.4 in central
# 	found org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 in central
# 	found com.google.guava#guava;27.0-jre in central
# 	found com.google.guava#failureaccess;1.0 in central
# 	found com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava in central
# 	found com.google.code.findbugs#jsr305;3.0.2 in central
# 	found org.checkerframework#checker-qual;2.5.2 in central
# 	found com.google.j2objc#j2objc-annotations;1.1 in central
# 	found org.codehaus.mojo#animal-sniffer-annotations;1.17 in central
# 	found commons-cli#commons-cli;1.2 in central
# 	found org.apache.commons#commons-math3;3.1.1 in central
# 	found org.apache.httpcomponents#httpclient;4.5.13 in central
# 	found org.apache.httpcomponents#httpcore;4.4.13 in central
# 	found commons-logging#commons-logging;1.1.3 in central
# 	found commons-codec#commons-codec;1.15 in central
# 	found commons-io#commons-io;2.8.0 in central
# 	found commons-net#commons-net;3.6 in central
# 	found commons-collections#commons-collections;3.2.2 in central
# 	found javax.servlet#javax.servlet-api;3.1.0 in central
# 	found org.eclipse.jetty#jetty-server;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-http;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-io;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-servlet;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-security;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-webapp;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-xml;9.4.43.v20210629 in central
# 	found com.sun.jersey#jersey-core;1.19 in central
# 	found javax.ws.rs#jsr311-api;1.1.1 in central
# 	found com.sun.jersey#jersey-servlet;1.19 in central
# 	found com.sun.jersey#jersey-server;1.19 in central
# 	found com.sun.jersey#jersey-json;1.19 in central
# 	found org.codehaus.jettison#jettison;1.1 in central
# 	found com.sun.xml.bind#jaxb-impl;2.2.3-1 in central
# 	found javax.xml.bind#jaxb-api;2.2.11 in central
# 	found org.codehaus.jackson#jackson-core-asl;1.9.13 in central
# 	found org.codehaus.jackson#jackson-mapper-asl;1.9.13 in central
# 	found org.codehaus.jackson#jackson-jaxrs;1.9.13 in central
# 	found org.codehaus.jackson#jackson-xc;1.9.13 in central
# 	found ch.qos.reload4j#reload4j;1.2.22 in central
# 	found commons-beanutils#commons-beanutils;1.9.4 in central
# 	found org.apache.commons#commons-configuration2;2.1.1 in central
# 	found org.apache.commons#commons-lang3;3.12.0 in central
# 	found org.apache.commons#commons-text;1.4 in central
# 	found org.slf4j#slf4j-api;1.7.36 in central
# 	found org.slf4j#slf4j-reload4j;1.7.36 in central
# 	found org.apache.avro#avro;1.7.7 in central
# 	found com.thoughtworks.paranamer#paranamer;2.3 in central
# 	found org.xerial.snappy#snappy-java;1.1.8.2 in central
# 	found org.apache.commons#commons-compress;1.21 in central
# 	found com.google.re2j#re2j;1.1 in central
# 	found com.google.protobuf#protobuf-java;2.5.0 in central
# 	found com.google.code.gson#gson;2.8.9 in central
# 	found org.apache.hadoop#hadoop-auth;3.3.4 in central
# 	found com.nimbusds#nimbus-jose-jwt;9.8.1 in central
# 	found com.github.stephenc.jcip#jcip-annotations;1.0-1 in central
# 	found net.minidev#json-smart;2.4.7 in central
# 	found net.minidev#accessors-smart;2.4.7 in central
# 	found org.ow2.asm#asm;5.0.4 in central
# 	found org.apache.zookeeper#zookeeper;3.5.6 in central
# 	found org.apache.zookeeper#zookeeper-jute;3.5.6 in central
# 	found org.apache.yetus#audience-annotations;0.5.0 in central
# 	found org.apache.curator#curator-framework;4.2.0 in central
# 	found org.apache.curator#curator-client;4.2.0 in central
# 	found org.apache.kerby#kerb-simplekdc;1.0.1 in central
# 	found org.apache.kerby#kerb-client;1.0.1 in central
# 	found org.apache.kerby#kerby-config;1.0.1 in central
# 	found org.apache.kerby#kerb-core;1.0.1 in central
# 	found org.apache.kerby#kerby-pkix;1.0.1 in central
# 	found org.apache.kerby#kerby-asn1;1.0.1 in central
# 	found org.apache.kerby#kerby-util;1.0.1 in central
# 	found org.apache.kerby#kerb-common;1.0.1 in central
# 	found org.apache.kerby#kerb-crypto;1.0.1 in central
# 	found org.apache.kerby#kerb-util;1.0.1 in central
# 	found org.apache.kerby#token-provider;1.0.1 in central
# 	found org.apache.kerby#kerb-admin;1.0.1 in central
# 	found org.apache.kerby#kerb-server;1.0.1 in central
# 	found org.apache.kerby#kerb-identity;1.0.1 in central
# 	found org.apache.kerby#kerby-xdr;1.0.1 in central
# 	found com.jcraft#jsch;0.1.55 in central
# 	found org.apache.curator#curator-recipes;4.2.0 in central
# 	found com.fasterxml.jackson.core#jackson-databind;2.12.7 in central
# 	found com.fasterxml.jackson.core#jackson-annotations;2.12.7 in central
# 	found com.fasterxml.jackson.core#jackson-core;2.12.7 in central
# 	found org.codehaus.woodstox#stax2-api;4.2.1 in central
# 	found com.fasterxml.woodstox#woodstox-core;5.3.0 in central
# 	found dnsjava#dnsjava;2.1.7 in central
# 	found jakarta.activation#jakarta.activation-api;1.2.1 in central
# 	found javax.servlet.jsp#jsp-api;2.1 in central
# 	found org.apache.logging.log4j#log4j-slf4j-impl;2.17.2 in central
# 	found org.apache.logging.log4j#log4j-core;2.17.2 in central
# 	found org.apache.logging.log4j#log4j-api;2.17.2 in central
# 	found org.apache.hadoop#hadoop-client;3.3.4 in central
# 	found org.apache.hadoop#hadoop-hdfs-client;3.3.4 in central
# 	found org.apache.hadoop#hadoop-yarn-api;3.3.4 in central
# 	found org.apache.hadoop#hadoop-yarn-client;3.3.4 in central
# 	found org.eclipse.jetty.websocket#websocket-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty#jetty-client;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-common;9.4.43.v20210629 in central
# 	found org.eclipse.jetty.websocket#websocket-api;9.4.43.v20210629 in central
# 	found org.jline#jline;3.9.0 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-core;3.3.4 in central
# 	found org.apache.hadoop#hadoop-yarn-common;3.3.4 in central
# 	found com.sun.jersey#jersey-client;1.19 in central
# 	found com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.12.7 in central
# 	found jakarta.xml.bind#jakarta.xml.bind-api;2.3.2 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.12.7 in central
# 	found com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.12.7 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-jobclient;3.3.4 in central
# 	found org.apache.hadoop#hadoop-mapreduce-client-common;3.3.4 in central
# 	found io.delta#delta-core_2.12;2.4.0 in central
# 	found io.delta#delta-storage;2.4.0 in central
# 	found org.antlr#antlr4-runtime;4.9.3 in central
# 	found org.postgresql#postgresql;42.2.18 in central
# 	found org.checkerframework#checker-qual;3.5.0 in central
# :: resolution report :: resolve 1615ms :: artifacts dl 39ms
# 	:: modules in use:
# 	ch.qos.reload4j#reload4j;1.2.22 from central in [default]
# 	com.amazonaws#aws-java-sdk-bundle;1.12.262 from central in [default]
# 	com.fasterxml.jackson.core#jackson-annotations;2.12.7 from central in [default]
# 	com.fasterxml.jackson.core#jackson-core;2.12.7 from central in [default]
# 	com.fasterxml.jackson.core#jackson-databind;2.12.7 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-base;2.12.7 from central in [default]
# 	com.fasterxml.jackson.jaxrs#jackson-jaxrs-json-provider;2.12.7 from central in [default]
# 	com.fasterxml.jackson.module#jackson-module-jaxb-annotations;2.12.7 from central in [default]
# 	com.fasterxml.woodstox#woodstox-core;5.3.0 from central in [default]
# 	com.github.stephenc.jcip#jcip-annotations;1.0-1 from central in [default]
# 	com.google.code.findbugs#jsr305;3.0.2 from central in [default]
# 	com.google.code.gson#gson;2.8.9 from central in [default]
# 	com.google.guava#failureaccess;1.0 from central in [default]
# 	com.google.guava#guava;27.0-jre from central in [default]
# 	com.google.guava#listenablefuture;9999.0-empty-to-avoid-conflict-with-guava from central in [default]
# 	com.google.j2objc#j2objc-annotations;1.1 from central in [default]
# 	com.google.protobuf#protobuf-java;2.5.0 from central in [default]
# 	com.google.re2j#re2j;1.1 from central in [default]
# 	com.jcraft#jsch;0.1.55 from central in [default]
# 	com.nimbusds#nimbus-jose-jwt;9.8.1 from central in [default]
# 	com.sun.jersey#jersey-client;1.19 from central in [default]
# 	com.sun.jersey#jersey-core;1.19 from central in [default]
# 	com.sun.jersey#jersey-json;1.19 from central in [default]
# 	com.sun.jersey#jersey-server;1.19 from central in [default]
# 	com.sun.jersey#jersey-servlet;1.19 from central in [default]
# 	com.sun.xml.bind#jaxb-impl;2.2.3-1 from central in [default]
# 	com.thoughtworks.paranamer#paranamer;2.3 from central in [default]
# 	commons-beanutils#commons-beanutils;1.9.4 from central in [default]
# 	commons-cli#commons-cli;1.2 from central in [default]
# 	commons-codec#commons-codec;1.15 from central in [default]
# 	commons-collections#commons-collections;3.2.2 from central in [default]
# 	commons-io#commons-io;2.8.0 from central in [default]
# 	commons-logging#commons-logging;1.1.3 from central in [default]
# 	commons-net#commons-net;3.6 from central in [default]
# 	dnsjava#dnsjava;2.1.7 from central in [default]
# 	io.delta#delta-core_2.12;2.4.0 from central in [default]
# 	io.delta#delta-storage;2.4.0 from central in [default]
# 	jakarta.activation#jakarta.activation-api;1.2.1 from central in [default]
# 	jakarta.xml.bind#jakarta.xml.bind-api;2.3.2 from central in [default]
# 	javax.servlet#javax.servlet-api;3.1.0 from central in [default]
# 	javax.servlet.jsp#jsp-api;2.1 from central in [default]
# 	javax.ws.rs#jsr311-api;1.1.1 from central in [default]
# 	javax.xml.bind#jaxb-api;2.2.11 from central in [default]
# 	net.minidev#accessors-smart;2.4.7 from central in [default]
# 	net.minidev#json-smart;2.4.7 from central in [default]
# 	org.antlr#antlr4-runtime;4.9.3 from central in [default]
# 	org.apache.avro#avro;1.7.7 from central in [default]
# 	org.apache.commons#commons-compress;1.21 from central in [default]
# 	org.apache.commons#commons-configuration2;2.1.1 from central in [default]
# 	org.apache.commons#commons-lang3;3.12.0 from central in [default]
# 	org.apache.commons#commons-math3;3.1.1 from central in [default]
# 	org.apache.commons#commons-text;1.4 from central in [default]
# 	org.apache.curator#curator-client;4.2.0 from central in [default]
# 	org.apache.curator#curator-framework;4.2.0 from central in [default]
# 	org.apache.curator#curator-recipes;4.2.0 from central in [default]
# 	org.apache.hadoop#hadoop-annotations;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-auth;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-aws;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-client;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-common;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-hdfs-client;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-mapreduce-client-common;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-mapreduce-client-core;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-mapreduce-client-jobclient;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-api;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-client;3.3.4 from central in [default]
# 	org.apache.hadoop#hadoop-yarn-common;3.3.4 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-guava;1.1.1 from central in [default]
# 	org.apache.hadoop.thirdparty#hadoop-shaded-protobuf_3_7;1.1.1 from central in [default]
# 	org.apache.httpcomponents#httpclient;4.5.13 from central in [default]
# 	org.apache.httpcomponents#httpcore;4.4.13 from central in [default]
# 	org.apache.kerby#kerb-admin;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-client;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-common;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-core;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-crypto;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-identity;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-server;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-simplekdc;1.0.1 from central in [default]
# 	org.apache.kerby#kerb-util;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-asn1;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-config;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-pkix;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-util;1.0.1 from central in [default]
# 	org.apache.kerby#kerby-xdr;1.0.1 from central in [default]
# 	org.apache.kerby#token-provider;1.0.1 from central in [default]
# 	org.apache.logging.log4j#log4j-api;2.17.2 from central in [default]
# 	org.apache.logging.log4j#log4j-core;2.17.2 from central in [default]
# 	org.apache.logging.log4j#log4j-slf4j-impl;2.17.2 from central in [default]
# 	org.apache.yetus#audience-annotations;0.5.0 from central in [default]
# 	org.apache.zookeeper#zookeeper;3.5.6 from central in [default]
# 	org.apache.zookeeper#zookeeper-jute;3.5.6 from central in [default]
# 	org.checkerframework#checker-qual;3.5.0 from central in [default]
# 	org.codehaus.jackson#jackson-core-asl;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-jaxrs;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-mapper-asl;1.9.13 from central in [default]
# 	org.codehaus.jackson#jackson-xc;1.9.13 from central in [default]
# 	org.codehaus.jettison#jettison;1.1 from central in [default]
# 	org.codehaus.mojo#animal-sniffer-annotations;1.17 from central in [default]
# 	org.codehaus.woodstox#stax2-api;4.2.1 from central in [default]
# 	org.eclipse.jetty#jetty-client;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-http;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-io;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-security;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-server;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-servlet;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-util;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-util-ajax;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-webapp;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty#jetty-xml;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-api;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-client;9.4.43.v20210629 from central in [default]
# 	org.eclipse.jetty.websocket#websocket-common;9.4.43.v20210629 from central in [default]
# 	org.jline#jline;3.9.0 from central in [default]
# 	org.ow2.asm#asm;5.0.4 from central in [default]
# 	org.postgresql#postgresql;42.2.18 from central in [default]
# 	org.slf4j#slf4j-api;1.7.36 from central in [default]
# 	org.slf4j#slf4j-reload4j;1.7.36 from central in [default]
# 	org.wildfly.openssl#wildfly-openssl;1.0.7.Final from central in [default]
# 	org.xerial.snappy#snappy-java;1.1.8.2 from central in [default]
# 	:: evicted modules:
# 	org.checkerframework#checker-qual;2.5.2 by [org.checkerframework#checker-qual;3.5.0] in [default]
# 	com.amazonaws#aws-java-sdk-bundle;1.12.261 by [com.amazonaws#aws-java-sdk-bundle;1.12.262] in [default]
# 	org.slf4j#slf4j-api;1.7.25 by [org.slf4j#slf4j-api;1.7.36] in [default]
# 	---------------------------------------------------------------------
# 	|                  |            modules            ||   artifacts   |
# 	|       conf       | number| search|dwnlded|evicted|| number|dwnlded|
# 	---------------------------------------------------------------------
# 	|      default     |  123  |   0   |   0   |   3   ||  120  |   0   |
# 	---------------------------------------------------------------------
# :: retrieving :: org.apache.spark#spark-submit-parent-3a19c2ad-28f1-4260-a55d-bef755375baf
# 	confs: [default]
# 	0 artifacts copied, 120 already retrieved (0kB/21ms)
# 25/09/02 21:59:34 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/09/02 21:59:36 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/09/02 21:59:36 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# /usr/local/lib/python3.7/site-packages/pyspark/context.py:317: FutureWarning: Python 3.7 support is deprecated in Spark 3.4.
#   warnings.warn("Python 3.7 support is deprecated in Spark 3.4.", FutureWarning)
# Spark session initialized successfully!

# %%
# Load data from Delta tables
def read_delta(path: str):
    """Read a Delta table from S3 path"""
    try:
        df = spark.read \
            .format("delta") \
            .option("inferSchema", "true") \
            .load(path)
            
        print(f"Successfully read delta table from: {path}")
        print(f"Number of rows: {df.count():,}")
        return df
        
    except Exception as e:
        print(f"Error reading delta table from {path}")
        print(f"Error: {str(e)}")
        return None

# Load all tables
bucket = "yelp-stevenhurwitt-2"

business_df = read_delta(f"s3a://{bucket}/business")
review_df = read_delta(f"s3a://{bucket}/reviews")
user_df = read_delta(f"s3a://{bucket}/users")
checkin_df = read_delta(f"s3a://{bucket}/checkins")
tip_df = read_delta(f"s3a://{bucket}/tips")
# Out:
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/business
# 25/09/02 22:01:38 WARN package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Number of rows: 150,346
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/reviews
# Number of rows: 6,990,280
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/users
# Number of rows: 1,987,897
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/checkins
# Number of rows: 131,930
# Successfully read delta table from: s3a://yelp-stevenhurwitt-2/tips
# Number of rows: 908,915

# %% [markdown]
# ## Table Schemas and Structure

# %% [markdown]
# ### 1. Business Table
#
# Contains information about businesses including restaurants, shops, services, etc.

# %%
print("=== BUSINESS TABLE SCHEMA ===")
business_df.printSchema()

print("\n=== BUSINESS SAMPLE DATA ===")
business_df.show(3, truncate=False)

print(f"\nTotal Businesses: {business_df.count():,}")
print(f"Columns: {len(business_df.columns)}")
# Out:
# === BUSINESS TABLE SCHEMA ===
# root
#  |-- business_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- review_count: integer (nullable = true)
#  |-- is_open: integer (nullable = true)
#  |-- attributes: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: string (valueContainsNull = true)
#  |-- categories: string (nullable = true)
#  |-- hours: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: string (valueContainsNull = true)
#
#
# === BUSINESS SAMPLE DATA ===
# +----------------------+-----------------------------+----------------------+------------+-----+-----------+----------+-----------+-----+------------+-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------+
# |business_id           |name                         |address               |city        |state|postal_code|latitude  |longitude  |stars|review_count|is_open|attributes                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |categories                                                       |hours                                                                                                                                        |
# +----------------------+-----------------------------+----------------------+------------+-----+-----------+----------+-----------+-----+------------+-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------+
# |lwItZ1Ck3KtpCgG4CPFmpQ|Stomel Elliot Attorney-At-Law|532 Rte 70 W, Fl 2    |Cherry Hill |NJ   |08002      |39.915478 |-75.016973 |5.0  |5           |1      |null                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |DUI Law, Professional Services, Lawyers, Criminal Defense Law    |{Monday -> 0:0-0:0, Tuesday -> 0:0-0:0, Wednesday -> 0:0-0:0, Thursday -> 0:0-0:0, Friday -> 0:0-0:0, Saturday -> 0:0-0:0, Sunday -> 0:0-0:0}|
# |8rb-3VYXE37IZix4yOdskw|Sharky's Sports Bar & Grill  |820 N Black Horse Pike|Williamstown|NJ   |08094      |39.6968014|-74.9998214|2.5  |29          |1      |{Alcohol -> u'full_bar', RestaurantsGoodForGroups -> True, BikeParking -> True, NoiseLevel -> u'average', RestaurantsAttire -> u'casual', BusinessAcceptsCreditCards -> True, GoodForKids -> False, HasTV -> True, RestaurantsTakeOut -> True, RestaurantsDelivery -> False, RestaurantsPriceRange2 -> 1, WiFi -> 'free', RestaurantsReservations -> False, OutdoorSeating -> False, BusinessParking -> {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}, Caters -> False, Ambience -> {'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': True, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}}|American (Traditional), Bars, Nightlife, Sports Bars, Restaurants|null                                                                                                                                         |
# |NZ_bFJma7brQUfln5h1UAg|Super Sushi Kyo Hin          |2501 Mt Holly Rd 245  |Burlington  |NJ   |08016      |40.0416285|-74.8258209|3.5  |6           |0      |{RestaurantsReservations -> True, RestaurantsAttire -> u'casual', HasTV -> False, RestaurantsTakeOut -> True, BusinessParking -> {'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}, RestaurantsDelivery -> False, GoodForKids -> True, Ambience -> {'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': False}, RestaurantsPriceRange2 -> 2, RestaurantsGoodForGroups -> True, OutdoorSeating -> False, NoiseLevel -> u'quiet', BusinessAcceptsCreditCards -> True}                                                                                |Restaurants, Japanese, Sushi Bars, Asian Fusion                  |null                                                                                                                                         |
# +----------------------+-----------------------------+----------------------+------------+-----+-----------+----------+-----------+-----+------------+-------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+-----------------------------------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 3 rows
#
#
# Total Businesses: 150,346
# Columns: 14

# %% [markdown]
# ### 2. Review Table
#
# Contains user reviews for businesses with ratings, text, and metadata.

# %%
print("=== REVIEW TABLE SCHEMA ===")
review_df.printSchema()

print("\n=== REVIEW SAMPLE DATA ===")
review_df.select("review_id", "user_id", "business_id", "stars", "date", "useful", "funny", "cool").show(3, truncate=False)

print(f"\nTotal Reviews: {review_df.count():,}")
print(f"Columns: {len(review_df.columns)}")
# Out:
# === REVIEW TABLE SCHEMA ===
# root
#  |-- review_id: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- stars: float (nullable = true)
#  |-- useful: integer (nullable = true)
#  |-- funny: integer (nullable = true)
#  |-- cool: integer (nullable = true)
#  |-- text: string (nullable = true)
#  |-- date: timestamp (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#
#
# === REVIEW SAMPLE DATA ===
# +----------------------+----------------------+----------------------+-----+-------------------+------+-----+----+
# |review_id             |user_id               |business_id           |stars|date               |useful|funny|cool|
# +----------------------+----------------------+----------------------+-----+-------------------+------+-----+----+
# |gSBCrfXhCSEoSbH0o72u_w|BI4lPhrUpmEySIJUywjIjQ|Aes-0Q_guDeYewMapFs_vg|3.0  |2005-11-11 06:29:59|0     |1    |0   |
# |2Gm9_x5b2sQGSVy8HWweAQ|F4cbJPyoF1nd3S7Rqz72vw|TBmbB10qaTgw4s14wqjliQ|5.0  |2005-11-11 03:23:18|0     |0    |0   |
# |G7ZpIMCu12HLlAeIeZJ4tg|uSxeEUPMW1nUJr-5jHYt6Q|RGVyb36fh2M2BTTUYxURLg|4.0  |2005-11-14 01:22:56|0     |0    |0   |
# +----------------------+----------------------+----------------------+-----+-------------------+------+-----+----+
# only showing top 3 rows
#
#
# Total Reviews: 6,990,280
# Columns: 11

# %% [markdown]
# ### 3. User Table
#
# Contains user profile information and statistics.

# %%
print("=== USER TABLE SCHEMA ===")
user_df.printSchema()

print("\n=== USER SAMPLE DATA ===")
user_df.select("user_id", "name", "review_count", "yelping_since", "useful", "funny", "cool", "fans", "average_stars").show(3, truncate=False)

print(f"\nTotal Users: {user_df.count():,}")
print(f"Columns: {len(user_df.columns)}")
# Out:
# === USER TABLE SCHEMA ===
# root
#  |-- user_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- review_count: integer (nullable = true)
#  |-- yelping_since: timestamp (nullable = true)
#  |-- friends: string (nullable = true)
#  |-- useful: integer (nullable = true)
#  |-- funny: integer (nullable = true)
#  |-- cool: integer (nullable = true)
#  |-- fans: integer (nullable = true)
#  |-- elite: string (nullable = true)
#  |-- average_stars: float (nullable = true)
#  |-- compliment_hot: integer (nullable = true)
#  |-- compliment_more: integer (nullable = true)
#  |-- compliment_profile: integer (nullable = true)
#  |-- compliment_cute: integer (nullable = true)
#  |-- compliment_list: integer (nullable = true)
#  |-- compliment_note: integer (nullable = true)
#  |-- compliment_plain: integer (nullable = true)
#  |-- compliment_cool: integer (nullable = true)
#  |-- compliment_funny: integer (nullable = true)
#  |-- compliment_writer: integer (nullable = true)
#  |-- compliment_photos: integer (nullable = true)
#
#
# === USER SAMPLE DATA ===
# +----------------------+---------+------------+-------------------+------+-----+----+----+-------------+
# |user_id               |name     |review_count|yelping_since      |useful|funny|cool|fans|average_stars|
# +----------------------+---------+------------+-------------------+------+-----+----+----+-------------+
# |XACigsMQP4VYX970eML8XQ|Al       |3           |2019-06-30 19:07:49|1     |0    |0   |0   |2.25         |
# |f7bENcNzAPWTCTfpqWxHeg|Kacey    |41          |2013-10-28 19:17:12|48    |8    |2   |0   |3.27         |
# |mg0pSgLvuiXKqLsd_uLadQ|Magdaline|114         |2008-09-29 23:51:09|90    |21   |12  |1   |3.5          |
# +----------------------+---------+------------+-------------------+------+-----+----+----+-------------+
# only showing top 3 rows
#
#
# Total Users: 1,987,897
# Columns: 22

# %% [markdown]
# ### 4. Tip Table
#
# Contains short tips/advice from users about businesses.

# %%
print("=== TIP TABLE SCHEMA ===")
tip_df.printSchema()

print("\n=== TIP SAMPLE DATA ===")
tip_df.show(5, truncate=False)

print(f"\nTotal Tips: {tip_df.count():,}")
print(f"Columns: {len(tip_df.columns)}")
# Out:
# === TIP TABLE SCHEMA ===
# root
#  |-- user_id: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- text: string (nullable = true)
#  |-- date: timestamp (nullable = true)
#  |-- compliment_count: integer (nullable = true)
#  |-- year: integer (nullable = true)
#
#
# === TIP SAMPLE DATA ===
# +----------------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------+-------------------+----------------+----+
# |user_id               |business_id           |text                                                                                                                              |date               |compliment_count|year|
# +----------------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------+-------------------+----------------+----+
# |veuUOGS0bbOeQzu71gVxEQ|aurSXIlX86Ob94kYvSSDPw|Awesome                                                                                                                           |2021-01-01 23:19:41|0               |2021|
# |JfAqGalRYKo3Byw735-eOw|mP9dVul2VKgVIs_kZlPAqw|SO quick and easy for a dryer vent cleaning--and a very reasonable price--thank you!                                              |2021-01-21 03:03:02|0               |2021|
# |ojvZZ_ZWRlfJDJN_kV1ESQ|J7-mw216H21rjz-E71wX-A|Love Kenny's flowers - beautiful arrangements.                                                                                    |2021-01-25 03:52:12|0               |2021|
# |77xznhdIIfltTaY5jPTVfQ|m3NH0HumRCp4ARx8RBD7IQ|Must try the cheesesteak egg rolls with the beer cheese dip that comes with the pretzel nuggets. Amazing combo and wont disappoint|2021-02-15 18:51:36|0               |2021|
# |lvthTfCQGD0qaEk6jCdRdQ|ruXD0lB3rq4FMvnQL7iqLw|They have a touch tank.                                                                                                           |2021-02-15 20:18:45|0               |2021|
# +----------------------+----------------------+----------------------------------------------------------------------------------------------------------------------------------+-------------------+----------------+----+
# only showing top 5 rows
#
#
# Total Tips: 908,915
# Columns: 6

# %% [markdown]
# ### 5. Checkin Table
#
# Contains check-in timestamps for businesses.

# %%
print("=== CHECKIN TABLE SCHEMA ===")
checkin_df.printSchema()

print("\n=== CHECKIN SAMPLE DATA ===")
checkin_df.show(5, truncate=False)

print(f"\nTotal Checkin Records: {checkin_df.count():,}")
print(f"Columns: {len(checkin_df.columns)}")
# Out:
# === CHECKIN TABLE SCHEMA ===
# root
#  |-- business_id: string (nullable = true)
#  |-- date: string (nullable = true)
#
#
# === CHECKIN SAMPLE DATA ===
# +----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |business_id           |date                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# +----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |k9-r1j1VeWY1BLS0IBku8w|2011-10-02 14:21:03, 2011-10-07 21:23:49, 2011-12-19 23:52:38, 2012-02-08 21:21:39, 2012-02-09 18:15:41, 2012-02-13 21:17:51, 2012-03-10 06:28:45, 2012-03-10 13:03:46, 2012-03-13 17:46:48, 2012-04-11 13:26:22, 2012-05-28 18:51:14, 2012-05-31 18:38:14, 2012-08-20 22:20:08, 2012-10-01 20:09:49, 2013-12-03 16:26:47, 2013-12-03 16:27:14, 2014-01-31 21:19:11, 2016-06-25 18:38:09, 2016-12-14 00:31:32, 2017-04-12 16:57:22                                                                                                         |
# |k91vKZa8oDHGFEumLyI-KQ|2012-05-05 23:00:04, 2012-07-22 23:39:34, 2013-01-07 20:16:00, 2013-06-24 17:51:13, 2013-07-07 22:45:24, 2013-07-31 22:42:56, 2013-09-26 21:54:25, 2013-10-05 18:23:29, 2014-05-10 17:19:44, 2014-07-02 13:31:55, 2014-08-04 16:44:57, 2015-02-01 14:35:57, 2015-10-12 14:32:16, 2016-06-20 19:12:00, 2016-09-24 14:10:22, 2017-08-07 16:02:56, 2018-10-05 20:34:27, 2018-10-17 14:59:26, 2020-02-11 13:28:42, 2021-07-27 12:42:44                                                                                                         |
# |k920l7wHSjLZDJLvn-UfyQ|2016-05-07 18:28:17, 2016-05-14 15:42:24, 2016-05-14 15:45:33, 2016-05-21 21:14:28, 2016-05-24 22:59:02, 2016-06-03 23:23:16, 2016-06-12 14:51:03, 2016-06-12 14:53:04, 2016-06-21 02:02:20, 2016-06-25 12:13:55, 2016-07-27 16:38:33, 2016-07-29 14:25:01, 2016-08-02 16:59:51, 2016-08-28 13:22:17, 2016-09-11 18:05:09, 2016-11-04 13:01:06, 2016-11-23 22:16:54, 2017-02-25 17:26:57, 2017-04-18 20:57:49, 2017-05-09 19:01:19, 2017-06-17 19:31:13, 2017-06-24 16:49:04, 2017-07-03 13:36:11, 2017-08-12 20:22:16, 2017-08-18 14:45:48|
# |k93U5RS4ohNqk9912QcyOw|2013-09-21 17:45:33, 2014-06-05 16:58:28, 2015-07-09 20:08:04, 2015-07-24 15:10:38, 2016-04-16 16:28:45, 2016-05-20 19:41:10, 2016-11-26 20:51:49, 2016-12-23 22:02:09, 2017-01-14 19:04:52, 2018-01-05 23:44:17, 2018-01-28 17:07:59, 2018-08-19 17:58:16, 2018-09-21 18:01:28, 2018-11-28 20:07:27, 2019-04-05 14:37:41, 2020-09-04 22:13:48, 2020-09-06 16:50:37                                                                                                                                                                        |
# |k94QZmoxe9RwUgwu1ZWi-w|2016-05-27 14:21:38, 2016-08-25 21:59:38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# +----------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows
#
#
# Total Checkin Records: 131,930
# Columns: 2

# %% [markdown]
# ## Entity Relationship Diagram (ERD)
#
# The Yelp dataset follows this relationship structure:
#
# ```
# ┌─────────────────┐    ┌─────────────────┐
# │     BUSINESS    │    │      USERS      │
# │                 │    │                 │
# │ • business_id   │    │ • user_id       │
# │ • name          │    │ • name          │
# │ • address       │    │ • review_count  │
# │ • city          │    │ • yelping_since │
# │ • state         │    │ • useful        │
# │ • postal_code   │    │ • funny         │
# │ • latitude      │    │ • cool          │
# │ • longitude     │    │ • fans          │
# │ • stars         │    │ • average_stars │
# │ • review_count  │    │ • elite         │
# │ • is_open       │    │ • friends       │
# │ • attributes    │    │ • compliments   │
# │ • categories    │    └─────────────────┘
# │ • hours         │              │
# └─────────────────┘              │
#          │                       │
#          │                       │
#     ┌────▼───────────────────────▼────┐
#     │          REVIEWS               │
#     │                               │
#     │ • review_id                   │
#     │ • user_id     (FK)            │
#     │ • business_id (FK)            │
#     │ • stars                       │
#     │ • useful                      │
#     │ • funny                       │
#     │ • cool                        │
#     │ • text                        │
#     │ • date                        │
#     └───────────────────────────────┘
#          │                       │
#          │                       │
#     ┌────▼─────────┐       ┌─────▼──────┐
#     │   CHECKINS   │       │    TIPS    │
#     │              │       │            │
#     │ • business_id│       │ • user_id  │
#     │   (FK)       │       │   (FK)     │
#     │ • date       │       │ • business_│
#     │              │       │   id (FK)  │
#     └──────────────┘       │ • text     │
#                            │ • date     │
#                            │ • complim. │
#                            │   _count   │
#                            └────────────┘
# ```

# %% [markdown]
# ## Key Relationships and Constraints

# %%
# Analyze key relationships
print("=== KEY RELATIONSHIP ANALYSIS ===")

# 1. Business-Review relationship
businesses_with_reviews = business_df.join(review_df, "business_id", "inner").select("business_id").distinct().count()
total_businesses = business_df.count()
print(f"Businesses with reviews: {businesses_with_reviews:,} out of {total_businesses:,} ({businesses_with_reviews/total_businesses*100:.1f}%)")

# 2. User-Review relationship
users_with_reviews = user_df.join(review_df, "user_id", "inner").select("user_id").distinct().count()
total_users = user_df.count()
print(f"Users with reviews: {users_with_reviews:,} out of {total_users:,} ({users_with_reviews/total_users*100:.1f}%)")

# 3. Business-Checkin relationship
businesses_with_checkins = business_df.join(checkin_df, "business_id", "inner").select("business_id").distinct().count()
print(f"Businesses with checkins: {businesses_with_checkins:,} out of {total_businesses:,} ({businesses_with_checkins/total_businesses*100:.1f}%)")

# 4. Business-Tip relationship
businesses_with_tips = business_df.join(tip_df, "business_id", "inner").select("business_id").distinct().count()
print(f"Businesses with tips: {businesses_with_tips:,} out of {total_businesses:,} ({businesses_with_tips/total_businesses*100:.1f}%)")

# 5. User-Tip relationship
users_with_tips = user_df.join(tip_df, "user_id", "inner").select("user_id").distinct().count()
print(f"Users with tips: {users_with_tips:,} out of {total_users:,} ({users_with_tips/total_users*100:.1f}%)")
# Out:
# === KEY RELATIONSHIP ANALYSIS ===
# 25/09/02 22:29:36 ERROR TaskSchedulerImpl: Lost executor 0 on 172.18.0.5: worker lost
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_12 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_12 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_12 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_12 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_12 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_12 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_48 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_13 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_12 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_17 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_25 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_40 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_30 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_29 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_10 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_47 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_37 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_12 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_28 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_19 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_5 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_1 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_9 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_14 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_34 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_35 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_7 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_36 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_12 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_8 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_18 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_15 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_41 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_33 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_21 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_45 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_6 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_39 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_2 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_11 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_43 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_23 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_16 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_49 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_42 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_32 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_38 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_26 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_27 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_20 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_46 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_0 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_3 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_4 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_31 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_44 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_24 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_22 !
# 25/09/02 22:29:36 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_12 !
# Businesses with reviews: 150,346 out of 150,346 (100.0%)
# Users with reviews: 1,987,897 out of 1,987,897 (100.0%)
# Businesses with checkins: 131,930 out of 150,346 (87.8%)
# Businesses with tips: 106,193 out of 150,346 (70.6%)
# [Stage 166:>                                                        (0 + 4) / 4]
# Users with tips: 301,758 out of 1,987,897 (15.2%)

# %% [markdown]
# ## Data Quality and Distribution Analysis

# %%
# Data quality analysis
print("=== DATA QUALITY ANALYSIS ===")

# Check for null values in key columns
tables = {
    'Business': business_df,
    'Reviews': review_df,
    'Users': user_df,
    'Tips': tip_df,
    'Checkins': checkin_df
}

for table_name, df in tables.items():
    print(f"\n{table_name.upper()} TABLE:")
    total_rows = df.count()
    
    # Check null values for each column
    for col_name in df.columns[:5]:  # Check first 5 columns to keep output manageable
        null_count = df.filter(col(col_name).isNull()).count()
        null_percentage = (null_count / total_rows) * 100
        print(f"  {col_name}: {null_count:,} nulls ({null_percentage:.1f}%)")
# Out:
# === DATA QUALITY ANALYSIS ===
#
# BUSINESS TABLE:
#   business_id: 0 nulls (0.0%)
#   name: 0 nulls (0.0%)
#   address: 0 nulls (0.0%)
#   city: 0 nulls (0.0%)
#   state: 0 nulls (0.0%)
#
# REVIEWS TABLE:
#   review_id: 0 nulls (0.0%)
#   user_id: 0 nulls (0.0%)
#   business_id: 0 nulls (0.0%)
#   stars: 0 nulls (0.0%)
#   useful: 0 nulls (0.0%)
#
# USERS TABLE:
#   user_id: 0 nulls (0.0%)
#   name: 0 nulls (0.0%)
#   review_count: 0 nulls (0.0%)
#   yelping_since: 0 nulls (0.0%)
#   friends: 0 nulls (0.0%)
#
# TIPS TABLE:
#   user_id: 0 nulls (0.0%)
#   business_id: 0 nulls (0.0%)
#   text: 0 nulls (0.0%)
#   date: 0 nulls (0.0%)
#   compliment_count: 0 nulls (0.0%)
#
# CHECKINS TABLE:
#   business_id: 0 nulls (0.0%)
#   date: 0 nulls (0.0%)

# %%
# Distribution analysis
print("=== DATA DISTRIBUTION ANALYSIS ===")

# Business star ratings distribution
print("\nBusiness Star Ratings Distribution:")
business_df.groupBy("stars").count().orderBy("stars").show()

# Review star ratings distribution
print("\nReview Star Ratings Distribution:")
review_df.groupBy("stars").count().orderBy("stars").show()

# Top states by business count
print("\nTop 10 States by Business Count:")
business_df.groupBy("state").count().orderBy(desc("count")).show(10)

# Business categories (top 10)
print("\nBusiness Status (Open vs Closed):")
business_df.groupBy("is_open").count().show()
# Out:
# === DATA DISTRIBUTION ANALYSIS ===
#
# Business Star Ratings Distribution:
# +-----+-----+
# |stars|count|
# +-----+-----+
# |  1.0| 1986|
# |  1.5| 4932|
# |  2.0| 9527|
# |  2.5|14316|
# |  3.0|18453|
# |  3.5|26519|
# |  4.0|31125|
# |  4.5|27181|
# |  5.0|16307|
# +-----+-----+
#
#
# Review Star Ratings Distribution:
# +-----+-------+
# |stars|  count|
# +-----+-------+
# |  1.0|1069561|
# |  2.0| 544240|
# |  3.0| 691934|
# |  4.0|1452918|
# |  5.0|3231627|
# +-----+-------+
#
#
# Top 10 States by Business Count:
# +-----+-----+
# |state|count|
# +-----+-----+
# |   PA|34039|
# |   FL|26330|
# |   TN|12056|
# |   IN|11247|
# |   MO|10913|
# |   LA| 9924|
# |   AZ| 9912|
# |   NJ| 8536|
# |   NV| 7715|
# |   AB| 5573|
# +-----+-----+
# only showing top 10 rows
#
#
# Business Status (Open vs Closed):
# [Stage 301:==============>                                          (1 + 3) / 4]
# +-------+------+
# |is_open| count|
# +-------+------+
# |      1|119698|
# |      0| 30648|
# +-------+------+

# %% [markdown]
# ## Primary and Foreign Key Analysis

# %%
# Primary key uniqueness check
print("=== PRIMARY KEY UNIQUENESS CHECK ===")

# Business table
business_total = business_df.count()
business_unique = business_df.select("business_id").distinct().count()
print(f"Business table: {business_total:,} total rows, {business_unique:,} unique business_ids ({'✓' if business_total == business_unique else '✗'})")

# Users table
users_total = user_df.count()
users_unique = user_df.select("user_id").distinct().count()
print(f"Users table: {users_total:,} total rows, {users_unique:,} unique user_ids ({'✓' if users_total == users_unique else '✗'})")

# Reviews table
reviews_total = review_df.count()
reviews_unique = review_df.select("review_id").distinct().count()
print(f"Reviews table: {reviews_total:,} total rows, {reviews_unique:,} unique review_ids ({'✓' if reviews_total == reviews_unique else '✗'})")

print("\n=== FOREIGN KEY INTEGRITY CHECK ===")

# Check if all review business_ids exist in business table
review_business_ids = review_df.select("business_id").distinct()
valid_review_businesses = review_business_ids.join(business_df.select("business_id"), "business_id", "inner").count()
total_review_businesses = review_business_ids.count()
print(f"Review business_id integrity: {valid_review_businesses:,}/{total_review_businesses:,} ({'✓' if valid_review_businesses == total_review_businesses else '✗'})")

# Check if all review user_ids exist in users table
review_user_ids = review_df.select("user_id").distinct()
valid_review_users = review_user_ids.join(user_df.select("user_id"), "user_id", "inner").count()
total_review_users = review_user_ids.count()
print(f"Review user_id integrity: {valid_review_users:,}/{total_review_users:,} ({'✓' if valid_review_users == total_review_users else '✗'})")

# Check tips foreign key integrity
tip_business_ids = tip_df.select("business_id").distinct()
valid_tip_businesses = tip_business_ids.join(business_df.select("business_id"), "business_id", "inner").count()
total_tip_businesses = tip_business_ids.count()
print(f"Tip business_id integrity: {valid_tip_businesses:,}/{total_tip_businesses:,} ({'✓' if valid_tip_businesses == total_tip_businesses else '✗'})")

# Check checkins foreign key integrity
checkin_business_ids = checkin_df.select("business_id").distinct()
valid_checkin_businesses = checkin_business_ids.join(business_df.select("business_id"), "business_id", "inner").count()
total_checkin_businesses = checkin_business_ids.count()
print(f"Checkin business_id integrity: {valid_checkin_businesses:,}/{total_checkin_businesses:,} ({'✓' if valid_checkin_businesses == total_checkin_businesses else '✗'})")
# Out:
# === PRIMARY KEY UNIQUENESS CHECK ===
# Business table: 150,346 total rows, 150,346 unique business_ids (✓)
# Users table: 1,987,897 total rows, 1,987,897 unique user_ids (✓)
# Reviews table: 6,990,280 total rows, 6,990,280 unique review_ids (✓)
#
# === FOREIGN KEY INTEGRITY CHECK ===
# Review business_id integrity: 150,346/150,346 (✓)
# Review user_id integrity: 1,987,897/1,987,929 (✗)
# Tip business_id integrity: 106,193/106,193 (✓)
# Checkin business_id integrity: 131,930/131,930 (✓)

# %% [markdown]
# ## Table Statistics Summary

# %%
# Create a comprehensive summary table
summary_data = []

tables_info = [
    ('Business', business_df, 'business_id', 'Contains business information (restaurants, shops, services)'),
    ('Reviews', review_df, 'review_id', 'User reviews with ratings and text content'),
    ('Users', user_df, 'user_id', 'User profiles and statistics'),
    ('Tips', tip_df, None, 'Short tips/advice about businesses'),
    ('Checkins', checkin_df, None, 'Business check-in timestamps')
]

for table_name, df, pk, description in tables_info:
    row_count = df.count()
    col_count = len(df.columns)
    summary_data.append({
        'Table': table_name,
        'Rows': f"{row_count:,}",
        'Columns': col_count,
        'Primary Key': pk if pk else 'Composite',
        'Description': description
    })

# Create and display summary DataFrame
summary_df = pd.DataFrame(summary_data)
print("=== YELP DATASET SUMMARY ===")
print(summary_df.to_string(index=False))

# Calculate total storage estimates
total_rows = sum([business_df.count(), review_df.count(), user_df.count(), tip_df.count(), checkin_df.count()])
print(f"\nTotal Records Across All Tables: {total_rows:,}")
print(f"Average Records per Table: {total_rows/5:,.0f}")
# Out:
# === YELP DATASET SUMMARY ===
#    Table      Rows  Columns Primary Key                                                  Description
# Business   150,346       14 business_id Contains business information (restaurants, shops, services)
#  Reviews 6,990,280       11   review_id                   User reviews with ratings and text content
#    Users 1,987,897       22     user_id                                 User profiles and statistics
#     Tips   908,915        6   Composite                           Short tips/advice about businesses
# Checkins   131,930        2   Composite                                 Business check-in timestamps
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3415/1075777780.py in <module>
#      27
#      28 # Calculate total storage estimates
# ---> 29 total_rows = sum([business_df.count(), review_df.count(), user_df.count(), tip_df.count(), checkin_df.count()])
#      30 print(f"\nTotal Records Across All Tables: {total_rows:,}")
#      31 print(f"Average Records per Table: {total_rows/5:,.0f}")
#
# /usr/local/lib/python3.7/site-packages/pyspark/sql/utils.py in wrapped(*args, **kwargs)
#     158             return getattr(functions, f.__name__)(*args, **kwargs)
#     159         else:
# --> 160             return f(*args, **kwargs)
#     161
#     162     return cast(FuncT, wrapped)
#
# /usr/local/lib/python3.7/site-packages/pyspark/sql/functions.py in sum(col)
#     629     +-------+
#     630     """
# --> 631     return _invoke_function_over_columns("sum", col)
#     632
#     633
#
# /usr/local/lib/python3.7/site-packages/pyspark/sql/functions.py in _invoke_function_over_columns(name, *cols)
#     101     and wraps the result with :class:`~pyspark.sql.Column`.
#     102     """
# --> 103     return _invoke_function(name, *(_to_java_column(col) for col in cols))
#     104
#     105
#
# /usr/local/lib/python3.7/site-packages/pyspark/sql/functions.py in <genexpr>(.0)
#     101     and wraps the result with :class:`~pyspark.sql.Column`.
#     102     """
# --> 103     return _invoke_function(name, *(_to_java_column(col) for col in cols))
#     104
#     105
#
# /usr/local/lib/python3.7/site-packages/pyspark/sql/column.py in _to_java_column(col)
#      67             "{0} of type {1}. "
#      68             "For column literals, use 'lit', 'array', 'struct' or 'create_map' "
# ---> 69             "function.".format(col, type(col))
#      70         )
#      71     return jcol
#
# TypeError: Invalid argument, not a string or column: [150346, 6990280, 1987897, 908915, 131930] of type <class 'list'>. For column literals, use 'lit', 'array', 'struct' or 'create_map' function.
# 25/09/03 21:03:37 ERROR TaskSchedulerImpl: Lost executor 2 on 172.18.0.6: Command exited with code 137
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_12 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_12 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_12 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_12 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_12 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_12 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_48 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_13 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_12 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_17 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_25 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_30 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_40 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_29 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_10 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_47 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_37 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_12 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_28 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_19 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_5 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_1 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_9 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_14 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_34 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_35 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_7 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_36 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_12 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_8 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_18 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_15 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_41 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_33 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_21 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_45 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_6 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_39 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_2 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_90_11 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_42_43 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_23 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_16 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_38_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_49 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_42 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_32 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_18_38 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_26 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_27 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_20 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_66_46 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_0 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_3 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_86_4 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_31 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_110_44 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_114_24 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_14_22 !
# 25/09/03 21:03:37 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_62_12 !
# 25/09/04 00:50:55 ERROR StandaloneSchedulerBackend: Application has been killed. Reason: Master removed our application: KILLED
# 25/09/04 00:50:55 ERROR StandaloneSchedulerBackend: Application has been killed. Reason: Master removed our application: KILLED
# 25/09/04 00:50:55 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exiting due to error from cluster scheduler: Master removed our application: KILLED
# 	at org.apache.spark.errors.SparkCoreErrors$.clusterSchedulerError(SparkCoreErrors.scala:291)
# 	at org.apache.spark.scheduler.TaskSchedulerImpl.error(TaskSchedulerImpl.scala:978)
# 	at org.apache.spark.scheduler.cluster.StandaloneSchedulerBackend.dead(StandaloneSchedulerBackend.scala:165)
# 	at org.apache.spark.deploy.client.StandaloneAppClient$ClientEndpoint.markDead(StandaloneAppClient.scala:263)
# 	at org.apache.spark.deploy.client.StandaloneAppClient$ClientEndpoint$$anonfun$receive$1.applyOrElse(StandaloneAppClient.scala:170)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:115)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)
# 25/09/04 00:50:55 ERROR Inbox: Ignoring error
# org.apache.spark.SparkException: Exiting due to error from cluster scheduler: Master removed our application: KILLED
# 	at org.apache.spark.errors.SparkCoreErrors$.clusterSchedulerError(SparkCoreErrors.scala:291)
# 	at org.apache.spark.scheduler.TaskSchedulerImpl.error(TaskSchedulerImpl.scala:978)
# 	at org.apache.spark.scheduler.cluster.StandaloneSchedulerBackend.dead(StandaloneSchedulerBackend.scala:165)
# 	at org.apache.spark.deploy.client.StandaloneAppClient$ClientEndpoint.markDead(StandaloneAppClient.scala:263)
# 	at org.apache.spark.deploy.client.StandaloneAppClient$ClientEndpoint$$anonfun$receive$1.applyOrElse(StandaloneAppClient.scala:170)
# 	at org.apache.spark.rpc.netty.Inbox.$anonfun$process$1(Inbox.scala:115)
# 	at org.apache.spark.rpc.netty.Inbox.safelyCall(Inbox.scala:213)
# 	at org.apache.spark.rpc.netty.Inbox.process(Inbox.scala:100)
# 	at org.apache.spark.rpc.netty.MessageLoop.org$apache$spark$rpc$netty$MessageLoop$$receiveLoop(MessageLoop.scala:75)
# 	at org.apache.spark.rpc.netty.MessageLoop$$anon$1.run(MessageLoop.scala:41)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1128)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:628)
# 	at java.base/java.lang.Thread.run(Thread.java:829)

# %% [markdown]
# ## Data Model Insights
#
# ### Key Observations:
#
# 1. **Central Entities**: Business and Users are the core entities, with Reviews connecting them
# 2. **Relationship Patterns**:
#    - One-to-Many: Business → Reviews, Users → Reviews
#    - Many-to-Many: Business ↔ Users (through Reviews and Tips)
# 3. **Data Completeness**: Most tables maintain good referential integrity
# 4. **Scale**: The dataset represents a comprehensive view of business-customer interactions
#
# ### Recommended Indexes for PostgreSQL:
# - `business(business_id)` - Primary key
# - `users(user_id)` - Primary key
# - `reviews(business_id, user_id)` - Foreign key indexes
# - `business(state, city)` - Geographic queries
# - `reviews(date)` - Temporal queries
# - `business(categories)` - Category-based searches
