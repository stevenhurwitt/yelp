# %% [markdown]
# # yelp data ingestion
#
# see example: https://github.com/polakowo/yelp-3nf

# %%
from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.sql import Window, Row

import pprint
import boto3
import json
import os

pp = pprint.PrettyPrinter(indent = 3)
print('imported modules.')
# Out:
# imported modules.

# %% [markdown]
# ## connect to s3

# %%
client = boto3.client('s3')

bucket_meta = client.list_objects(Bucket = 'yelp-dataset-stevenhurwitt')
print('files in s3 bucket:')
print('')
for c in bucket_meta['Contents']:
    print(c['Key'])
# Out:
# files in s3 bucket:
#
# raw/
# raw/yelp_academic_dataset_business.json
# raw/yelp_academic_dataset_checkin.json
# raw/yelp_academic_dataset_review.json
# raw/yelp_academic_dataset_tip.json
# raw/yelp_academic_dataset_user.json

# %% [markdown]
# ## function to read json from s3

# %%
def read_json(filename):
    """
    reads a yelp .json file from s3 bucket.

    keyword arguments:
    filename - name of file (str)

    returns: json_file (json)
    """

    bucket = "yelp-dataset-stevenhurwitt"
    print(f"bucket: {bucket}.")
    print(f"filename: {filename}.")
    
    response = client.get_object(Bucket = bucket, Key = filename)
    file_content = response['Body'].read().decode('utf-8')
    json_file = json.loads("[" + file_content.replace("}\n{", "},\n{") + "]")
    return(json_file)

# %%
my_file = read_json('raw/yelp_academic_dataset_business.json')
my_file
# Out:
# bucket: yelp-dataset-stevenhurwitt.
# filename: raw/yelp_academic_dataset_business.json.
# [{'business_id': 'Pns2l4eNsfO8kk83dixA6A',
#   'name': 'Abby Rappoport, LAC, CMQ',
#   'address': '1616 Chapala St, Ste 2',
#   'city': 'Santa Barbara',
#   'state': 'CA',
#   'postal_code': '93101',
#   'latitude': 34.4266787,
#   'longitude': -119.7111968,
#   'stars': 5.0,
#   'review_count': 7,
#   'is_open': 0,
#   'attributes': {'ByAppointmentOnly': 'True'},
#   'categories': 'Doctors, Traditional Chinese Medicine, Naturopathic/Holistic, Acupuncture, Health & Medical, Nutritionists',
#   'hours': None},
#  {'business_id': 'mpf3x-BjTdTEA3yCZrAYPw',
#   'name': 'The UPS Store',
#   'address': '87 Grasso Plaza Shopping Center',
#   'city': 'Affton',
#   'state': 'MO',
#   'postal_code': '63123',
#   'latitude': 38.551126,
#   'longitude': -90.335695,
#   'stars': 3.0,
#   'review_count': 15,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True'},
#   'categories': 'Shipping Centers, Local Services, Notaries, Mailbox Centers, Printing Services',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '8:0-18:30',
#    'Wednesday': '8:0-18:30',
#    'Thursday': '8:0-18:30',
#    'Friday': '8:0-18:30',
#    'Saturday': '8:0-14:0'}},
#  {'business_id': 'tUFrWirKiKi_TAnsVWINQQ',
#   'name': 'Target',
#   'address': '5255 E Broadway Blvd',
#   'city': 'Tucson',
#   'state': 'AZ',
#   'postal_code': '85711',
#   'latitude': 32.223236,
#   'longitude': -110.880452,
#   'stars': 3.5,
#   'review_count': 22,
#   'is_open': 0,
#   'attributes': {'BikeParking': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'CoatCheck': 'False',
#    'RestaurantsTakeOut': 'False',
#    'RestaurantsDelivery': 'False',
#    'Caters': 'False',
#    'WiFi': "u'no'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'WheelchairAccessible': 'True',
#    'HappyHour': 'False',
#    'OutdoorSeating': 'False',
#    'HasTV': 'False',
#    'RestaurantsReservations': 'False',
#    'DogsAllowed': 'False',
#    'ByAppointmentOnly': 'False'},
#   'categories': 'Department Stores, Shopping, Fashion, Home & Garden, Electronics, Furniture Stores',
#   'hours': {'Monday': '8:0-22:0',
#    'Tuesday': '8:0-22:0',
#    'Wednesday': '8:0-22:0',
#    'Thursday': '8:0-22:0',
#    'Friday': '8:0-23:0',
#    'Saturday': '8:0-23:0',
#    'Sunday': '8:0-22:0'}},
#  {'business_id': 'MTSW4McQd7CbVtyjqoe9mw',
#   'name': 'St Honore Pastries',
#   'address': '935 Race St',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19107',
#   'latitude': 39.9555052,
#   'longitude': -75.1555641,
#   'stars': 4.0,
#   'review_count': 80,
#   'is_open': 1,
#   'attributes': {'RestaurantsDelivery': 'False',
#    'OutdoorSeating': 'False',
#    'BusinessAcceptsCreditCards': 'False',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#    'BikeParking': 'True',
#    'RestaurantsPriceRange2': '1',
#    'RestaurantsTakeOut': 'True',
#    'ByAppointmentOnly': 'False',
#    'WiFi': "u'free'",
#    'Alcohol': "u'none'",
#    'Caters': 'True'},
#   'categories': 'Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries',
#   'hours': {'Monday': '7:0-20:0',
#    'Tuesday': '7:0-20:0',
#    'Wednesday': '7:0-20:0',
#    'Thursday': '7:0-20:0',
#    'Friday': '7:0-21:0',
#    'Saturday': '7:0-21:0',
#    'Sunday': '7:0-21:0'}},
#  {'business_id': 'mWMc6_wTdE0EUBKIGXDVfA',
#   'name': 'Perkiomen Valley Brewery',
#   'address': '101 Walnut St',
#   'city': 'Green Lane',
#   'state': 'PA',
#   'postal_code': '18054',
#   'latitude': 40.3381827,
#   'longitude': -75.4716585,
#   'stars': 4.5,
#   'review_count': 13,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'WheelchairAccessible': 'True',
#    'RestaurantsTakeOut': 'True',
#    'BusinessParking': "{'garage': None, 'street': None, 'validated': None, 'lot': True, 'valet': False}",
#    'BikeParking': 'True',
#    'GoodForKids': 'True',
#    'Caters': 'False'},
#   'categories': 'Brewpubs, Breweries, Food',
#   'hours': {'Wednesday': '14:0-22:0',
#    'Thursday': '16:0-22:0',
#    'Friday': '12:0-22:0',
#    'Saturday': '12:0-22:0',
#    'Sunday': '12:0-18:0'}},
#  {'business_id': 'CF33F8-E6oudUQ46HnavjQ',
#   'name': 'Sonic Drive-In',
#   'address': '615 S Main St',
#   'city': 'Ashland City',
#   'state': 'TN',
#   'postal_code': '37015',
#   'latitude': 36.269593,
#   'longitude': -87.058943,
#   'stars': 2.0,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'BusinessParking': 'None',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'OutdoorSeating': 'True',
#    'RestaurantsReservations': 'False',
#    'Caters': 'False',
#    'RestaurantsTakeOut': 'True',
#    'Alcohol': "u'none'",
#    'Ambience': 'None',
#    'GoodForKids': 'True',
#    'RestaurantsPriceRange2': '1',
#    'ByAppointmentOnly': 'False',
#    'CoatCheck': 'False',
#    'DogsAllowed': 'False',
#    'RestaurantsTableService': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsDelivery': 'True',
#    'WiFi': "u'no'",
#    'WheelchairAccessible': 'True',
#    'HasTV': 'True',
#    'HappyHour': 'False',
#    'DriveThru': 'True',
#    'BikeParking': 'False'},
#   'categories': 'Burgers, Fast Food, Sandwiches, Food, Ice Cream & Frozen Yogurt, Restaurants',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '6:0-22:0',
#    'Wednesday': '6:0-22:0',
#    'Thursday': '6:0-22:0',
#    'Friday': '9:0-0:0',
#    'Saturday': '9:0-22:0',
#    'Sunday': '8:0-22:0'}},
#  {'business_id': 'n_0UpQx1hsNbnPUSlodU8w',
#   'name': 'Famous Footwear',
#   'address': '8522 Eager Road, Dierbergs Brentwood Point',
#   'city': 'Brentwood',
#   'state': 'MO',
#   'postal_code': '63144',
#   'latitude': 38.627695,
#   'longitude': -90.340465,
#   'stars': 2.5,
#   'review_count': 13,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}"},
#   'categories': 'Sporting Goods, Fashion, Shoe Stores, Shopping, Sports Wear, Accessories',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '10:0-18:0',
#    'Wednesday': '10:0-18:0',
#    'Thursday': '10:0-18:0',
#    'Friday': '10:0-18:0',
#    'Saturday': '10:0-18:0',
#    'Sunday': '12:0-18:0'}},
#  {'business_id': 'qkRM_2X51Yqxk3btlwAQIg',
#   'name': 'Temple Beth-El',
#   'address': '400 Pasadena Ave S',
#   'city': 'St. Petersburg',
#   'state': 'FL',
#   'postal_code': '33707',
#   'latitude': 27.76659,
#   'longitude': -82.732983,
#   'stars': 3.5,
#   'review_count': 5,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'Synagogues, Religious Organizations',
#   'hours': {'Monday': '9:0-17:0',
#    'Tuesday': '9:0-17:0',
#    'Wednesday': '9:0-17:0',
#    'Thursday': '9:0-17:0',
#    'Friday': '9:0-17:0'}},
#  {'business_id': 'k0hlBqXX-Bt0vf1op7Jr1w',
#   'name': "Tsevi's Pub And Grill",
#   'address': '8025 Mackenzie Rd',
#   'city': 'Affton',
#   'state': 'MO',
#   'postal_code': '63123',
#   'latitude': 38.5651648,
#   'longitude': -90.3210868,
#   'stars': 3.0,
#   'review_count': 19,
#   'is_open': 0,
#   'attributes': {'Caters': 'True',
#    'Alcohol': "u'full_bar'",
#    'RestaurantsAttire': "u'casual'",
#    'RestaurantsDelivery': 'False',
#    'RestaurantsTakeOut': 'True',
#    'HasTV': 'True',
#    'NoiseLevel': "u'average'",
#    'BusinessAcceptsCreditCards': 'True',
#    'OutdoorSeating': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': False}",
#    'RestaurantsPriceRange2': '1',
#    'GoodForKids': 'True',
#    'WiFi': "u'free'",
#    'RestaurantsReservations': 'False',
#    'RestaurantsGoodForGroups': 'True'},
#   'categories': 'Pubs, Restaurants, Italian, Bars, American (Traditional), Nightlife, Greek',
#   'hours': None},
#  {'business_id': 'bBDDEgkFA1Otx9Lfe7BZUQ',
#   'name': 'Sonic Drive-In',
#   'address': '2312 Dickerson Pike',
#   'city': 'Nashville',
#   'state': 'TN',
#   'postal_code': '37207',
#   'latitude': 36.2081024,
#   'longitude': -86.7681696,
#   'stars': 1.5,
#   'review_count': 10,
#   'is_open': 1,
#   'attributes': {'RestaurantsAttire': "'casual'",
#    'RestaurantsGoodForGroups': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'OutdoorSeating': 'True',
#    'GoodForKids': 'True',
#    'Alcohol': "u'none'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'DogsAllowed': 'False',
#    'RestaurantsTableService': 'False',
#    'ByAppointmentOnly': 'False',
#    'WiFi': "u'no'",
#    'RestaurantsPriceRange2': '1',
#    'RestaurantsReservations': 'False',
#    'HasTV': 'True',
#    'RestaurantsDelivery': 'True',
#    'CoatCheck': 'False',
#    'Caters': 'False',
#    'RestaurantsTakeOut': 'True',
#    'DriveThru': 'True',
#    'HappyHour': 'False',
#    'WheelchairAccessible': 'True'},
#   'categories': 'Ice Cream & Frozen Yogurt, Fast Food, Burgers, Restaurants, Food',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '6:0-21:0',
#    'Wednesday': '6:0-21:0',
#    'Thursday': '6:0-16:0',
#    'Friday': '6:0-16:0',
#    'Saturday': '6:0-17:0',
#    'Sunday': '6:0-21:0'}},
#  {'business_id': 'UJsufbvfyfONHeWdvAHKjA',
#   'name': 'Marshalls',
#   'address': '21705 Village Lakes Sc Dr',
#   'city': "Land O' Lakes",
#   'state': 'FL',
#   'postal_code': '34639',
#   'latitude': 28.1904587953,
#   'longitude': -82.4573802199,
#   'stars': 3.5,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'RestaurantsPriceRange2': '2',
#    'BikeParking': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"},
#   'categories': 'Department Stores, Shopping, Fashion',
#   'hours': {'Monday': '9:30-21:30',
#    'Tuesday': '9:30-21:30',
#    'Wednesday': '9:30-21:30',
#    'Thursday': '9:30-21:30',
#    'Friday': '9:30-21:30',
#    'Saturday': '9:30-21:30',
#    'Sunday': '10:0-20:0'}},
#  {'business_id': 'eEOYSgkmpB90uNA7lDOMRA',
#   'name': 'Vietnamese Food Truck',
#   'address': '',
#   'city': 'Tampa Bay',
#   'state': 'FL',
#   'postal_code': '33602',
#   'latitude': 27.9552692,
#   'longitude': -82.4563199,
#   'stars': 4.0,
#   'review_count': 10,
#   'is_open': 1,
#   'attributes': {'Alcohol': "'none'",
#    'OutdoorSeating': 'None',
#    'RestaurantsReservations': 'False',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': False}",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"},
#   'categories': 'Vietnamese, Food, Restaurants, Food Trucks',
#   'hours': {'Monday': '11:0-14:0',
#    'Tuesday': '11:0-14:0',
#    'Wednesday': '11:0-14:0',
#    'Thursday': '11:0-14:0',
#    'Friday': '11:0-14:0',
#    'Saturday': '5:0-10:0',
#    'Sunday': '15:0-18:0'}},
#  {'business_id': 'il_Ro8jwPlHresjw9EGmBg',
#   'name': "Denny's",
#   'address': '8901 US 31 S',
#   'city': 'Indianapolis',
#   'state': 'IN',
#   'postal_code': '46227',
#   'latitude': 39.6371332838,
#   'longitude': -86.127217412,
#   'stars': 2.5,
#   'review_count': 28,
#   'is_open': 1,
#   'attributes': {'RestaurantsReservations': 'False',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsAttire': "'casual'",
#    'GoodForKids': 'True',
#    'BikeParking': 'False',
#    'RestaurantsPriceRange2': '1',
#    'BusinessAcceptsCreditCards': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}",
#    'RestaurantsGoodForGroups': 'True',
#    'OutdoorSeating': 'False',
#    'WiFi': "u'no'",
#    'Alcohol': "'none'",
#    'RestaurantsDelivery': 'True',
#    'BusinessParking': "{'garage': None, 'street': False, 'validated': None, 'lot': True, 'valet': False}",
#    'HasTV': 'True',
#    'Ambience': "{'touristy': None, 'hipster': None, 'romantic': False, 'divey': None, 'intimate': None, 'trendy': None, 'upscale': None, 'classy': None, 'casual': True}"},
#   'categories': 'American (Traditional), Restaurants, Diners, Breakfast & Brunch',
#   'hours': {'Monday': '6:0-22:0',
#    'Tuesday': '6:0-22:0',
#    'Wednesday': '6:0-22:0',
#    'Thursday': '6:0-22:0',
#    'Friday': '6:0-22:0',
#    'Saturday': '6:0-22:0',
#    'Sunday': '6:0-22:0'}},
#  {'business_id': 'jaxMSoInw8Poo3XeMJt8lQ',
#   'name': 'Adams Dental',
#   'address': '15 N Missouri Ave',
#   'city': 'Clearwater',
#   'state': 'FL',
#   'postal_code': '33755',
#   'latitude': 27.966235,
#   'longitude': -82.787412,
#   'stars': 5.0,
#   'review_count': 10,
#   'is_open': 1,
#   'attributes': {'ByAppointmentOnly': 'True'},
#   'categories': 'General Dentistry, Dentists, Health & Medical, Cosmetic Dentists',
#   'hours': {'Monday': '7:30-15:30',
#    'Tuesday': '7:30-15:30',
#    'Wednesday': '7:30-15:30',
#    'Thursday': '7:30-15:30'}},
#  {'business_id': '0bPLkL0QhhPO5kt1_EXmNQ',
#   'name': "Zio's Italian Market",
#   'address': '2575 E Bay Dr',
#   'city': 'Largo',
#   'state': 'FL',
#   'postal_code': '33771',
#   'latitude': 27.9161159,
#   'longitude': -82.7604608,
#   'stars': 4.5,
#   'review_count': 100,
#   'is_open': 0,
#   'attributes': {'OutdoorSeating': 'False',
#    'RestaurantsGoodForGroups': 'False',
#    'WiFi': "u'no'",
#    'RestaurantsPriceRange2': '1',
#    'RestaurantsDelivery': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsTakeOut': 'True',
#    'Caters': 'True',
#    'NoiseLevel': "u'average'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'GoodForKids': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BikeParking': 'True',
#    'RestaurantsTableService': 'False',
#    'Alcohol': "u'none'",
#    'RestaurantsReservations': 'False',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': False, 'breakfast': False}",
#    'HasTV': 'True',
#    'WheelchairAccessible': 'True'},
#   'categories': 'Food, Delis, Italian, Bakeries, Restaurants',
#   'hours': {'Monday': '10:0-18:0',
#    'Tuesday': '10:0-20:0',
#    'Wednesday': '10:0-20:0',
#    'Thursday': '10:0-20:0',
#    'Friday': '10:0-20:0',
#    'Saturday': '10:0-20:0'}},
#  {'business_id': 'MUTTqe8uqyMdBl186RmNeA',
#   'name': 'Tuna Bar',
#   'address': '205 Race St',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19106',
#   'latitude': 39.953949,
#   'longitude': -75.1432262,
#   'stars': 4.0,
#   'review_count': 245,
#   'is_open': 1,
#   'attributes': {'RestaurantsReservations': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsAttire': "'casual'",
#    'BusinessAcceptsCreditCards': 'True',
#    'WiFi': "'free'",
#    'HasTV': 'False',
#    'RestaurantsTakeOut': 'True',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': False}",
#    'GoodForKids': 'False',
#    'GoodForMeal': "{'dessert': True, 'latenight': None, 'lunch': None, 'dinner': True, 'brunch': None, 'breakfast': None}",
#    'NoiseLevel': "u'average'",
#    'RestaurantsPriceRange2': '2',
#    'Alcohol': "'full_bar'",
#    'DogsAllowed': 'False',
#    'HappyHour': 'True',
#    'RestaurantsDelivery': 'True',
#    'WheelchairAccessible': 'True',
#    'OutdoorSeating': 'True',
#    'RestaurantsTableService': 'True',
#    'BusinessParking': "{u'valet': False, u'garage': None, u'street': True, u'lot': False, u'validated': None}"},
#   'categories': 'Sushi Bars, Restaurants, Japanese',
#   'hours': {'Tuesday': '13:30-22:0',
#    'Wednesday': '13:30-22:0',
#    'Thursday': '13:30-22:0',
#    'Friday': '13:30-23:0',
#    'Saturday': '13:30-23:0',
#    'Sunday': '13:30-22:0'}},
#  {'business_id': 'rBmpy_Y1UbBx8ggHlyb7hA',
#   'name': 'Arizona Truck Outfitters',
#   'address': '625 N Stone Ave',
#   'city': 'Tucson',
#   'state': 'AZ',
#   'postal_code': '85705',
#   'latitude': 32.2298719,
#   'longitude': -110.9723419,
#   'stars': 4.5,
#   'review_count': 10,
#   'is_open': 1,
#   'attributes': {'DriveThru': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'WiFi': "u'free'",
#    'ByAppointmentOnly': 'False'},
#   'categories': 'Automotive, Auto Parts & Supplies, Auto Customization',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '8:0-17:0',
#    'Wednesday': '8:0-17:0',
#    'Thursday': '8:0-17:0',
#    'Friday': '8:0-17:0',
#    'Saturday': '8:0-14:0',
#    'Sunday': '0:0-0:0'}},
#  {'business_id': 'M0XSSHqrASOnhgbWDJIpQA',
#   'name': 'Herb Import Co',
#   'address': '712 Adams St',
#   'city': 'New Orleans',
#   'state': 'LA',
#   'postal_code': '70118',
#   'latitude': 29.9414679565,
#   'longitude': -90.129952757,
#   'stars': 4.0,
#   'review_count': 5,
#   'is_open': 1,
#   'attributes': {'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'BikeParking': 'True'},
#   'categories': 'Vape Shops, Tobacco Shops, Personal Shopping, Vitamins & Supplements, Shopping',
#   'hours': {'Monday': '10:0-19:0',
#    'Tuesday': '10:0-19:0',
#    'Wednesday': '10:0-19:0',
#    'Thursday': '10:0-19:0',
#    'Friday': '10:0-19:0',
#    'Saturday': '10:0-19:0',
#    'Sunday': '10:0-19:0'}},
#  {'business_id': '8wGISYjYkE2tSqn3cDMu8A',
#   'name': 'Nifty Car Rental',
#   'address': '1241 Airline Dr',
#   'city': 'Kenner',
#   'state': 'LA',
#   'postal_code': '70062',
#   'latitude': 29.981183,
#   'longitude': -90.2540123,
#   'stars': 3.5,
#   'review_count': 14,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'Automotive, Car Rental, Hotels & Travel, Truck Rental',
#   'hours': {'Monday': '8:0-17:0',
#    'Tuesday': '8:0-17:0',
#    'Wednesday': '8:0-17:0',
#    'Thursday': '8:0-17:0',
#    'Friday': '8:0-17:0',
#    'Saturday': '9:0-15:0',
#    'Sunday': '9:0-12:0'}},
#  {'business_id': 'ROeacJQwBeh05Rqg7F6TCg',
#   'name': 'BAP',
#   'address': '1224 South St',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19147',
#   'latitude': 39.943223,
#   'longitude': -75.162568,
#   'stars': 4.5,
#   'review_count': 205,
#   'is_open': 1,
#   'attributes': {'NoiseLevel': "u'quiet'",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'RestaurantsGoodForGroups': 'False',
#    'RestaurantsTableService': 'True',
#    'WiFi': "u'no'",
#    'GoodForKids': 'True',
#    'Alcohol': "u'none'",
#    'RestaurantsPriceRange2': '1',
#    'RestaurantsAttire': "u'casual'",
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#    'Caters': 'True',
#    'RestaurantsReservations': 'False',
#    'HasTV': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'OutdoorSeating': 'None',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': None, 'trendy': False, 'upscale': False, 'classy': False, 'casual': True}",
#    'RestaurantsDelivery': 'None',
#    'RestaurantsTakeOut': 'True'},
#   'categories': 'Korean, Restaurants',
#   'hours': {'Monday': '11:30-20:30',
#    'Tuesday': '11:30-20:30',
#    'Wednesday': '11:30-20:30',
#    'Thursday': '11:30-20:30',
#    'Friday': '11:30-20:30',
#    'Saturday': '11:30-20:30'}},
#  {'business_id': 'WKMJwqnfZKsAae75RMP6jA',
#   'name': 'Roast Coffeehouse and Wine Bar',
#   'address': '10359 104 Street NW',
#   'city': 'Edmonton',
#   'state': 'AB',
#   'postal_code': 'T5J 1B9',
#   'latitude': 53.5460453,
#   'longitude': -113.4991693,
#   'stars': 4.0,
#   'review_count': 40,
#   'is_open': 0,
#   'attributes': {'OutdoorSeating': 'False',
#    'Caters': 'True',
#    'RestaurantsDelivery': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsPriceRange2': '2',
#    'RestaurantsReservations': 'False',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#    'HasTV': 'False',
#    'GoodForKids': 'False',
#    'RestaurantsTakeOut': 'True',
#    'WiFi': "u'free'",
#    'NoiseLevel': "u'average'",
#    'RestaurantsAttire': "u'casual'",
#    'Alcohol': "u'beer_and_wine'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': True, 'touristy': False, 'trendy': True, 'upscale': False, 'casual': False}"},
#   'categories': 'Coffee & Tea, Food, Cafes, Bars, Wine Bars, Restaurants, Nightlife',
#   'hours': {'Monday': '8:0-18:0',
#    'Tuesday': '8:0-18:0',
#    'Wednesday': '8:0-18:0',
#    'Thursday': '8:0-18:0',
#    'Friday': '8:0-18:0',
#    'Saturday': '8:0-18:0',
#    'Sunday': '10:0-17:0'}},
#  {'business_id': 'qhDdDeI3K4jy2KyzwFN53w',
#   'name': 'Barnes & Noble Booksellers',
#   'address': '8675 River Crossing Blvd',
#   'city': 'Indianapolis',
#   'state': 'IN',
#   'postal_code': '46240',
#   'latitude': 39.91382,
#   'longitude': -86.105739,
#   'stars': 4.0,
#   'review_count': 38,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BikeParking': 'False'},
#   'categories': 'Shopping, Books, Mags, Music & Video, Bookstores',
#   'hours': {'Monday': '10:0-21:0',
#    'Tuesday': '10:0-21:0',
#    'Wednesday': '10:0-21:0',
#    'Thursday': '10:0-21:0',
#    'Friday': '10:0-21:0',
#    'Saturday': '10:0-21:0',
#    'Sunday': '11:0-19:0'}},
#  {'business_id': 'kfNv-JZpuN6TVNSO6hHdkw',
#   'name': 'Hibachi Express',
#   'address': '6625 E 82nd St',
#   'city': 'Indianapolis',
#   'state': 'IN',
#   'postal_code': '46250',
#   'latitude': 39.9043203184,
#   'longitude': -86.0530799,
#   'stars': 4.0,
#   'review_count': 20,
#   'is_open': 1,
#   'attributes': {'RestaurantsDelivery': 'True',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsPriceRange2': '2'},
#   'categories': 'Steakhouses, Asian Fusion, Restaurants',
#   'hours': {'Monday': '11:0-21:0',
#    'Tuesday': '11:0-21:0',
#    'Wednesday': '11:0-21:0',
#    'Thursday': '11:0-21:0',
#    'Friday': '11:0-21:0',
#    'Saturday': '11:0-21:0'}},
#  {'business_id': '9OG5YkX1g2GReZM0AskizA',
#   'name': "Romano's Macaroni Grill",
#   'address': '5505 S Virginia St',
#   'city': 'Reno',
#   'state': 'NV',
#   'postal_code': '89502',
#   'latitude': 39.4761165,
#   'longitude': -119.7893392,
#   'stars': 2.5,
#   'review_count': 339,
#   'is_open': 1,
#   'attributes': {'RestaurantsGoodForGroups': 'True',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsAttire': "'casual'",
#    'NoiseLevel': "u'average'",
#    'OutdoorSeating': 'True',
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'RestaurantsPriceRange2': '2',
#    'Caters': 'True',
#    'GoodForKids': 'True',
#    'RestaurantsReservations': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'Alcohol': "'full_bar'",
#    'GoodForMeal': "{'dessert': None, 'latenight': False, 'lunch': True, 'dinner': True, 'brunch': None, 'breakfast': False}",
#    'RestaurantsTableService': 'True',
#    'HappyHour': 'True',
#    'WiFi': "u'free'",
#    'DogsAllowed': 'False',
#    'Ambience': "{u'divey': False, u'hipster': False, u'casual': True, u'touristy': False, u'trendy': False, u'intimate': False, u'romantic': None, u'classy': None, u'upscale': False}",
#    'RestaurantsDelivery': 'True',
#    'HasTV': 'True'},
#   'categories': 'Restaurants, Italian',
#   'hours': {'Monday': '11:0-22:0',
#    'Tuesday': '11:0-22:0',
#    'Wednesday': '10:0-22:0',
#    'Thursday': '11:0-20:0',
#    'Friday': '11:0-21:0',
#    'Saturday': '12:0-21:0',
#    'Sunday': '11:0-21:0'}},
#  {'business_id': '4iRzR7OaS-QaSXuvYxEGKA',
#   'name': 'Super Dog',
#   'address': '1160 Gallatin Pike S',
#   'city': 'Nashville',
#   'state': 'TN',
#   'postal_code': '37115',
#   'latitude': 36.2485696,
#   'longitude': -86.7199857,
#   'stars': 4.0,
#   'review_count': 6,
#   'is_open': 0,
#   'attributes': {'RestaurantsReservations': 'False',
#    'RestaurantsDelivery': 'False',
#    'RestaurantsAttire': "u'casual'",
#    'BusinessAcceptsCreditCards': 'False',
#    'Alcohol': "u'beer_and_wine'",
#    'OutdoorSeating': 'False',
#    'RestaurantsGoodForGroups': 'True',
#    'NoiseLevel': "u'average'",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': False}",
#    'RestaurantsPriceRange2': '1',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'HasTV': 'True',
#    'RestaurantsTakeOut': 'True',
#    'WiFi': "u'no'",
#    'GoodForKids': 'True',
#    'Caters': 'False'},
#   'categories': 'Hot Dogs, Restaurants',
#   'hours': None},
#  {'business_id': 'PSo_C1Sfa13JHjzVNW6ziQ',
#   'name': 'Indian Walk Veterinary Center',
#   'address': '662 Durham Rd',
#   'city': 'Newtown',
#   'state': 'PA',
#   'postal_code': '18940',
#   'latitude': 40.2734926,
#   'longitude': -74.987496,
#   'stars': 5.0,
#   'review_count': 15,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'Pet Services, Pet Groomers, Pets, Veterinarians',
#   'hours': {'Monday': '8:0-19:0',
#    'Tuesday': '8:0-19:0',
#    'Wednesday': '8:0-19:0',
#    'Thursday': '8:0-19:0',
#    'Friday': '8:0-17:0',
#    'Saturday': '9:0-13:0'}},
#  {'business_id': 'noByYNtDLQAra9ccqxdfDw',
#   'name': 'H&M',
#   'address': '827-833 State St',
#   'city': 'Santa Barbara',
#   'state': 'CA',
#   'postal_code': '93101',
#   'latitude': 34.4202089255,
#   'longitude': -119.7004597389,
#   'stars': 3.0,
#   'review_count': 24,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'RestaurantsPriceRange2': '1'},
#   'categories': "Women's Clothing, Accessories, Children's Clothing, Men's Clothing, Adult, Shopping, Fashion",
#   'hours': {'Monday': '11:0-18:0',
#    'Tuesday': '11:0-18:0',
#    'Wednesday': '11:0-18:0',
#    'Thursday': '11:0-18:0',
#    'Friday': '11:0-18:0',
#    'Saturday': '11:0-18:0',
#    'Sunday': '11:0-18:0'}},
#  {'business_id': 'tMkwHmWFUEXrC9ZduonpTg',
#   'name': 'The Green Pheasant',
#   'address': '215 1st Ave S',
#   'city': 'Nashville',
#   'state': 'TN',
#   'postal_code': '37201',
#   'latitude': 36.1598858,
#   'longitude': -86.7731974,
#   'stars': 4.0,
#   'review_count': 161,
#   'is_open': 0,
#   'attributes': {'RestaurantsGoodForGroups': 'True',
#    'HappyHour': 'True',
#    'GoodForMeal': "{'dessert': None, 'latenight': None, 'lunch': None, 'dinner': True, 'brunch': None, 'breakfast': None}",
#    'DogsAllowed': 'False',
#    'RestaurantsAttire': "u'casual'",
#    'BikeParking': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'RestaurantsTakeOut': 'None',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': False}",
#    'HasTV': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': True, 'lot': False, 'valet': True}",
#    'GoodForKids': 'False',
#    'RestaurantsReservations': 'True',
#    'RestaurantsTableService': 'True',
#    'RestaurantsDelivery': 'None',
#    'Caters': 'True',
#    'OutdoorSeating': 'False',
#    'WiFi': "u'free'",
#    'Alcohol': "u'full_bar'",
#    'WheelchairAccessible': 'True',
#    'NoiseLevel': "u'average'"},
#   'categories': 'Restaurants, Japanese, Seafood',
#   'hours': {'Wednesday': '16:0-22:0',
#    'Thursday': '16:0-22:0',
#    'Friday': '16:0-23:0',
#    'Saturday': '16:0-23:0'}},
#  {'business_id': 'QdN72BWoyFypdGJhhI5r7g',
#   'name': 'Bar One',
#   'address': '767 S 9th St',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19147',
#   'latitude': 39.9398245705,
#   'longitude': -75.1574465632,
#   'stars': 4.0,
#   'review_count': 65,
#   'is_open': 0,
#   'attributes': {'Smoking': "u'no'",
#    'NoiseLevel': "u'average'",
#    'Caters': 'False',
#    'WiFi': "u'free'",
#    'RestaurantsGoodForGroups': 'True',
#    'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#    'OutdoorSeating': 'False',
#    'RestaurantsTableService': 'True',
#    'RestaurantsAttire': "'casual'",
#    'Ambience': "{'touristy': False, 'hipster': True, 'romantic': None, 'divey': False, 'intimate': False, 'trendy': None, 'upscale': False, 'classy': None, 'casual': True}",
#    'RestaurantsReservations': 'False',
#    'RestaurantsTakeOut': 'True',
#    'GoodForDancing': 'False',
#    'RestaurantsPriceRange2': '2',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': True, 'breakfast': False}",
#    'GoodForKids': 'False',
#    'HappyHour': 'True',
#    'RestaurantsDelivery': 'True',
#    'BusinessParking': "{'garage': None, 'street': True, 'validated': None, 'lot': False, 'valet': False}",
#    'BikeParking': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'HasTV': 'True',
#    'Alcohol': "u'full_bar'"},
#   'categories': 'Cocktail Bars, Bars, Italian, Nightlife, Restaurants',
#   'hours': {'Monday': '16:0-0:0',
#    'Tuesday': '16:0-0:0',
#    'Wednesday': '16:0-0:0',
#    'Thursday': '12:0-0:0',
#    'Friday': '12:0-2:0',
#    'Saturday': '11:0-2:0',
#    'Sunday': '11:0-0:0'}},
#  {'business_id': 'sqSqqLy0sN8n2IZrAbzidQ',
#   'name': "Domino's Pizza",
#   'address': '3001 Highway 31 W',
#   'city': 'White House',
#   'state': 'TN',
#   'postal_code': '37188',
#   'latitude': 36.4647467622,
#   'longitude': -86.6591868908,
#   'stars': 3.5,
#   'review_count': 8,
#   'is_open': 1,
#   'attributes': {'RestaurantsPriceRange2': '1'},
#   'categories': 'Pizza, Chicken Wings, Sandwiches, Restaurants',
#   'hours': {'Monday': '10:0-0:0',
#    'Tuesday': '10:0-0:0',
#    'Wednesday': '10:0-0:0',
#    'Thursday': '10:0-0:0',
#    'Friday': '10:0-1:0',
#    'Saturday': '10:0-1:0',
#    'Sunday': '10:0-0:0'}},
#  {'business_id': 'fvWn8oXXwbj2l79cochZyw',
#   'name': 'Altitude Trampoline Park - Boise',
#   'address': '1301 N Milwaukee St',
#   'city': 'Boise',
#   'state': 'ID',
#   'postal_code': '83704',
#   'latitude': 43.6167635,
#   'longitude': -116.2853821,
#   'stars': 5.0,
#   'review_count': 30,
#   'is_open': 1,
#   'attributes': {'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'ByAppointmentOnly': 'False',
#    'WheelchairAccessible': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'BikeParking': 'True'},
#   'categories': 'Trampoline Parks, Active Life',
#   'hours': {'Monday': '10:0-20:0',
#    'Tuesday': '10:0-20:0',
#    'Wednesday': '10:0-20:0',
#    'Thursday': '10:0-20:0',
#    'Friday': '10:0-22:0',
#    'Saturday': '9:0-22:0',
#    'Sunday': '10:0-20:0'}},
#  {'business_id': 'Mjboz24M9NlBeiOJKLEd_Q',
#   'name': 'DeSandro on Main',
#   'address': '4105 Main St',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19127',
#   'latitude': 40.0224662,
#   'longitude': -75.218314,
#   'stars': 3.0,
#   'review_count': 41,
#   'is_open': 0,
#   'attributes': {'RestaurantsReservations': 'False',
#    'Caters': 'False',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsDelivery': 'True',
#    'RestaurantsPriceRange2': '1',
#    'RestaurantsGoodForGroups': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': False}",
#    'GoodForKids': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'Alcohol': "u'none'",
#    'BusinessAcceptsCreditCards': 'True',
#    'OutdoorSeating': 'True',
#    'BikeParking': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'GoodForMeal': "{'dessert': False, 'latenight': True, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}",
#    'RestaurantsTableService': 'True',
#    'HasTV': 'True',
#    'WiFi': "'no'",
#    'NoiseLevel': "'average'"},
#   'categories': 'Pizza, Restaurants, Salad, Soup',
#   'hours': {'Tuesday': '17:0-21:30',
#    'Wednesday': '17:0-1:30',
#    'Thursday': '17:0-1:30',
#    'Friday': '17:0-0:30',
#    'Saturday': '17:0-0:30',
#    'Sunday': '17:0-21:30'}},
#  {'business_id': '8sshLb4UU7emeUDvtJWnpA',
#   'name': 'DanceLine',
#   'address': '30 W Lancaster Ave',
#   'city': 'Paoli',
#   'state': 'PA',
#   'postal_code': '19301',
#   'latitude': 40.0415845065,
#   'longitude': -75.4849526577,
#   'stars': 4.5,
#   'review_count': 11,
#   'is_open': 1,
#   'attributes': {'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'GoodForKids': 'True',
#    'BikeParking': 'True',
#    'WheelchairAccessible': 'True'},
#   'categories': "Dance Wear, Sports Wear, Children's Clothing, Arts & Entertainment, Social Clubs, Performing Arts, Sporting Goods, Shoe Stores, Fashion, Shopping",
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '10:0-19:0',
#    'Wednesday': '10:0-19:0',
#    'Thursday': '10:0-19:0',
#    'Friday': '10:0-19:0',
#    'Saturday': '10:0-17:0',
#    'Sunday': '12:0-15:0'}},
#  {'business_id': 'kV_Q1oqis8Qli8dUoGpTyQ',
#   'name': 'Ardmore Pizza',
#   'address': '10 Rittenhouse Pl',
#   'city': 'Ardmore',
#   'state': 'PA',
#   'postal_code': '19003',
#   'latitude': 40.0067071,
#   'longitude': -75.289671,
#   'stars': 3.5,
#   'review_count': 109,
#   'is_open': 1,
#   'attributes': {'RestaurantsGoodForGroups': 'True',
#    'WiFi': "u'no'",
#    'Alcohol': "u'none'",
#    'GoodForKids': 'True',
#    'OutdoorSeating': 'False',
#    'HasTV': 'True',
#    'RestaurantsPriceRange2': '1',
#    'RestaurantsAttire': "u'casual'",
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsReservations': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsDelivery': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': True, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'NoiseLevel': "u'average'",
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'Caters': 'True'},
#   'categories': 'Pizza, Restaurants',
#   'hours': {'Monday': '11:0-0:0',
#    'Tuesday': '11:0-0:0',
#    'Wednesday': '11:0-0:0',
#    'Thursday': '11:0-0:0',
#    'Friday': '11:0-1:0',
#    'Saturday': '11:0-1:0',
#    'Sunday': '11:0-0:0'}},
#  {'business_id': 'w_AMNoI1iG9eay7ncmc67w',
#   'name': 'River 127',
#   'address': '100 Iberville St',
#   'city': 'New Orleans',
#   'state': 'LA',
#   'postal_code': '70130',
#   'latitude': 29.951359,
#   'longitude': -90.0646715,
#   'stars': 3.0,
#   'review_count': 12,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'WiFi': "'no'",
#    'RestaurantsPriceRange2': '2'},
#   'categories': 'Event Planning & Services, Hotels, Hotels & Travel',
#   'hours': None},
#  {'business_id': 'aPNXGTDkf-4bjhyMBQxqpQ',
#   'name': 'Craft Hall',
#   'address': '901 N Delaware Ave',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19123',
#   'latitude': 39.9625821,
#   'longitude': -75.1356571,
#   'stars': 3.5,
#   'review_count': 65,
#   'is_open': 1,
#   'attributes': {'OutdoorSeating': 'True',
#    'RestaurantsPriceRange2': '2',
#    'BusinessAcceptsCreditCards': 'True',
#    'DogsAllowed': 'True',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': False}",
#    'HappyHour': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}",
#    'RestaurantsDelivery': 'True',
#    'HasTV': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'RestaurantsTakeOut': 'True',
#    'GoodForKids': 'True'},
#   'categories': 'Eatertainment, Arts & Entertainment, Brewpubs, American (Traditional), Bakeries, Breweries, Food, Restaurants',
#   'hours': {'Monday': '0:0-0:0',
#    'Wednesday': '16:0-22:0',
#    'Thursday': '16:0-22:0',
#    'Friday': '16:0-19:0',
#    'Saturday': '11:0-23:0',
#    'Sunday': '11:0-20:0'}},
#  {'business_id': '2xVsWBNFwZOxIOdd9Mwnww',
#   'name': 'Cheeseburger In Paradise',
#   'address': '116 N Pottstown Pike',
#   'city': 'Exton',
#   'state': 'PA',
#   'postal_code': '19341',
#   'latitude': 40.029962,
#   'longitude': -75.630607,
#   'stars': 2.5,
#   'review_count': 20,
#   'is_open': 0,
#   'attributes': {'NoiseLevel': "u'average'",
#    'HasTV': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': False}",
#    'RestaurantsPriceRange2': '2',
#    'BusinessAcceptsCreditCards': 'True',
#    'OutdoorSeating': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'WiFi': "u'free'",
#    'RestaurantsDelivery': 'False',
#    'GoodForKids': 'True',
#    'Alcohol': "u'full_bar'",
#    'RestaurantsTakeOut': 'True',
#    'HappyHour': 'True'},
#   'categories': 'Restaurants, Burgers',
#   'hours': None},
#  {'business_id': 'mGFsPRHdE6SMV1gYQ6GzgQ',
#   'name': 'T-Mobile',
#   'address': '4735 Concord Pike',
#   'city': 'Wilmington',
#   'state': 'DE',
#   'postal_code': '19803',
#   'latitude': 39.822176,
#   'longitude': -75.546007,
#   'stars': 2.0,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '3',
#    'WheelchairAccessible': 'True'},
#   'categories': 'Mobile Phones, Telecommunications, Electronics, Mobile Phone Accessories, Local Services, Shopping, IT Services & Computer Repair',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '10:0-20:0',
#    'Wednesday': '10:0-20:0',
#    'Thursday': '10:0-20:0',
#    'Friday': '10:0-20:0',
#    'Saturday': '10:0-20:0',
#    'Sunday': '11:0-18:0'}},
#  {'business_id': 'LcAozWCMLGjwRbokaJAKMg',
#   'name': "Edwardsville Children's Museum",
#   'address': '722 Holyoake Rd',
#   'city': 'Edwardsville',
#   'state': 'IL',
#   'postal_code': '62025',
#   'latitude': 38.8043945,
#   'longitude': -89.9497332,
#   'stars': 4.5,
#   'review_count': 12,
#   'is_open': 1,
#   'attributes': {'GoodForKids': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'WheelchairAccessible': 'True',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}"},
#   'categories': "Museums, Kids Activities, Arts & Entertainment, Education, Active Life, Playgrounds, Children's Museums",
#   'hours': {'Monday': '10:0-15:0',
#    'Tuesday': '9:30-14:0',
#    'Wednesday': '10:0-18:0',
#    'Thursday': '10:0-18:0',
#    'Friday': '9:30-17:30',
#    'Saturday': '9:30-17:30'}},
#  {'business_id': 'fSCNwMtNNQY9QT69Cj9fiA',
#   'name': 'Sierra Pro Events',
#   'address': '',
#   'city': 'Sparks',
#   'state': 'NV',
#   'postal_code': '89431',
#   'latitude': 39.5401545,
#   'longitude': -119.7483949,
#   'stars': 5.0,
#   'review_count': 7,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True', 'WiFi': "u'no'"},
#   'categories': 'Musicians, DJs, Karaoke, Event Planning & Services, Nightlife',
#   'hours': {'Monday': '9:0-17:0',
#    'Tuesday': '9:0-17:0',
#    'Wednesday': '9:0-17:0',
#    'Thursday': '9:0-17:0',
#    'Friday': '9:0-17:0',
#    'Saturday': '9:0-17:0',
#    'Sunday': '9:0-17:0'}},
#  {'business_id': 'x1mhq4IpWctQOBM06dU8vg',
#   'name': 'Diamond Hair Company',
#   'address': '5324 W 16th St',
#   'city': 'Indianapolis',
#   'state': 'IN',
#   'postal_code': '46224',
#   'latitude': 39.7874644177,
#   'longitude': -86.2514209,
#   'stars': 1.5,
#   'review_count': 25,
#   'is_open': 1,
#   'attributes': {'RestaurantsPriceRange2': '2'},
#   'categories': 'Hair Salons, Hair Extensions, Beauty & Spas, Wigs, Shopping',
#   'hours': {'Monday': '9:0-18:0',
#    'Tuesday': '9:0-18:0',
#    'Wednesday': '9:0-18:0',
#    'Thursday': '9:0-18:0',
#    'Friday': '9:0-18:0',
#    'Saturday': '9:0-15:0',
#    'Sunday': '9:0-15:0'}},
#  {'business_id': 'ljxNT9p0y7YMPx0fcNBGig',
#   'name': "Tony's Restaurant & 3rd Street Cafe",
#   'address': '312 Piasa St',
#   'city': 'Alton',
#   'state': 'IL',
#   'postal_code': '62002',
#   'latitude': 38.896563,
#   'longitude': -90.1862032987,
#   'stars': 3.0,
#   'review_count': 94,
#   'is_open': 1,
#   'attributes': {'RestaurantsReservations': 'True',
#    'RestaurantsPriceRange2': '2',
#    'OutdoorSeating': 'True',
#    'RestaurantsDelivery': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'Alcohol': "u'full_bar'",
#    'HasTV': 'True',
#    'Caters': 'True',
#    'GoodForKids': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'NoiseLevel': "u'average'",
#    'RestaurantsAttire': "u'casual'",
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': True, 'valet': False}",
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': True, 'brunch': False, 'breakfast': False}",
#    'WiFi': "'free'",
#    'RestaurantsTakeOut': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'HappyHour': 'True',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': True, 'casual': True}",
#    'RestaurantsTableService': 'True',
#    'WheelchairAccessible': 'True'},
#   'categories': 'Restaurants, Specialty Food, Steakhouses, Food, Italian, Pizza, Pasta Shops',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '16:0-21:30',
#    'Wednesday': '16:0-21:30',
#    'Thursday': '16:0-21:30',
#    'Friday': '16:0-22:0',
#    'Saturday': '16:0-22:0',
#    'Sunday': '16:0-21:30'}},
#  {'business_id': 'lwItZ1Ck3KtpCgG4CPFmpQ',
#   'name': 'Stomel Elliot Attorney-At-Law',
#   'address': '532 Rte 70 W, Fl 2',
#   'city': 'Cherry Hill',
#   'state': 'NJ',
#   'postal_code': '08002',
#   'latitude': 39.915478,
#   'longitude': -75.016973,
#   'stars': 5.0,
#   'review_count': 5,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'DUI Law, Professional Services, Lawyers, Criminal Defense Law',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '0:0-0:0',
#    'Wednesday': '0:0-0:0',
#    'Thursday': '0:0-0:0',
#    'Friday': '0:0-0:0',
#    'Saturday': '0:0-0:0',
#    'Sunday': '0:0-0:0'}},
#  {'business_id': 'Kq51_lGAgAigqmENITTr-A',
#   'name': 'Bala Better Health',
#   'address': '2 Bala Plz, Ste PL-11',
#   'city': 'Bala Cynwyd',
#   'state': 'PA',
#   'postal_code': '19004',
#   'latitude': 40.00687,
#   'longitude': -75.217262,
#   'stars': 4.0,
#   'review_count': 13,
#   'is_open': 1,
#   'attributes': {'WiFi': "u'free'",
#    'BusinessAcceptsBitcoin': 'False',
#    'BikeParking': 'True',
#    'AcceptsInsurance': 'False',
#    'ByAppointmentOnly': 'False',
#    'WheelchairAccessible': 'True',
#    'BusinessAcceptsCreditCards': 'True'},
#   'categories': 'Health & Medical, Beauty & Spas, Laser Hair Removal, Doctors, Hair Removal, Chiropractors, Weight Loss Centers, Sports Medicine, Medical Spas, Skin Care',
#   'hours': {'Monday': '0:0-0:0', 'Tuesday': '9:0-15:0'}},
#  {'business_id': 'mglME3E7esPSpIF5bias8w',
#   'name': 'Pier 1',
#   'address': '1014 Baltimore Pike',
#   'city': 'Springfield',
#   'state': 'PA',
#   'postal_code': '19064',
#   'latitude': 39.9152704301,
#   'longitude': -75.3426812589,
#   'stars': 2.5,
#   'review_count': 8,
#   'is_open': 0,
#   'attributes': {'RestaurantsPriceRange2': '3',
#    'BikeParking': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}"},
#   'categories': 'Fashion, Shopping, Department Stores, Furniture Stores, Candle Stores, Home & Garden, Home Decor',
#   'hours': {'Monday': '10:0-20:0',
#    'Tuesday': '10:0-20:0',
#    'Wednesday': '10:0-20:0',
#    'Thursday': '10:0-20:0',
#    'Friday': '10:0-21:0',
#    'Saturday': '10:0-21:0',
#    'Sunday': '11:0-19:0'}},
#  {'business_id': 'wghnIlMb_i5U46HMBGx9ig',
#   'name': 'China Dragon Restaurant',
#   'address': '1625 W Valencia Rd, Ste 101-103',
#   'city': 'Tucson',
#   'state': 'AZ',
#   'postal_code': '85746',
#   'latitude': 32.1323047,
#   'longitude': -110.9999851,
#   'stars': 3.0,
#   'review_count': 23,
#   'is_open': 0,
#   'attributes': {'WiFi': "'no'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'HasTV': 'False',
#    'Alcohol': "'beer_and_wine'",
#    'RestaurantsDelivery': 'False',
#    'RestaurantsPriceRange2': '2',
#    'RestaurantsAttire': "u'casual'",
#    'OutdoorSeating': 'False',
#    'RestaurantsReservations': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'NoiseLevel': "u'quiet'",
#    'RestaurantsTakeOut': 'True',
#    'Caters': 'False',
#    'Ambience': "{'romantic': False, 'intimate': False, 'classy': False, 'hipster': False, 'divey': False, 'touristy': False, 'trendy': False, 'upscale': False, 'casual': True}",
#    'BusinessAcceptsCreditCards': 'True',
#    'GoodForKids': 'True'},
#   'categories': 'Restaurants, Chinese',
#   'hours': {'Monday': '11:0-21:0',
#    'Tuesday': '11:0-21:0',
#    'Wednesday': '11:0-21:0',
#    'Thursday': '11:0-21:0',
#    'Friday': '11:0-21:0',
#    'Saturday': '11:0-21:0',
#    'Sunday': '11:0-21:0'}},
#  {'business_id': 'JX4tUpd09YFchLBuI43lGw',
#   'name': 'Naked Cyber Cafe & Espresso Bar',
#   'address': '10303  108 Street NW',
#   'city': 'Edmonton',
#   'state': 'AB',
#   'postal_code': 'T5J 1L7',
#   'latitude': 53.5446819,
#   'longitude': -113.506589,
#   'stars': 4.0,
#   'review_count': 12,
#   'is_open': 1,
#   'attributes': {'OutdoorSeating': 'False',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': True, 'lot': True, 'valet': False}",
#    'WiFi': "u'free'",
#    'RestaurantsPriceRange2': '2',
#    'HasTV': 'False',
#    'Alcohol': "u'none'",
#    'RestaurantsTakeOut': 'True',
#    'BikeParking': 'True',
#    'Smoking': "u'no'",
#    'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': True, 'video': False, 'karaoke': False}",
#    'Caters': 'False',
#    'DogsAllowed': 'False',
#    'CoatCheck': 'False',
#    'WheelchairAccessible': 'True'},
#   'categories': 'Arts & Entertainment, Music Venues, Internet Service Providers, Nightlife, Food, Coffee & Tea, Jazz & Blues, Professional Services, Internet Cafes',
#   'hours': {'Monday': '11:0-1:0',
#    'Tuesday': '11:0-1:0',
#    'Wednesday': '11:0-1:0',
#    'Thursday': '11:0-1:0',
#    'Friday': '11:0-1:0',
#    'Saturday': '19:0-1:0',
#    'Sunday': '19:0-1:0'}},
#  {'business_id': 'lk9IwjZXqUMqqOhM774DtQ',
#   'name': 'Caviar & Bananas',
#   'address': '2031 Broadway',
#   'city': 'Nashville',
#   'state': 'TN',
#   'postal_code': '37203',
#   'latitude': 36.1483712,
#   'longitude': -86.7988947,
#   'stars': 3.5,
#   'review_count': 159,
#   'is_open': 0,
#   'attributes': {'RestaurantsTakeOut': 'True',
#    'RestaurantsReservations': 'False',
#    'RestaurantsAttire': "'casual'",
#    'OutdoorSeating': 'True',
#    'BestNights': "{'monday': False, 'tuesday': False, 'friday': False, 'wednesday': False, 'thursday': False, 'sunday': False, 'saturday': False}",
#    'RestaurantsTableService': 'False',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': True, 'upscale': False, 'classy': True, 'casual': True}",
#    'RestaurantsPriceRange2': '2',
#    'Alcohol': "u'beer_and_wine'",
#    'RestaurantsGoodForGroups': 'True',
#    'BikeParking': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'GoodForKids': 'True',
#    'HappyHour': 'True',
#    'WiFi': "'free'",
#    'CoatCheck': 'False',
#    'BusinessParking': "{'garage': True, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'GoodForMeal': "{'dessert': True, 'latenight': False, 'lunch': True, 'dinner': False, 'brunch': True, 'breakfast': True}",
#    'WheelchairAccessible': 'True',
#    'NoiseLevel': "u'average'",
#    'Caters': 'True',
#    'HasTV': 'False',
#    'Music': "{'dj': False, 'background_music': False, 'no_music': False, 'jukebox': False, 'live': False, 'video': False, 'karaoke': False}",
#    'Smoking': "u'no'",
#    'RestaurantsDelivery': 'True',
#    'GoodForDancing': 'False'},
# ...
#   'name': 'Starbucks',
#   'address': '1251 Route 130 S',
#   'city': 'Cinnaminson',
#   'state': 'NJ',
#   'postal_code': '08077',
#   'latitude': 40.000157,
#   'longitude': -74.9873134,
#   'stars': 4.5,
#   'review_count': 7,
#   'is_open': 1,
#   'attributes': {'WiFi': "u'free'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"},
#   'categories': 'Coffee & Tea, Food',
#   'hours': {'Monday': '5:30-20:0',
#    'Tuesday': '5:30-20:0',
#    'Wednesday': '5:30-20:0',
#    'Thursday': '5:30-20:0',
#    'Friday': '5:30-20:0',
#    'Saturday': '5:30-20:0',
#    'Sunday': '6:0-20:0'}},
#  {'business_id': 'h-GjLWwP7A0580JTqO-Wpg',
#   'name': 'The Window Depot',
#   'address': '2300 South 6th Ave',
#   'city': 'Tucson',
#   'state': 'AZ',
#   'postal_code': '85713',
#   'latitude': 32.1949772399,
#   'longitude': -110.9686693634,
#   'stars': 2.5,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'ByAppointmentOnly': 'False'},
#   'categories': 'Furniture Stores, Home Services, Building Supplies, Contractors, Shopping, Home & Garden, Kitchen & Bath, Interior Design, Kitchen Supplies',
#   'hours': {'Monday': '7:0-18:0',
#    'Tuesday': '7:0-18:0',
#    'Wednesday': '7:0-18:0',
#    'Thursday': '7:0-18:0',
#    'Friday': '7:0-18:0',
#    'Saturday': '8:0-16:0'}},
#  {'business_id': 'Tr1K019SoddjZegRv7vy2w',
#   'name': 'James Brown Hair',
#   'address': '1114 Pine St',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19106',
#   'latitude': 39.944743,
#   'longitude': -75.160428,
#   'stars': 4.0,
#   'review_count': 21,
#   'is_open': 0,
#   'attributes': {'RestaurantsPriceRange2': '2',
#    'ByAppointmentOnly': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'GoodForKids': 'False',
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}"},
#   'categories': 'Waxing, Hair Removal, Beauty & Spas, Hair Salons',
#   'hours': {'Wednesday': '10:0-19:0',
#    'Thursday': '10:0-19:0',
#    'Friday': '10:0-19:0',
#    'Saturday': '10:0-16:0'}},
#  {'business_id': 'g7GCbnZC_HKO0ybNt7NXBw',
#   'name': 'Popeyes Louisiana Kitchen',
#   'address': '443 Opry Mills Dr',
#   'city': 'Nashville',
#   'state': 'TN',
#   'postal_code': '37214',
#   'latitude': 36.202427,
#   'longitude': -86.692898,
#   'stars': 1.0,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'RestaurantsDelivery': 'None', 'RestaurantsTakeOut': 'None'},
#   'categories': 'Chicken Wings, Fast Food, Restaurants',
#   'hours': None},
#  {'business_id': 'woVWLiVcJoC-KkUv4WlkGw',
#   'name': 'Roll A Guard',
#   'address': '12722 62nd St, Ste 206',
#   'city': 'Largo',
#   'state': 'FL',
#   'postal_code': '33773',
#   'latitude': 27.8877925,
#   'longitude': -82.7213744,
#   'stars': 4.0,
#   'review_count': 5,
#   'is_open': 1,
#   'attributes': {'ByAppointmentOnly': 'True',
#    'BusinessAcceptsCreditCards': 'True'},
#   'categories': 'Home Services, Shutters',
#   'hours': {'Monday': '8:30-17:0',
#    'Tuesday': '8:30-17:0',
#    'Wednesday': '8:30-17:0',
#    'Thursday': '8:30-17:0',
#    'Friday': '8:30-17:0'}},
#  {'business_id': 'T4RZpKY2xQkWlP-_bGpLCQ',
#   'name': "Willie's Shoe Repair",
#   'address': '4483 Castleman Ave',
#   'city': 'Saint Louis',
#   'state': 'MO',
#   'postal_code': '63110',
#   'latitude': 38.6168931,
#   'longitude': -90.2611424,
#   'stars': 3.0,
#   'review_count': 5,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'Local Services, Shoe Repair',
#   'hours': None},
#  {'business_id': 'g6VqerF6K0MeiSODAK5PBA',
#   'name': "MH Pomander's Bridal",
#   'address': '1101 E 54th St, Ste A',
#   'city': 'Indianapolis',
#   'state': 'IN',
#   'postal_code': '46220',
#   'latitude': 39.850895,
#   'longitude': -86.1393779,
#   'stars': 3.5,
#   'review_count': 5,
#   'is_open': 0,
#   'attributes': {'ByAppointmentOnly': 'False',
#    'BusinessAcceptsCreditCards': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'RestaurantsPriceRange2': '2'},
#   'categories': "Bridal, Jewelry, Fashion, Sewing & Alterations, Women's Clothing, Local Services, Shopping",
#   'hours': {'Tuesday': '11:0-17:0',
#    'Wednesday': '11:0-17:0',
#    'Thursday': '11:0-17:0',
#    'Friday': '11:0-17:0',
#    'Saturday': '10:0-17:0'}},
#  {'business_id': 'iIJDIIUVmcvFUZrgnj983g',
#   'name': 'Sierra Car Wash',
#   'address': '4991 Longley Ln',
#   'city': 'Reno',
#   'state': 'NV',
#   'postal_code': '89502',
#   'latitude': 39.4780893,
#   'longitude': -119.7649205,
#   'stars': 3.0,
#   'review_count': 109,
#   'is_open': 1,
#   'attributes': {'ByAppointmentOnly': 'False',
#    'BusinessAcceptsCreditCards': 'True'},
#   'categories': 'Automotive, Car Wash',
#   'hours': {'Monday': '7:30-18:0',
#    'Tuesday': '7:30-18:0',
#    'Wednesday': '7:30-18:0',
#    'Thursday': '7:30-18:0',
#    'Friday': '7:30-18:0',
#    'Saturday': '7:30-18:0',
#    'Sunday': '7:30-18:0'}},
#  {'business_id': 'ChrCGMx2MHhDYgZFuVhHWA',
#   'name': 'Salon Mosaic',
#   'address': '6815 Sierra Ctr Pkwy, Ste 400',
#   'city': 'Reno',
#   'state': 'NV',
#   'postal_code': '89511',
#   'latitude': 39.4657110269,
#   'longitude': -119.7798574532,
#   'stars': 4.0,
#   'review_count': 6,
#   'is_open': 1,
#   'attributes': {'ByAppointmentOnly': 'False',
#    'RestaurantsPriceRange2': '2',
#    'WheelchairAccessible': 'True',
#    'GoodForKids': 'True',
#    'BikeParking': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'HairSpecializesIn': "{'straightperms': False, 'coloring': False, 'extensions': False, 'africanamerican': False, 'curly': False, 'kids': False, 'perms': False, 'asian': False}",
#    'BusinessAcceptsCreditCards': 'True'},
#   'categories': 'Hair Salons, Nail Salons, Beauty & Spas, Skin Care',
#   'hours': {'Monday': '10:0-18:0',
#    'Tuesday': '10:0-18:0',
#    'Wednesday': '10:0-18:0',
#    'Thursday': '10:0-18:0',
#    'Friday': '10:0-18:0',
#    'Saturday': '9:0-18:0'}},
#  {'business_id': 'a4BzM4nqUzJRqszzEV1fJQ',
#   'name': 'Italian Style! Italian Restaurant',
#   'address': '1203 Murfreesboro Rd, Ste 501',
#   'city': 'Franklin',
#   'state': 'TN',
#   'postal_code': '37067',
#   'latitude': 35.9173052,
#   'longitude': -86.8296648,
#   'stars': 3.5,
#   'review_count': 5,
#   'is_open': 0,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsReservations': 'True',
#    'WiFi': "u'free'",
#    'RestaurantsAttire': "u'casual'",
#    'Alcohol': "u'none'",
#    'GoodForKids': 'True',
#    'RestaurantsPriceRange2': '2',
#    'HasTV': 'False',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsGoodForGroups': 'True'},
#   'categories': 'Italian, Restaurants',
#   'hours': None},
#  {'business_id': 'GpN4ZVRZaU2jaixGjqCCXQ',
#   'name': "CJ's Tire & Automotive",
#   'address': '210 Eagleview Blvd',
#   'city': 'Lionville',
#   'state': 'PA',
#   'postal_code': '19341',
#   'latitude': 40.0548501663,
#   'longitude': -75.6648682058,
#   'stars': 2.0,
#   'review_count': 14,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True', 'WiFi': "u'free'"},
#   'categories': 'Auto Repair, Oil Change Stations, Automotive, Tires',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '8:0-18:0',
#    'Wednesday': '8:0-18:0',
#    'Thursday': '8:0-18:0',
#    'Friday': '8:0-18:0',
#    'Saturday': '8:0-13:0'}},
#  {'business_id': '5cz1XbgalpQ89gsNQwneVQ',
#   'name': "Portofino's Italian Kitchen",
#   'address': '6742 Memorial Hwy',
#   'city': 'Tampa',
#   'state': 'FL',
#   'postal_code': '33615',
#   'latitude': 27.9955961525,
#   'longitude': -82.5828616138,
#   'stars': 4.0,
#   'review_count': 59,
#   'is_open': 0,
#   'attributes': {'Alcohol': "u'beer_and_wine'",
#    'RestaurantsPriceRange2': '2',
#    'NoiseLevel': "u'quiet'",
#    'HasTV': 'False',
#    'RestaurantsTableService': 'True',
#    'OutdoorSeating': 'False',
#    'RestaurantsTakeOut': 'True',
#    'RestaurantsReservations': 'True',
#    'GoodForMeal': "{'dessert': False, 'latenight': False, 'lunch': False, 'dinner': False, 'brunch': False, 'breakfast': False}",
#    'RestaurantsDelivery': 'True',
#    'RestaurantsGoodForGroups': 'True',
#    'GoodForKids': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'Caters': 'True',
#    'BikeParking': 'False',
#    'Ambience': "{'touristy': False, 'hipster': False, 'romantic': False, 'divey': False, 'intimate': False, 'trendy': False, 'upscale': False, 'classy': False, 'casual': False}",
#    'WheelchairAccessible': 'True',
#    'WiFi': "'free'"},
#   'categories': 'Restaurants, Pizza, Italian',
#   'hours': {'Monday': '0:0-0:0',
#    'Tuesday': '11:30-21:0',
#    'Wednesday': '11:30-21:0',
#    'Thursday': '11:30-21:0',
#    'Friday': '11:30-22:0',
#    'Saturday': '11:30-22:0',
#    'Sunday': '11:30-20:0'}},
#  {'business_id': 'IYMvwRM6WR4C0WC1A8em3A',
#   'name': 'Fred Beans Nissan of Doylestown',
#   'address': '4469 W Swamp Rd',
#   'city': 'Doylestown',
#   'state': 'PA',
#   'postal_code': '18902',
#   'latitude': 40.3331505,
#   'longitude': -75.1375955,
#   'stars': 2.5,
#   'review_count': 26,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True'},
#   'categories': 'Auto Repair, Car Dealers, Oil Change Stations, Automotive',
#   'hours': {'Monday': '9:0-17:0',
#    'Tuesday': '9:0-20:0',
#    'Wednesday': '9:0-20:0',
#    'Thursday': '9:0-20:0',
#    'Friday': '9:0-20:0',
#    'Saturday': '9:0-17:0'}},
#  {'business_id': 'SvcWlFeXbSNkENnZfWYgEQ',
#   'name': 'willow + june hair',
#   'address': '6212 A Ridge Ave',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19128',
#   'latitude': 40.0357941,
#   'longitude': -75.218028,
#   'stars': 5.0,
#   'review_count': 24,
#   'is_open': 1,
#   'attributes': {'ByAppointmentOnly': 'True',
#    'RestaurantsPriceRange2': '2',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'WiFi': "u'free'",
#    'BusinessAcceptsCreditCards': 'True',
#    'GoodForKids': 'True',
#    'BikeParking': 'True'},
#   'categories': 'Beauty & Spas, Hair Extensions, Makeup Artists, Hair Salons',
#   'hours': {'Tuesday': '14:0-20:0',
#    'Wednesday': '14:0-20:0',
#    'Thursday': '14:0-20:0',
#    'Friday': '10:0-18:0',
#    'Saturday': '9:0-15:0'}},
#  {'business_id': '7zfO3VB6wEqDnk0_U16uBg',
#   'name': 'Maximum Grow Gardening',
#   'address': '6117 E Washington St',
#   'city': 'Indianapolis',
#   'state': 'IN',
#   'postal_code': '46219',
#   'latitude': 39.771262889,
#   'longitude': -86.0611667244,
#   'stars': 4.0,
#   'review_count': 5,
#   'is_open': 1,
#   'attributes': {'BikeParking': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsPriceRange2': '2',
#    'WheelchairAccessible': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}"},
#   'categories': 'Home Services, Home & Garden, Shopping, Gardeners, Nurseries & Gardening, Hydroponics',
#   'hours': {'Monday': '10:30-19:0',
#    'Tuesday': '10:30-19:0',
#    'Wednesday': '10:30-19:0',
#    'Thursday': '10:30-19:0',
#    'Friday': '10:30-19:0',
#    'Saturday': '10:0-17:0'}},
#  {'business_id': 'OCrqJ_5eS517_2QIYqCmDQ',
#   'name': 'Contemporary Automotive',
#   'address': '205 N Causeway Blvd',
#   'city': 'Metairie',
#   'state': 'LA',
#   'postal_code': '70001',
#   'latitude': 29.9757236,
#   'longitude': -90.1555333,
#   'stars': 5.0,
#   'review_count': 11,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True', 'WiFi': "u'free'"},
#   'categories': 'Auto Repair, Body Shops, Transmission Repair, Automotive',
#   'hours': {'Monday': '7:0-18:0',
#    'Tuesday': '7:0-18:0',
#    'Wednesday': '7:0-18:0',
#    'Thursday': '7:0-18:0'}},
#  {'business_id': '9yl6MnXqbzIh0NH2wNreFw',
#   'name': 'Lincoln Tactical',
#   'address': '5809 S Dale Mabry Hwy',
#   'city': 'Tampa',
#   'state': 'FL',
#   'postal_code': '33616',
#   'latitude': 27.8832644164,
#   'longitude': -82.5065423958,
#   'stars': 2.5,
#   'review_count': 14,
#   'is_open': 0,
#   'attributes': {'BikeParking': 'True',
#    'BusinessAcceptsCreditCards': 'True',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': True, 'valet': False}",
#    'RestaurantsPriceRange2': '2'},
#   'categories': 'Sporting Goods, Shopping, Guns & Ammo',
#   'hours': {'Monday': '10:0-18:0',
#    'Tuesday': '10:0-18:0',
#    'Wednesday': '10:0-18:0',
#    'Thursday': '10:0-18:0',
#    'Friday': '10:0-18:0',
#    'Saturday': '11:0-16:0'}},
#  {'business_id': 'iNMdSi5bmvGSGeRQiUW4dw',
#   'name': "Wendy's",
#   'address': '3535 E. Irvington Road',
#   'city': 'Tucson',
#   'state': 'AZ',
#   'postal_code': '85714',
#   'latitude': 32.1637404,
#   'longitude': -110.9167218,
#   'stars': 2.5,
#   'review_count': 14,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'RestaurantsAttire': "u'casual'",
#    'Caters': 'False',
#    'OutdoorSeating': 'False',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}",
#    'RestaurantsTakeOut': 'True',
#    'Ambience': "{'romantic': False, 'intimate': False, 'touristy': False, 'hipster': False, 'divey': False, 'classy': False, 'trendy': False, 'upscale': False, 'casual': False}",
#    'WiFi': "u'no'",
#    'RestaurantsPriceRange2': '1',
#    'RestaurantsReservations': 'False',
#    'GoodForKids': 'True',
#    'Alcohol': "u'none'",
#    'NoiseLevel': "u'average'",
#    'RestaurantsGoodForGroups': 'True',
#    'RestaurantsDelivery': 'True',
#    'HasTV': 'True'},
#   'categories': 'Fast Food, Burgers, Restaurants',
#   'hours': {'Monday': '10:0-23:0',
#    'Tuesday': '10:0-23:0',
#    'Wednesday': '10:0-23:0',
#    'Thursday': '10:0-23:0',
#    'Friday': '10:0-0:0',
#    'Saturday': '10:0-0:0',
#    'Sunday': '10:0-23:0'}},
#  {'business_id': '0QmgzzPVNHeNL76B8rwTKA',
#   'name': 'Beneficial Bank',
#   'address': '1600 Chestnut St',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19103',
#   'latitude': 39.9511539,
#   'longitude': -75.1673349,
#   'stars': 2.5,
#   'review_count': 5,
#   'is_open': 0,
#   'attributes': None,
#   'categories': 'Banks & Credit Unions, Financial Services',
#   'hours': {'Monday': '8:30-17:0',
#    'Tuesday': '8:30-17:0',
#    'Wednesday': '8:30-17:0',
#    'Thursday': '8:30-17:0',
#    'Friday': '8:30-18:0',
#    'Saturday': '10:0-14:0'}},
#  {'business_id': 'ByDCN9n5mwHP9LQqUx-1pw',
#   'name': 'Largo Police Department',
#   'address': '201 Highland Ave',
#   'city': 'Largo',
#   'state': 'FL',
#   'postal_code': '33770',
#   'latitude': 27.9201938271,
#   'longitude': -82.7763634482,
#   'stars': 2.5,
#   'review_count': 7,
#   'is_open': 1,
#   'attributes': None,
#   'categories': 'Public Services & Government, Police Departments',
#   'hours': None},
#  {'business_id': 'TwIouh_gbW9TCSK3PhuPrg',
#   'name': 'T J Maxx',
#   'address': '545 Cool Springs Blvd',
#   'city': 'Franklin',
#   'state': 'TN',
#   'postal_code': '37067',
#   'latitude': 35.948462,
#   'longitude': -86.823777,
#   'stars': 3.0,
#   'review_count': 28,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'BikeParking': 'False',
#    'RestaurantsPriceRange2': '2',
#    'BusinessParking': "{'garage': False, 'street': False, 'validated': False, 'lot': False, 'valet': False}"},
#   'categories': 'Fashion, Shopping, Department Stores',
#   'hours': None},
#  {'business_id': 'sDOxVq8gQBpHFYtoxwoLWw',
#   'name': 'Plume Salon',
#   'address': '111 E Girard Ave',
#   'city': 'Philadelphia',
#   'state': 'PA',
#   'postal_code': '19125',
#   'latitude': 39.9691898,
#   'longitude': -75.1340384,
#   'stars': 4.5,
#   'review_count': 138,
#   'is_open': 1,
#   'attributes': {'BusinessAcceptsCreditCards': 'True',
#    'BusinessAcceptsBitcoin': 'False',
#    'GoodForKids': 'True',
#    'BusinessParking': "{'garage': False, 'street': True, 'validated': False, 'lot': False, 'valet': False}",
#    'ByAppointmentOnly': 'False',
#    'BikeParking': 'True',
#    'RestaurantsPriceRange2': '2'},
#   'categories': 'Waxing, Beauty & Spas, Eyelash Service, Used, Vintage & Consignment, Hair Salons, Hair Removal, Makeup Artists, Shopping, Fashion',
#   'hours': {'Monday': '12:0-20:0',
#    'Tuesday': '10:0-20:0',
#    'Wednesday': '10:0-20:0',
#    'Thursday': '10:0-20:0',
#    'Friday': '10:0-20:0',
#    'Saturday': '9:0-19:0',
#    'Sunday': '11:0-19:0'}},
#  ...]

# %%
# pp.pprint(my_file[0])

# %%
pp.pprint(my_file[3])
# Out:
# {  'address': '935 Race St',
#    'attributes': {  'Alcohol': "u'none'",
#                     'BikeParking': 'True',
#                     'BusinessAcceptsCreditCards': 'False',
#                     'BusinessParking': "{'garage': False, 'street': True, "
#                                        "'validated': False, 'lot': False, "
#                                        "'valet': False}",
#                     'ByAppointmentOnly': 'False',
#                     'Caters': 'True',
#                     'OutdoorSeating': 'False',
#                     'RestaurantsDelivery': 'False',
#                     'RestaurantsPriceRange2': '1',
#                     'RestaurantsTakeOut': 'True',
#                     'WiFi': "u'free'"},
#    'business_id': 'MTSW4McQd7CbVtyjqoe9mw',
#    'categories': 'Restaurants, Food, Bubble Tea, Coffee & Tea, Bakeries',
#    'city': 'Philadelphia',
#    'hours': {  'Friday': '7:0-21:0',
#                'Monday': '7:0-20:0',
#                'Saturday': '7:0-21:0',
#                'Sunday': '7:0-21:0',
#                'Thursday': '7:0-20:0',
#                'Tuesday': '7:0-20:0',
#                'Wednesday': '7:0-20:0'},
#    'is_open': 1,
#    'latitude': 39.9555052,
#    'longitude': -75.1555641,
#    'name': 'St Honore Pastries',
#    'postal_code': '19107',
#    'review_count': 80,
#    'stars': 4.0,
#    'state': 'PA'}

# %% [markdown]
# ## create dynamodb yelp-checkin table

# %%
# yelp_business.delete()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-becbf1df69d2> in <module>
# ----> 1 checkin_table.delete()
#
# NameError: name 'checkin_table' is not defined

# %%
dynamodb = boto3.resource('dynamodb', endpoint_url="https://us-east-2.console.aws.amazon.com?arn=arn:aws:dynamodb:us-east-2134132211607:8000")

# %%
yelp_business = dynamodb.create_table(
        TableName='yelp.business',
        KeySchema=[
            {
                'AttributeName': 'business_id',
                'KeyType': 'HASH'  # Partition key
            }
        ],
        AttributeDefinitions=[
            {
                'AttributeName': 'name',
                'AttributeType': 'S'
            }
        ],
        ProvisionedThroughput={
            'ReadCapacityUnits': 25,
            'WriteCapacityUnits': 20
        }
    )
print('created dynamo table.')
# Out:
# ---------------------------------------------------------------------------
# ResourceInUseException                    Traceback (most recent call last)
# <ipython-input-21-d7526f9457c8> in <module>
#       1 dynamodb = boto3.resource('dynamodb', endpoint_url="http://xanaxprincess.asuscomm.com:8000")
#       2
# ----> 3 checkin_table = dynamodb.create_table(
#       4         TableName='yelp-checkin',
#       5         KeySchema=[
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\boto3\resources\factory.py in do_action(self, *args, **kwargs)
#     518             # instance via ``self``.
#     519             def do_action(self, *args, **kwargs):
# --> 520                 response = action(self, *args, **kwargs)
#     521
#     522                 if hasattr(self, 'load'):
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\boto3\resources\action.py in __call__(self, parent, *args, **kwargs)
#      81                     operation_name, params)
#      82
# ---> 83         response = getattr(parent.meta.client, operation_name)(*args, **params)
#      84
#      85         logger.debug('Response: %r', response)
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\botocore\client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\botocore\client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ResourceInUseException: An error occurred (ResourceInUseException) when calling the CreateTable operation: Cannot create preexisting table

# %% [markdown]
# ## checkin

# %%
checkin = read_json('s3a://yelp-dataset-stevenhurwitt/yelp_academic_dataset_checkin.json')
print('read in json file.')
# Out:
# read in json file.

# %%
print('json file has {} records with size of {} mb.'.format(len(checkin), sys.getsizeof(checkin)/1000000))
print('here is an example record:')
print('')
pp.pprint(checkin[0])
# Out:
# json file has 138876 records with size of 1.140568 mb.
# here is an example record:
#
# {  'business_id': '--0zrn43LEaB4jUWTQH_Bg',
#    'date': '2010-10-08 22:21:20, 2010-11-01 21:29:14, 2010-12-23 22:55:45, '
#            '2011-04-08 17:14:59, 2011-04-11 21:28:45, 2011-04-26 16:42:25, '
#            '2011-05-20 19:30:57, 2011-05-24 20:02:21, 2011-08-29 19:01:31'}

# %% [markdown]
# ## insert checkin items into dynamo table

# %%
# checkin_missing_index = []

# for i, c in enumerate(checkin):
#     try:
#         checkin_table.put_item(Item = c)
#     except:
#         print('item too large, index {}, skipping...'.format(i))
#         checkin_missing_index.append(i)

# print('loaded data into table.')
# Out:
# index 138400, skipping...
# item too large, index 138401, skipping...
# item too large, index 138402, skipping...
# item too large, index 138403, skipping...
# item too large, index 138404, skipping...
# item too large, index 138405, skipping...
# item too large, index 138406, skipping...
# item too large, index 138407, skipping...
# item too large, index 138408, skipping...
# item too large, index 138409, skipping...
# item too large, index 138410, skipping...
# item too large, index 138411, skipping...
# item too large, index 138412, skipping...
# item too large, index 138413, skipping...
# item too large, index 138414, skipping...
# item too large, index 138415, skipping...
# item too large, index 138416, skipping...
# item too large, index 138417, skipping...
# item too large, index 138418, skipping...
# item too large, index 138419, skipping...
# item too large, index 138420, skipping...
# item too large, index 138421, skipping...
# item too large, index 138422, skipping...
# item too large, index 138423, skipping...
# item too large, index 138424, skipping...
# item too large, index 138425, skipping...
# item too large, index 138426, skipping...
# item too large, index 138427, skipping...
# item too large, index 138428, skipping...
# item too large, index 138429, skipping...
# item too large, index 138430, skipping...
# item too large, index 138431, skipping...
# item too large, index 138432, skipping...
# item too large, index 138433, skipping...
# item too large, index 138434, skipping...
# item too large, index 138435, skipping...
# item too large, index 138436, skipping...
# item too large, index 138437, skipping...
# item too large, index 138438, skipping...
# item too large, index 138439, skipping...
# item too large, index 138440, skipping...
# item too large, index 138441, skipping...
# item too large, index 138442, skipping...
# item too large, index 138443, skipping...
# item too large, index 138444, skipping...
# item too large, index 138445, skipping...
# item too large, index 138446, skipping...
# item too large, index 138447, skipping...
# item too large, index 138448, skipping...
# item too large, index 138449, skipping...
# item too large, index 138450, skipping...
# item too large, index 138451, skipping...
# item too large, index 138452, skipping...
# item too large, index 138453, skipping...
# item too large, index 138454, skipping...
# item too large, index 138455, skipping...
# item too large, index 138456, skipping...
# item too large, index 138457, skipping...
# item too large, index 138458, skipping...
# item too large, index 138459, skipping...
# item too large, index 138460, skipping...
# item too large, index 138461, skipping...
# item too large, index 138462, skipping...
# item too large, index 138463, skipping...
# item too large, index 138464, skipping...
# item too large, index 138465, skipping...
# item too large, index 138466, skipping...
# item too large, index 138467, skipping...
# item too large, index 138468, skipping...
# item too large, index 138469, skipping...
# item too large, index 138470, skipping...
# item too large, index 138471, skipping...
# item too large, index 138472, skipping...
# item too large, index 138473, skipping...
# item too large, index 138474, skipping...
# item too large, index 138475, skipping...
# item too large, index 138476, skipping...
# item too large, index 138477, skipping...
# item too large, index 138478, skipping...
# item too large, index 138479, skipping...
# item too large, index 138480, skipping...
# item too large, index 138481, skipping...
# item too large, index 138482, skipping...
# item too large, index 138483, skipping...
# item too large, index 138484, skipping...
# item too large, index 138485, skipping...
# item too large, index 138486, skipping...
# item too large, index 138487, skipping...
# item too large, index 138488, skipping...
# item too large, index 138489, skipping...
# item too large, index 138490, skipping...
# item too large, index 138491, skipping...
# item too large, index 138492, skipping...
# item too large, index 138493, skipping...
# item too large, index 138494, skipping...
# item too large, index 138495, skipping...
# item too large, index 138496, skipping...
# item too large, index 138497, skipping...
# item too large, index 138498, skipping...
# item too large, index 138499, skipping...
# item too large, index 138500, skipping...
# item too large, index 138501, skipping...
# item too large, index 138502, skipping...
# item too large, index 138503, skipping...
# item too large, index 138504, skipping...
# item too large, index 138505, skipping...
# item too large, index 138506, skipping...
# item too large, index 138507, skipping...
# item too large, index 138508, skipping...
# item too large, index 138509, skipping...
# item too large, index 138510, skipping...
# item too large, index 138511, skipping...
# item too large, index 138512, skipping...
# item too large, index 138513, skipping...
# item too large, index 138514, skipping...
# item too large, index 138515, skipping...
# item too large, index 138516, skipping...
# item too large, index 138517, skipping...
# item too large, index 138518, skipping...
# item too large, index 138519, skipping...
# item too large, index 138520, skipping...
# item too large, index 138521, skipping...
# item too large, index 138522, skipping...
# item too large, index 138523, skipping...
# item too large, index 138524, skipping...
# item too large, index 138525, skipping...
# item too large, index 138526, skipping...
# item too large, index 138527, skipping...
# item too large, index 138528, skipping...
# item too large, index 138529, skipping...
# item too large, index 138530, skipping...
# item too large, index 138531, skipping...
# item too large, index 138532, skipping...
# item too large, index 138533, skipping...
# item too large, index 138534, skipping...
# item too large, index 138535, skipping...
# item too large, index 138536, skipping...
# item too large, index 138537, skipping...
# item too large, index 138538, skipping...
# item too large, index 138539, skipping...
# item too large, index 138540, skipping...
# item too large, index 138541, skipping...
# item too large, index 138542, skipping...
# item too large, index 138543, skipping...
# item too large, index 138544, skipping...
# item too large, index 138545, skipping...
# item too large, index 138546, skipping...
# item too large, index 138547, skipping...
# item too large, index 138548, skipping...
# item too large, index 138549, skipping...
# item too large, index 138550, skipping...
# item too large, index 138551, skipping...
# item too large, index 138552, skipping...
# item too large, index 138553, skipping...
# item too large, index 138554, skipping...
# item too large, index 138555, skipping...
# item too large, index 138556, skipping...
# item too large, index 138557, skipping...
# item too large, index 138558, skipping...
# item too large, index 138559, skipping...
# item too large, index 138560, skipping...
# item too large, index 138561, skipping...
# item too large, index 138562, skipping...
# item too large, index 138563, skipping...
# item too large, index 138564, skipping...
# item too large, index 138565, skipping...
# item too large, index 138566, skipping...
# item too large, index 138567, skipping...
# item too large, index 138568, skipping...
# item too large, index 138569, skipping...
# item too large, index 138570, skipping...
# item too large, index 138571, skipping...
# item too large, index 138572, skipping...
# item too large, index 138573, skipping...
# item too large, index 138574, skipping...
# item too large, index 138575, skipping...
# item too large, index 138576, skipping...
# item too large, index 138577, skipping...
# item too large, index 138578, skipping...
# item too large, index 138579, skipping...
# item too large, index 138580, skipping...
# item too large, index 138581, skipping...
# item too large, index 138582, skipping...
# item too large, index 138583, skipping...
# item too large, index 138584, skipping...
# item too large, index 138585, skipping...
# item too large, index 138586, skipping...
# item too large, index 138587, skipping...
# item too large, index 138588, skipping...
# item too large, index 138589, skipping...
# item too large, index 138590, skipping...
# item too large, index 138591, skipping...
# item too large, index 138592, skipping...
# item too large, index 138593, skipping...
# item too large, index 138594, skipping...
# item too large, index 138595, skipping...
# item too large, index 138596, skipping...
# item too large, index 138597, skipping...
# item too large, index 138598, skipping...
# item too large, index 138599, skipping...
# item too large, index 138600, skipping...
# item too large, index 138601, skipping...
# item too large, index 138602, skipping...
# item too large, index 138603, skipping...
# item too large, index 138604, skipping...
# item too large, index 138605, skipping...
# item too large, index 138606, skipping...
# item too large, index 138607, skipping...
# item too large, index 138608, skipping...
# item too large, index 138609, skipping...
# item too large, index 138610, skipping...
# item too large, index 138611, skipping...
# item too large, index 138612, skipping...
# item too large, index 138613, skipping...
# item too large, index 138614, skipping...
# item too large, index 138615, skipping...
# item too large, index 138616, skipping...
# item too large, index 138617, skipping...
# item too large, index 138618, skipping...
# item too large, index 138619, skipping...
# item too large, index 138620, skipping...
# item too large, index 138621, skipping...
# item too large, index 138622, skipping...
# item too large, index 138623, skipping...
# item too large, index 138624, skipping...
# item too large, index 138625, skipping...
# item too large, index 138626, skipping...
# item too large, index 138627, skipping...
# item too large, index 138628, skipping...
# item too large, index 138629, skipping...
# item too large, index 138630, skipping...
# item too large, index 138631, skipping...
# item too large, index 138632, skipping...
# item too large, index 138633, skipping...
# item too large, index 138634, skipping...
# item too large, index 138635, skipping...
# item too large, index 138636, skipping...
# item too large, index 138637, skipping...
# item too large, index 138638, skipping...
# item too large, index 138639, skipping...
# item too large, index 138640, skipping...
# item too large, index 138641, skipping...
# item too large, index 138642, skipping...
# item too large, index 138643, skipping...
# item too large, index 138644, skipping...
# item too large, index 138645, skipping...
# item too large, index 138646, skipping...
# item too large, index 138647, skipping...
# item too large, index 138648, skipping...
# item too large, index 138649, skipping...
# item too large, index 138650, skipping...
# item too large, index 138651, skipping...
# item too large, index 138652, skipping...
# item too large, index 138653, skipping...
# item too large, index 138654, skipping...
# item too large, index 138655, skipping...
# item too large, index 138656, skipping...
# item too large, index 138657, skipping...
# item too large, index 138658, skipping...
# item too large, index 138659, skipping...
# item too large, index 138660, skipping...
# item too large, index 138661, skipping...
# item too large, index 138662, skipping...
# item too large, index 138663, skipping...
# item too large, index 138664, skipping...
# item too large, index 138665, skipping...
# item too large, index 138666, skipping...
# item too large, index 138667, skipping...
# item too large, index 138668, skipping...
# item too large, index 138669, skipping...
# item too large, index 138670, skipping...
# item too large, index 138671, skipping...
# item too large, index 138672, skipping...
# item too large, index 138673, skipping...
# item too large, index 138674, skipping...
# item too large, index 138675, skipping...
# item too large, index 138676, skipping...
# item too large, index 138677, skipping...
# item too large, index 138678, skipping...
# item too large, index 138679, skipping...
# item too large, index 138680, skipping...
# item too large, index 138681, skipping...
# item too large, index 138682, skipping...
# item too large, index 138683, skipping...
# item too large, index 138684, skipping...
# item too large, index 138685, skipping...
# item too large, index 138686, skipping...
# item too large, index 138687, skipping...
# item too large, index 138688, skipping...
# item too large, index 138689, skipping...
# item too large, index 138690, skipping...
# item too large, index 138691, skipping...
# item too large, index 138692, skipping...
# item too large, index 138693, skipping...
# item too large, index 138694, skipping...
# item too large, index 138695, skipping...
# item too large, index 138696, skipping...
# item too large, index 138697, skipping...
# item too large, index 138698, skipping...
# item too large, index 138699, skipping...
# item too large, index 138700, skipping...
# item too large, index 138701, skipping...
# item too large, index 138702, skipping...
# item too large, index 138703, skipping...
# item too large, index 138704, skipping...
# item too large, index 138705, skipping...
# item too large, index 138706, skipping...
# item too large, index 138707, skipping...
# item too large, index 138708, skipping...
# item too large, index 138709, skipping...
# item too large, index 138710, skipping...
# item too large, index 138711, skipping...
# item too large, index 138712, skipping...
# item too large, index 138713, skipping...
# item too large, index 138714, skipping...
# item too large, index 138715, skipping...
# item too large, index 138716, skipping...
# item too large, index 138717, skipping...
# item too large, index 138718, skipping...
# item too large, index 138719, skipping...
# item too large, index 138720, skipping...
# item too large, index 138721, skipping...
# item too large, index 138722, skipping...
# item too large, index 138723, skipping...
# item too large, index 138724, skipping...
# item too large, index 138725, skipping...
# item too large, index 138726, skipping...
# item too large, index 138727, skipping...
# item too large, index 138728, skipping...
# item too large, index 138729, skipping...
# item too large, index 138730, skipping...
# item too large, index 138731, skipping...
# item too large, index 138732, skipping...
# item too large, index 138733, skipping...
# item too large, index 138734, skipping...
# item too large, index 138735, skipping...
# item too large, index 138736, skipping...
# item too large, index 138737, skipping...
# item too large, index 138738, skipping...
# item too large, index 138739, skipping...
# item too large, index 138740, skipping...
# item too large, index 138741, skipping...
# item too large, index 138742, skipping...
# item too large, index 138743, skipping...
# item too large, index 138744, skipping...
# item too large, index 138745, skipping...
# item too large, index 138746, skipping...
# item too large, index 138747, skipping...
# item too large, index 138748, skipping...
# item too large, index 138749, skipping...
# item too large, index 138750, skipping...
# item too large, index 138751, skipping...
# item too large, index 138752, skipping...
# item too large, index 138753, skipping...
# item too large, index 138754, skipping...
# item too large, index 138755, skipping...
# item too large, index 138756, skipping...
# item too large, index 138757, skipping...
# item too large, index 138758, skipping...
# item too large, index 138759, skipping...
# item too large, index 138760, skipping...
# item too large, index 138761, skipping...
# item too large, index 138762, skipping...
# item too large, index 138763, skipping...
# item too large, index 138764, skipping...
# item too large, index 138765, skipping...
# item too large, index 138766, skipping...
# item too large, index 138767, skipping...
# item too large, index 138768, skipping...
# item too large, index 138769, skipping...
# item too large, index 138770, skipping...
# item too large, index 138771, skipping...
# item too large, index 138772, skipping...
# item too large, index 138773, skipping...
# item too large, index 138774, skipping...
# item too large, index 138775, skipping...
# item too large, index 138776, skipping...
# item too large, index 138777, skipping...
# item too large, index 138778, skipping...
# item too large, index 138779, skipping...
# item too large, index 138780, skipping...
# item too large, index 138781, skipping...
# item too large, index 138782, skipping...
# item too large, index 138783, skipping...
# item too large, index 138784, skipping...
# item too large, index 138785, skipping...
# item too large, index 138786, skipping...
# item too large, index 138787, skipping...
# item too large, index 138788, skipping...
# item too large, index 138789, skipping...
# item too large, index 138790, skipping...
# item too large, index 138791, skipping...
# item too large, index 138792, skipping...
# item too large, index 138793, skipping...
# item too large, index 138794, skipping...
# item too large, index 138795, skipping...
# item too large, index 138796, skipping...
# item too large, index 138797, skipping...
# item too large, index 138798, skipping...
# item too large, index 138799, skipping...
# item too large, index 138800, skipping...
# item too large, index 138801, skipping...
# item too large, index 138802, skipping...
# item too large, index 138803, skipping...
# item too large, index 138804, skipping...
# item too large, index 138805, skipping...
# item too large, index 138806, skipping...
# item too large, index 138807, skipping...
# item too large, index 138808, skipping...
# item too large, index 138809, skipping...
# item too large, index 138810, skipping...
# item too large, index 138811, skipping...
# item too large, index 138812, skipping...
# item too large, index 138813, skipping...
# item too large, index 138814, skipping...
# item too large, index 138815, skipping...
# item too large, index 138816, skipping...
# item too large, index 138817, skipping...
# item too large, index 138818, skipping...
# item too large, index 138819, skipping...
# item too large, index 138820, skipping...
# item too large, index 138821, skipping...
# item too large, index 138822, skipping...
# item too large, index 138823, skipping...
# item too large, index 138824, skipping...
# item too large, index 138825, skipping...
# item too large, index 138826, skipping...
# item too large, index 138827, skipping...
# item too large, index 138828, skipping...
# item too large, index 138829, skipping...
# item too large, index 138830, skipping...
# item too large, index 138831, skipping...
# item too large, index 138832, skipping...
# item too large, index 138833, skipping...
# item too large, index 138834, skipping...
# item too large, index 138835, skipping...
# item too large, index 138836, skipping...
# item too large, index 138837, skipping...
# item too large, index 138838, skipping...
# item too large, index 138839, skipping...
# item too large, index 138840, skipping...
# item too large, index 138841, skipping...
# item too large, index 138842, skipping...
# item too large, index 138843, skipping...
# item too large, index 138844, skipping...
# item too large, index 138845, skipping...
# item too large, index 138846, skipping...
# item too large, index 138847, skipping...
# item too large, index 138848, skipping...
# item too large, index 138849, skipping...
# item too large, index 138850, skipping...
# item too large, index 138851, skipping...
# item too large, index 138852, skipping...
# item too large, index 138853, skipping...
# item too large, index 138854, skipping...
# item too large, index 138855, skipping...
# item too large, index 138856, skipping...
# item too large, index 138857, skipping...
# item too large, index 138858, skipping...
# item too large, index 138859, skipping...
# item too large, index 138860, skipping...
# item too large, index 138861, skipping...
# item too large, index 138862, skipping...
# item too large, index 138863, skipping...
# item too large, index 138864, skipping...
# item too large, index 138865, skipping...
# item too large, index 138866, skipping...
# item too large, index 138867, skipping...
# item too large, index 138868, skipping...
# item too large, index 138869, skipping...
# item too large, index 138870, skipping...
# item too large, index 138871, skipping...
# item too large, index 138872, skipping...
# item too large, index 138873, skipping...
# item too large, index 138874, skipping...
# item too large, index 138875, skipping...
# loaded data into table.

# %%
# print(checkin_table.item_count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-dd54b3e573b8> in <module>
# ----> 1 print(checkin_table.item_count)
#
# NameError: name 'checkin_table' is not defined

# %% [markdown]
# ## business

# %%
business = read_json('s3a://yelp-dataset-stevenhurwitt/yelp_academic_dataset_business.json')
print('read in json file.')
# Out:
# read in json file.

# %%
print('json file has {} records with size of {} mb.'.format(len(business), sys.getsizeof(business)/1000000))
print('here is an example record:')
print('')
pp.pprint(business[0])
# Out:
# json file has 160585 records with size of 1.443576 gb.
# here is an example record:
#
# {  'address': '921 Pearl St',
#    'attributes': {  'Alcohol': "'beer_and_wine'",
#                     'Ambience': "{'touristy': False, 'hipster': False, "
#                                 "'romantic': False, 'divey': False, "
#                                 "'intimate': False, 'trendy': False, "
#                                 "'upscale': False, 'classy': False, 'casual': "
#                                 'True}',
#                     'BikeParking': 'True',
#                     'BusinessAcceptsBitcoin': 'False',
#                     'BusinessAcceptsCreditCards': 'True',
#                     'BusinessParking': "{'garage': False, 'street': True, "
#                                        "'validated': False, 'lot': False, "
#                                        "'valet': False}",
#                     'Caters': 'True',
#                     'DogsAllowed': 'False',
#                     'GoodForMeal': "{'dessert': False, 'latenight': False, "
#                                    "'lunch': False, 'dinner': False, 'brunch': "
#                                    "False, 'breakfast': False}",
#                     'HappyHour': 'True',
#                     'HasTV': 'True',
#                     'NoiseLevel': "u'average'",
#                     'OutdoorSeating': 'True',
#                     'RestaurantsAttire': "'casual'",
#                     'RestaurantsDelivery': 'None',
#                     'RestaurantsGoodForGroups': 'True',
#                     'RestaurantsPriceRange2': '2',
#                     'RestaurantsReservations': 'False',
#                     'RestaurantsTableService': 'True',
#                     'RestaurantsTakeOut': 'True',
#                     'WheelchairAccessible': 'True',
#                     'WiFi': "u'free'"},
#    'business_id': '6iYb2HFDywm3zjuRg0shjw',
#    'categories': 'Gastropubs, Food, Beer Gardens, Restaurants, Bars, American '
#                  '(Traditional), Beer Bar, Nightlife, Breweries',
#    'city': 'Boulder',
#    'hours': {  'Friday': '11:0-23:0',
#                'Monday': '11:0-23:0',
#                'Saturday': '11:0-23:0',
#                'Sunday': '11:0-23:0',
#                'Thursday': '11:0-23:0',
#                'Tuesday': '11:0-23:0',
#                'Wednesday': '11:0-23:0'},
#    'is_open': 1,
#    'latitude': 40.0175444,
#    'longitude': -105.2833481,
#    'name': 'Oskar Blues Taproom',
#    'postal_code': '80302',
#    'review_count': 86,
#    'stars': 4.0,
#    'state': 'CO'}

# %%
del business

# %%
checkin[0]['date']
# Out:
# str

# %%
# for i in range(1,len(checkin)):
    # mongo_upload(checkin[i])
    # pp.pprint(checkin[i])

# print('uploaded checkin collection.')
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-12-8731e4264d5c> in <module>
#       1 for i in range(1,len(checkin)):
# ----> 2     mongo_upload(checkin[i])
#       3
#       4 print('uploaded checkin collection.')
#
# <ipython-input-11-d6eb11881702> in mongo_upload(endpoint)
#      21     Collection = db[endpoint_str]
#      22     # Collection.insert_many(endpoint)
# ---> 23     Collection.insert_one(endpoint)
#      24     # print('uploaded {} collection to mongodb.'.format(endpoint_str))
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     696         write_concern = self._write_concern_for(session)
#     697         return InsertOneResult(
# --> 698             self._insert(document,
#     699                          write_concern=write_concern,
#     700                          bypass_doc_val=bypass_document_validation,
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     611         """Internal insert helper."""
#     612         if isinstance(docs, abc.Mapping):
# --> 613             return self._insert_one(
#     614                 docs, ordered, check_keys, manipulate, write_concern, op_id,
#     615                 bypass_doc_val, session)
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     600             _check_write_command_response(result)
#     601
# --> 602         self.__database.client._retryable_write(
#     603             acknowledged, _insert_command, session)
#     604
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1496         """Internal retryable write helper."""
#    1497         with self._tmp_session(session) as s:
# -> 1498             return self._retry_with_session(retryable, func, s, None)
#    1499
#    1500     def _handle_getlasterror(self, address, error_msg):
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1382         retryable = (retryable and self.retry_writes
#    1383                      and session and not session.in_transaction)
# -> 1384         return self._retry_internal(retryable, func, session, bulk)
#    1385
#    1386     def _retry_internal(self, retryable, func, session, bulk):
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1414                             raise last_error
#    1415                         retryable = False
# -> 1416                     return func(session, sock_info, retryable)
#    1417             except ServerSelectionTimeoutError:
#    1418                 if is_retrying():
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\collection.py in _insert_command(session, sock_info, retryable_write)
#     588                 command['bypassDocumentValidation'] = True
#     589
# --> 590             result = sock_info.command(
#     591                 self.__database.name,
#     592                 command,
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     681             self._raise_if_not_writable(unacknowledged)
#     682         try:
# --> 683             return command(self, dbname, spec, slave_ok,
#     684                            self.is_mongos, read_preference, codec_options,
#     685                            session, client, check, allowable_errors,
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     157                 client._process_response(response_doc, session)
#     158             if check:
# --> 159                 helpers._check_command_response(
#     160                     response_doc, sock_info.max_wire_version, None,
#     161                     allowable_errors,
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, msg, allowable_errors, parse_write_concern_error)
#     165
#     166             msg = msg or "%s"
# --> 167             raise OperationFailure(msg % errmsg, code, response,
#     168                                    max_wire_version)
#     169
#
# OperationFailure: Fully qualified namespace is too long. Namespace: yelp.{'business_id': '--0zrn43LEaB4jUWTQH_Bg', 'date': '2010-10-08 22:21:20, 2010-11-01 21:29:14, 2010-12-23 22:55:45, 2011-04-08 17:14:59, 2011-04-11 21:28:45, 2011-04-26 16:42:25, 2011-05-20 19:30:57, 2011-05-24 20:02:21, 2011-08-29 19:01:31', '_id': ObjectId('60691a52c189385debb59268')} Max: 255, full error: {'ok': 0.0, 'errmsg': "Fully qualified namespace is too long. Namespace: yelp.{'business_id': '--0zrn43LEaB4jUWTQH_Bg', 'date': '2010-10-08 22:21:20, 2010-11-01 21:29:14, 2010-12-23 22:55:45, 2011-04-08 17:14:59, 2011-04-11 21:28:45, 2011-04-26 16:42:25, 2011-05-20 19:30:57, 2011-05-24 20:02:21, 2011-08-29 19:01:31', '_id': ObjectId('60691a52c189385debb59268')} Max: 255", 'code': 4862100, 'codeName': 'Location4862100'}

# %%
# str(business[0]["business_id"])
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-14-5faa4caedf93> in <module>
# ----> 1 mongo_upload(checkin[2])
#
# <ipython-input-11-d6eb11881702> in mongo_upload(endpoint)
#      21     Collection = db[endpoint_str]
#      22     # Collection.insert_many(endpoint)
# ---> 23     Collection.insert_one(endpoint)
#      24     # print('uploaded {} collection to mongodb.'.format(endpoint_str))
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     696         write_concern = self._write_concern_for(session)
#     697         return InsertOneResult(
# --> 698             self._insert(document,
#     699                          write_concern=write_concern,
#     700                          bypass_doc_val=bypass_document_validation,
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\collection.py in _insert(self, docs, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     611         """Internal insert helper."""
#     612         if isinstance(docs, abc.Mapping):
# --> 613             return self._insert_one(
#     614                 docs, ordered, check_keys, manipulate, write_concern, op_id,
#     615                 bypass_doc_val, session)
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, manipulate, write_concern, op_id, bypass_doc_val, session)
#     600             _check_write_command_response(result)
#     601
# --> 602         self.__database.client._retryable_write(
#     603             acknowledged, _insert_command, session)
#     604
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1496         """Internal retryable write helper."""
#    1497         with self._tmp_session(session) as s:
# -> 1498             return self._retry_with_session(retryable, func, s, None)
#    1499
#    1500     def _handle_getlasterror(self, address, error_msg):
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\mongo_client.py in _retry_with_session(self, retryable, func, session, bulk)
#    1382         retryable = (retryable and self.retry_writes
#    1383                      and session and not session.in_transaction)
# -> 1384         return self._retry_internal(retryable, func, session, bulk)
#    1385
#    1386     def _retry_internal(self, retryable, func, session, bulk):
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\mongo_client.py in _retry_internal(self, retryable, func, session, bulk)
#    1414                             raise last_error
#    1415                         retryable = False
# -> 1416                     return func(session, sock_info, retryable)
#    1417             except ServerSelectionTimeoutError:
#    1418                 if is_retrying():
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\collection.py in _insert_command(session, sock_info, retryable_write)
#     588                 command['bypassDocumentValidation'] = True
#     589
# --> 590             result = sock_info.command(
#     591                 self.__database.name,
#     592                 command,
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     681             self._raise_if_not_writable(unacknowledged)
#     682         try:
# --> 683             return command(self, dbname, spec, slave_ok,
#     684                            self.is_mongos, read_preference, codec_options,
#     685                            session, client, check, allowable_errors,
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     157                 client._process_response(response_doc, session)
#     158             if check:
# --> 159                 helpers._check_command_response(
#     160                     response_doc, sock_info.max_wire_version, None,
#     161                     allowable_errors,
#
# C:\ProgramData\Miniconda3\envs\yelp\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, msg, allowable_errors, parse_write_concern_error)
#     165
#     166             msg = msg or "%s"
# --> 167             raise OperationFailure(msg % errmsg, code, response,
#     168                                    max_wire_version)
#     169
#
#               '2016-05-19 17:50:15, 2016-05-19 23:14:21, 2016-05-20 21:55:53, '
#               '2016-05-23 23:47:17, 2016-05-28 22:48:13, 2016-06-02 23:52:03, '
#               '2016-06-09 17:26:29, 2016-06-11 00:10:02, 2016-06-11 03:21:59, '
#               '2016-06-11 20:05:29, 2016-06-11 20:57:08, 2016-06-12 01:49:16, '
#               '2016-06-17 02:58:38, 2016-06-17 18:41:38, 2016-06-22 01:07:59, '
#               '2016-06-24 04:00:11, 2016-06-25 23:43:28, 2016-06-25 23:56:45, '
#               '2016-07-01 03:38:50, 2016-07-02 21:00:22, 2016-07-04 20:16:00, '
#               '2016-07-05 19:19:58, 2016-07-08 00:58:22, 2016-07-10 00:51:39, '
#               '2016-07-10 19:03:05, 2016-07-14 18:22:47, 2016-07-17 20:40:19, '
#               '2016-07-24 01:35:20, 2016-07-24 03:15:34, 2016-07-25 04:04:33, '
#               '2016-07-28 22:47:05, 2016-07-29 18:43:48, 2016-08-02 02:03:04, '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-3af9dab6562f> in <module>
# ----> 1 pp.pprint(checkin)
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/pprint.py in pprint(self, object)
#     146
#     147     def pprint(self, object):
# --> 148         self._format(object, self._stream, 0, 0, {}, 0)
#     149         self._stream.write("\n")
#     150
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/pprint.py in _pprint_list(self, object, stream, indent, allowance, context, level)
#     219     def _pprint_list(self, object, stream, indent, allowance, context, level):
#     220         stream.write('[')
# --> 221         self._format_items(object, stream, indent, allowance + 1,
#     222                            context, level)
#     223         stream.write(']')
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/pprint.py in _format_items(self, items, stream, indent, allowance, context, level)
#     424             write(delim)
#     425             delim = delimnl
# --> 426             self._format(ent, stream, indent,
#     427                          allowance if last else 1,
#     428                          context, level)
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     198             else:
#     199                 items = object.items()
# --> 200             self._format_dict_items(items, stream, indent, allowance + 1,
#     201                                     context, level)
#     202         write('}')
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     381             write(rep)
#     382             write(': ')
# --> 383             self._format(ent, stream, indent + len(rep) + 2,
#     384                          allowance if last else 1,
#     385                          context, level)
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/pprint.py in _pprint_str(self, object, stream, indent, allowance, context, level)
#     299             if i > 0:
#     300                 write('\n' + ' '*indent)
# --> 301             write(rep)
#     302         if level == 1:
#     303             write(')')
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/site-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/site-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     503                 )
#     504             data.group = group
# --> 505         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     506
#     507     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
del checkin

# %% [markdown]
# ## tip

# %%
tip = read_json('s3a://yelp-dataset-stevenhurwitt/yelp_academic_dataset_tip.json')
logger.info('read in json file.')
# Out:
# read in json file.

# %%
logger.info('json file has {} records with size of {} mb.'.format(len(tip), sys.getsizeof(tip)/1000000))
logger.info('here is an example record:')
logger.info('')
logger.info(tip[0])
# Out:
# json file has 1162119 records with size of 9.504856 gb.
# here is an example record:
#
# {  'business_id': 'ENwBByjpoa5Gg7tKgxqwLg',
#    'compliment_count': 0,
#    'date': '2011-07-22 19:07:35',
#    'text': 'Carne asada chips...',
#    'user_id': 'WCjg0jdHXMlwbqS9tZUx8Q'}

# %%
del tip

# %% [markdown]
# ## user

# %%
try:
    user = read_json('s3a://yelp-dataset-stevenhurwitt/yelp_academic_dataset_user.json')
    print('read in json file.')

except Exception as e:
    logger.warn(e)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-5-72d4f5f5af8c> in <module>
# ----> 1 user = read_json('yelp_academic_dataset_user.json')
#       2 print('read in json file.')
#
# <ipython-input-4-162ca460b095> in read_json(filename)
#      10
#      11     response = client.get_object(Bucket = 'yelp-academic-dataset-123', Key = filename)
# ---> 12     file_content = response['Body'].read().decode('utf-8')
#      13     json_file = json_util.loads("[" + file_content.replace("}\n{", "},\n{") + "]")
#      14     return(json_file)
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/site-packages/botocore/response.py in read(self, amt)
#      75         """
#      76         try:
# ---> 77             chunk = self._raw_stream.read(amt)
#      78         except URLLib3ReadTimeoutError as e:
#      79             # TODO: the url will be None as urllib3 isn't setting it yet
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     513             if amt is None:
#     514                 # cStringIO doesn't like amt=None
# --> 515                 data = self._fp.read() if not fp_closed else b""
#     516                 flush_decoder = True
#     517             else:
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/http/client.py in read(self, amt)
#     469             else:
#     470                 try:
# --> 471                     s = self._safe_read(self.length)
#     472                 except IncompleteRead:
#     473                     self._close_conn()
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/http/client.py in _safe_read(self, amt)
#     610         IncompleteRead exception can be used to detect the problem.
#     611         """
# --> 612         data = self.fp.read(amt)
#     613         if len(data) < amt:
#     614             raise IncompleteRead(data, amt-len(data))
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# OverflowError: signed integer is greater than maximum

# %%
logger.info('json file has {} records with size of {} mb.'.format(len(user), sys.getsizeof(user)/1000000))
logger.info('here is an example record:')
logger.info('')
logger.info(user[0])

# %%
del user

# %% [markdown]
# ## review

# %%
try:
    review = read_json('s3a://yelp-dataset-stevenhurwitt/yelp_academic_dataset_review.json')
    logger.info('read in json file')

except Exception as e:
    logger.warn(e)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-6-ff647a1ba226> in <module>
# ----> 1 review = read_json('yelp_academic_dataset_review.json')
#       2 print('read in json file.')
#
# <ipython-input-4-162ca460b095> in read_json(filename)
#      10
#      11     response = client.get_object(Bucket = 'yelp-academic-dataset-123', Key = filename)
# ---> 12     file_content = response['Body'].read().decode('utf-8')
#      13     json_file = json_util.loads("[" + file_content.replace("}\n{", "},\n{") + "]")
#      14     return(json_file)
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/site-packages/botocore/response.py in read(self, amt)
#      75         """
#      76         try:
# ---> 77             chunk = self._raw_stream.read(amt)
#      78         except URLLib3ReadTimeoutError as e:
#      79             # TODO: the url will be None as urllib3 isn't setting it yet
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     513             if amt is None:
#     514                 # cStringIO doesn't like amt=None
# --> 515                 data = self._fp.read() if not fp_closed else b""
#     516                 flush_decoder = True
#     517             else:
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/http/client.py in read(self, amt)
#     469             else:
#     470                 try:
# --> 471                     s = self._safe_read(self.length)
#     472                 except IncompleteRead:
#     473                     self._close_conn()
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/http/client.py in _safe_read(self, amt)
#     610         IncompleteRead exception can be used to detect the problem.
#     611         """
# --> 612         data = self.fp.read(amt)
#     613         if len(data) < amt:
#     614             raise IncompleteRead(data, amt-len(data))
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~/miniforge-pypy3/envs/yelp/lib/python3.9/ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# OverflowError: signed integer is greater than maximum

# %%
logger.info('json file has {} records with size of {} mb.'.format(len(review), sys.getsizeof(review)/1000000))
logger.info('here is an example record:')
logger.info('')
logger.info(review[0])

# %%
del review
